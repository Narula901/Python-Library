# %%
pip install pmdarima
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pmdarima.arima import auto_arima

# %%
# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
help(auto_arima)
# Out:
# Help on function auto_arima in module pmdarima.arima.auto:
#
# auto_arima(y, X=None, start_p=2, d=None, start_q=2, max_p=5, max_d=2, max_q=5, start_P=1, D=None, start_Q=1, max_P=2, max_D=1, max_Q=2, max_order=5, m=1, seasonal=True, stationary=False, information_criterion='aic', alpha=0.05, test='kpss', seasonal_test='ocsb', stepwise=True, n_jobs=1, start_params=None, trend=None, method='lbfgs', maxiter=50, offset_test_args=None, seasonal_test_args=None, suppress_warnings=True, error_action='trace', trace=False, random=False, random_state=None, n_fits=10, return_valid_fits=False, out_of_sample_size=0, scoring='mse', scoring_args=None, with_intercept='auto', sarimax_kwargs=None, **fit_args)
#     Automatically discover the optimal order for an ARIMA model.
#
#     The auto-ARIMA process seeks to identify the most optimal
#     parameters for an ``ARIMA`` model, settling on a single fitted ARIMA model.
#     This process is based on the commonly-used R function,
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('D:\\karan data\\Data for Preprocessing\\Forecasting Data\\airline_passengers.csv', index_col='Month',parse_dates=True)

# %%
df
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121
# ...                             ...
# 1960-08-01                      606
# 1960-09-01                      508
# 1960-10-01                      461
# 1960-11-01                      390
# 1960-12-01                      432
#
# [144 rows x 1 columns]

# %%
auto_arima(df['Thousands of Passengers'],error_action='ignore',seasonal=True, m=12).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ...
# Dep. Variable:                                   y   No. Observations:                  144
# Model:             SARIMAX(2, 1, 1)x(0, 1, [], 12)   Log Likelihood                -504.923
# Date:                             Fri, 01 Mar 2024   AIC                           1017.847
# Time:                                     10:18:18   BIC                           1029.348
# Sample:                                 01-01-1949   HQIC                          1022.520
#                                       - 12-01-1960
# Covariance Type:                               opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5959      0.085      6.987      0.000       0.429       0.763
# ...

# %%
Birth = pd.read_csv('D:\\karan data\\Data for Preprocessing\\Forecasting Data\\DailyTotalFemaleBirths.csv', index_col='Date', parse_dates=True)

# %%
Birth.head()
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44

# %%
auto_arima(Birth['Births'],error_action='ignore', start_p=0, start_q=0, max_p=6, max_q=3, seasonal=False,trace=True).summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2650.760, Time=0.14 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2565.234, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2463.584, Time=0.19 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2648.768, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2460.154, Time=0.18 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=2461.271, Time=0.29 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.47 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=2460.722, Time=0.22 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=2536.154, Time=0.11 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2463.043, Time=0.51 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=2459.074, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=2462.221, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=2563.261, Time=0.04 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=2460.367, Time=0.11 sec
# ...

# %%
auto_arima(Birth['Births'],error_action='ignore').summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  365
# Model:               SARIMAX(1, 1, 1)   Log Likelihood               -1226.537
# Date:                Fri, 01 Mar 2024   AIC                           2459.074
# Time:                        10:09:13   BIC                           2470.766
# Sample:                    01-01-1959   HQIC                          2463.721
#                          - 12-31-1959
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1252      0.060      2.097      0.036       0.008       0.242
# ma.L1         -0.9624      0.017    -56.429      0.000      -0.996      -0.929
# sigma2        49.1512      3.250     15.122      0.000      42.781      55.522
# ...

# %%
stepwise_fit = auto_arima(Birth['Births'], start_p=0, start_q=0,
                          max_p=6, max_q=3, m=12,
                          seasonal=False,
                          d=None, trace=True,
                          error_action='ignore',   # we don't want to know if an order does not work
                          suppress_warnings=True,  # we don't want convergence warnings
                          stepwise=True)           # set to stepwise

stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2650.760, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2565.234, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2463.584, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2648.768, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2460.154, Time=0.17 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=2461.271, Time=0.25 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.44 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=2460.722, Time=0.21 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=2536.154, Time=0.10 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2463.043, Time=0.55 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=2459.074, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=2462.221, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=2563.261, Time=0.03 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=2460.367, Time=0.10 sec
# ...

# %%
stepwise_fit = auto_arima(df['Thousands of Passengers'], start_p=1, start_q=1,
                          max_p=3, max_q=3, m=12,
                          start_P=0, seasonal=True,
                          d=None, D=1, trace=True,
                          error_action='ignore',   # we don't want to know if an order does not work
                          suppress_warnings=True,  # we don't want convergence warnings
                          stepwise=True)           # set to stepwise

stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=1022.896, Time=0.20 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=1031.508, Time=0.03 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=1020.393, Time=0.10 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=1021.003, Time=0.11 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=1020.393, Time=0.07 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=1019.239, Time=0.23 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=1.52 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=1020.493, Time=0.30 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : AIC=1032.120, Time=0.14 sec
#  ARIMA(2,1,0)(2,1,0)[12]             : AIC=1021.120, Time=0.26 sec
#  ARIMA(1,1,1)(2,1,0)[12]             : AIC=1021.032, Time=0.41 sec
#  ARIMA(0,1,1)(2,1,0)[12]             : AIC=1019.178, Time=0.22 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=1020.425, Time=0.11 sec
# ...
