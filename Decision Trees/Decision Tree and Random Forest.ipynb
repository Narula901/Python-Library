# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('D:\\karan data\\Data for Preprocessing\\Census_income_train.csv')

# %%
df.head()
# Out:
#    Age          Workclass  fnlwgt   Education  Education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         Marital status          Occupation    Relationship    Race      Sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    Capital-gain  Capital-loss  Hours-per-week  Native-country  Income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# fnlwgt            0
# Education         0
# Education-num     0
# Marital status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital-gain      0
# Capital-loss      0
# Hours-per-week    0
# Native-country    0
# Income            0
# dtype: int64

# %%
df['Workclass'].str.contains('\?') == False
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 32555    True
# 32556    True
# 32557    True
# 32558    True
# 32559    True
# Name: Workclass, Length: 32560, dtype: bool

# %%
df = df[df['Workclass'].str.contains('\?') == False]

# %%
df
# Out:
#        Age          Workclass  fnlwgt    Education  Education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital status          Occupation    Relationship    Race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df = df[df['Occupation'].str.contains('\?') == False]

# %%
df[df['Native-country'].str.contains('\?') == False]
# Out:
#        Age          Workclass  fnlwgt    Education  Education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital status          Occupation    Relationship    Race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.head()
# Out:
#    Age          Workclass  fnlwgt   Education  Education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         Marital status          Occupation    Relationship    Race      Sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    Capital-gain  Capital-loss  Hours-per-week  Native-country  Income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df
# Out:
#        Age          Workclass  fnlwgt    Education  Education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital status          Occupation    Relationship    Race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df_dummies = pd.get_dummies(df, drop_first=False)

# %%
df_dummies = df_dummies.astype(int)

# %%
df_dummies.drop('Income_ <=50K', axis =1, inplace=True)

# %%
df_dummies.head()
# Out:
#    Age  fnlwgt  Education-num  Capital-gain  Capital-loss  Hours-per-week  \
# 0   39   77516             13          2174             0              40
# 1   50   83311             13             0             0              13
# 2   38  215646              9             0             0              40
# 3   53  234721              7             0             0              40
# 4   28  338409             13             0             0              40
#
#    Workclass_ Federal-gov  Workclass_ Local-gov  Workclass_ Private  \
# 0                       0                     0                   0
# 1                       0                     0                   0
# 2                       0                     0                   1
# 3                       0                     0                   1
# 4                       0                     0                   1
#
#    Workclass_ Self-emp-inc  ...  Native-country_ Puerto-Rico  \
# ...

# %%
X_train = df_dummies.iloc[:, :-1]
y_train = df_dummies.iloc[:, -1]

# %%
y_train
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32555    0
# 32556    1
# 32557    0
# 32558    0
# 32559    1
# Name: Income_ >50K, Length: 30717, dtype: int32

# %%
X_train
# Out:
#        Age  fnlwgt  Education-num  Capital-gain  Capital-loss  Hours-per-week  \
# 0       39   77516             13          2174             0              40
# 1       50   83311             13             0             0              13
# 2       38  215646              9             0             0              40
# 3       53  234721              7             0             0              40
# 4       28  338409             13             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 32555   27  257302             12             0             0              38
# 32556   40  154374              9             0             0              40
# 32557   58  151910              9             0             0              40
# 32558   22  201490              9             0             0              20
# 32559   52  287927              9         15024             0              40
#
# ...

# %%
# Now do same thing for test dataset

# %%
df_1 = pd.read_csv('D:\karan data\Data for Preprocessing\Census_income_test.csv')

# %%
df_1
# Out:
#        Age      Workclass  fnlwgt      Education  Education-num  \
# 0       25        Private  226802           11th              7
# 1       38        Private   89814        HS-grad              9
# 2       28      Local-gov  336951     Assoc-acdm             12
# 3       44        Private  160323   Some-college             10
# 4       18              ?  103497   Some-college             10
# ...    ...            ...     ...            ...            ...
# 16276   39        Private  215419      Bachelors             13
# 16277   64              ?  321403        HS-grad              9
# 16278   38        Private  374983      Bachelors             13
# 16279   44        Private   83891      Bachelors             13
# 16280   35   Self-emp-inc  182148      Bachelors             13
#
#             Marital status          Occupation     Relationship  \
# 0            Never-married   Machine-op-inspct        Own-child
# 1       Married-civ-spouse     Farming-fishing          Husband
# ...

# %%
df_1 = df_1[df_1['Workclass'].str.contains('\?') == False]

# %%
df_1 = df_1[df_1['Occupation'].str.contains('\?') == False]

# %%
df_1 = df_1[df_1['Native-country'].str.contains('\?') == False]

# %%
df_1[df_1['Native-country'].str.contains('\?') == False]
# Out:
#        Age      Workclass  fnlwgt      Education  Education-num  \
# 0       25        Private  226802           11th              7
# 1       38        Private   89814        HS-grad              9
# 2       28      Local-gov  336951     Assoc-acdm             12
# 3       44        Private  160323   Some-college             10
# 5       34        Private  198693           10th              6
# ...    ...            ...     ...            ...            ...
# 16275   33        Private  245211      Bachelors             13
# 16276   39        Private  215419      Bachelors             13
# 16278   38        Private  374983      Bachelors             13
# 16279   44        Private   83891      Bachelors             13
# 16280   35   Self-emp-inc  182148      Bachelors             13
#
#             Marital status          Occupation    Relationship  \
# 0            Never-married   Machine-op-inspct       Own-child
# 1       Married-civ-spouse     Farming-fishing         Husband
# ...

# %%
df_1['Native-country'].value_counts()
# Out:
# Native-country
#  United-States                 13788
#  Mexico                          293
#  Philippines                      95
#  Puerto-Rico                      66
#  Germany                          65
#  Canada                           56
#  El-Salvador                      47
#  India                            47
#  China                            45
#  Cuba                             41
#  England                          33
#  Italy                            32
#  South                            30
#  Dominican-Republic               30
#  Japan                            30
#  Portugal                         28
#  Haiti                            27
#  Columbia                         26
#  Poland                           25
#  Guatemala                        23
#  Jamaica                          23
#  Greece                           20
#  Vietnam                          19
#  Ecuador                          16
#  Nicaragua                        15
# ...

# %%
test_dummies = pd.get_dummies(df_1, drop_first=False)

# %%
test_dummies = test_dummies.astype(int)

# %%
test_dummies
# Out:
#        Age  fnlwgt  Education-num  Capital-gain  Capital-loss  Hours-per-week  \
# 0       25  226802              7             0             0              40
# 1       38   89814              9             0             0              50
# 2       28  336951             12             0             0              40
# 3       44  160323             10          7688             0              40
# 5       34  198693              6             0             0              30
# ...    ...     ...            ...           ...           ...             ...
# 16275   33  245211             13             0             0              40
# 16276   39  215419             13             0             0              36
# 16278   38  374983             13             0             0              50
# 16279   44   83891             13          5455             0              40
# 16280   35  182148             13             0             0              60
#
# ...

# %%
test_dummies = test_dummies.drop(['Income_ <=50K.'],axis=1)

# %%
test_dummies
# Out:
#        Age  fnlwgt  Education-num  Capital-gain  Capital-loss  Hours-per-week  \
# 0       25  226802              7             0             0              40
# 1       38   89814              9             0             0              50
# 2       28  336951             12             0             0              40
# 3       44  160323             10          7688             0              40
# 5       34  198693              6             0             0              30
# ...    ...     ...            ...           ...           ...             ...
# 16275   33  245211             13             0             0              40
# 16276   39  215419             13             0             0              36
# 16278   38  374983             13             0             0              50
# 16279   44   83891             13          5455             0              40
# 16280   35  182148             13             0             0              60
#
# ...

# %%
X_test = test_dummies.iloc[:, :-1]
y_test = test_dummies.iloc[:,-1]

# %%
X_test
# Out:
#        Age  fnlwgt  Education-num  Capital-gain  Capital-loss  Hours-per-week  \
# 0       25  226802              7             0             0              40
# 1       38   89814              9             0             0              50
# 2       28  336951             12             0             0              40
# 3       44  160323             10          7688             0              40
# 5       34  198693              6             0             0              30
# ...    ...     ...            ...           ...           ...             ...
# 16275   33  245211             13             0             0              40
# 16276   39  215419             13             0             0              36
# 16278   38  374983             13             0             0              50
# 16279   44   83891             13          5455             0              40
# 16280   35  182148             13             0             0              60
#
# ...

# %% [markdown]
# ## Creating and visualizing the tree

# %%
from sklearn import tree
from sklearn.metrics import classification_report

# %%
# Define the model as a decision tree classifier
clf = tree.DecisionTreeClassifier()

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Plot the tree
#plt.figure(figsize=(10,10))
#tree.plot_tree(clf, filled=True)
#plt.show()

# %%
# This picture is very complicated indicating a tree with enormous proportions
# This indicates a high probability that the model has overfitted

# %%
test_pred = clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 test_pred = clf.predict(X_test)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:500, in BaseDecisionTree.predict(self, X, check_input)
#     477 """Predict class or regression value for X.
#     478
#     479 For a classification model, the predicted class for each sample in X is
#    (...)
#     497     The predicted classes, or the predict values.
#     498 """
#     499 check_is_fitted(self)
# --> 500 X = self._validate_X_predict(X, check_input)
#     501 proba = self.tree_.predict(X)
#     502 n_samples = X.shape[0]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:460, in BaseDecisionTree._validate_X_predict(self, X, check_input)
#     458 else:
#     459     force_all_finite = True
# --> 460 X = self._validate_data(
#     461     X,
# ...

# %%
X_test.head(2)
# Out:
#    Age  fnlwgt  Education-num  Capital-gain  Capital-loss  Hours-per-week  \
# 0   25  226802              7             0             0              40
# 1   38   89814              9             0             0              50
#
#    Workclass_ Federal-gov  Workclass_ Local-gov  Workclass_ Private  \
# 0                       0                     0                   1
# 1                       0                     0                   1
#
#    Workclass_ Self-emp-inc  ...  Native-country_ Portugal  \
# 0                        0  ...                         0
# 1                        0  ...                         0
#
#    Native-country_ Puerto-Rico  Native-country_ Scotland  \
# 0                            0                         0
# 1                            0                         0
#
#    Native-country_ South  Native-country_ Taiwan  Native-country_ Thailand  \
# 0                      0                       0                         0
# ...

# %%
X_train.head(2)
# Out:
#    Age  fnlwgt  Education-num  Capital-gain  Capital-loss  Hours-per-week  \
# 0   39   77516             13          2174             0              40
# 1   50   83311             13             0             0              13
#
#    Workclass_ Federal-gov  Workclass_ Local-gov  Workclass_ Private  \
# 0                       0                     0                   0
# 1                       0                     0                   0
#
#    Workclass_ Self-emp-inc  ...  Native-country_ Portugal  \
# 0                        0  ...                         0
# 1                        0  ...                         0
#
#    Native-country_ Puerto-Rico  Native-country_ Scotland  \
# 0                            0                         0
# 1                            0                         0
#
#    Native-country_ South  Native-country_ Taiwan  Native-country_ Thailand  \
# 0                      0                       0                         0
# ...

# %%
import pandas as pd

# Assuming X_test is your test data and X_train is your training data
# Check if "Native-country_ ?" feature is missing in test data
if 'Native-country_ ?' not in X_test.columns:
    # If missing, add the feature with appropriate values (e.g., all zeros)
    X_test['Native-country_ ?'] = 0

# Re-Order Features: Ensure feature order matches that of the training data
# Drop any extra columns in test data that are not present in training data
X_test = X_test[X_train.columns]

# Make predictions
test_pred = clf.predict(X_test)

# %%
test_pred
# Out:
# array([0, 0, 1, ..., 1, 0, 1])

# %%
# print the metrics obtained from the real targets and our model's predictions
print(classification_report(y_test, test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87     11360
#            1       0.61      0.62      0.61      3700
#
#     accuracy                           0.81     15060
#    macro avg       0.74      0.74      0.74     15060
# weighted avg       0.81      0.81      0.81     15060

# %% [markdown]
# ## Create the tree with pruning

# %%
clf = tree.DecisionTreeClassifier(ccp_alpha=0.001)

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.001)

# %%
X_train
# Out:
#        Age  fnlwgt  Education-num  Capital-gain  Capital-loss  Hours-per-week  \
# 0       39   77516             13          2174             0              40
# 1       50   83311             13             0             0              13
# 2       38  215646              9             0             0              40
# 3       53  234721              7             0             0              40
# 4       28  338409             13             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 32555   27  257302             12             0             0              38
# 32556   40  154374              9             0             0              40
# 32557   58  151910              9             0             0              40
# 32558   22  201490              9             0             0              20
# 32559   52  287927              9         15024             0              40
#
# ...

# %%
feature_names_list = list(X_train.columns)

# %%
# Plot the tree
plt.figure(figsize=(15,15))
tree.plot_tree(clf, filled=True, feature_names=feature_names_list)
plt.show()

# %%
# Plot the tree
plt.figure(figsize=(15,10))
tree.plot_tree(clf, filled=True)
plt.show()

# %%
test_pred = clf.predict(X_test)

# %%
# print the metrics obtained from the real targets and our model's predictions
print(classification_report(y_test, test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.90     11360
#            1       0.79      0.51      0.62      3700
#
#     accuracy                           0.85     15060
#    macro avg       0.82      0.73      0.76     15060
# weighted avg       0.84      0.85      0.83     15060

# %%
# The accuracy jumped from 80% to 85% after pruning
# This confirms our suspicions that the first tree has overfitted

# %% [markdown]
# ## Apply the Random Forest Method

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clfR = RandomForestClassifier(n_estimators=150)
clfR.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=150)

# %%
test_pred = clfR.predict(X_test)

# %%
print(classification_report(y_test, test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90     11360
#            1       0.72      0.62      0.66      3700
#
#     accuracy                           0.85     15060
#    macro avg       0.80      0.77      0.78     15060
# weighted avg       0.84      0.85      0.84     15060

# %%
# The result is basically the same as before, so the additional trees didn't help at all

# %%
# Apply the pruning on Random forest parameter

# %%
clf = RandomForestClassifier(ccp_alpha=0.0001)

# %%
# Train the model
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(ccp_alpha=0.0001)

# %%
test_pred = clf.predict(X_test)

# %%
# Print the metrics obtained from the real targets and our model's predictions
print(classification_report(y_test, test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91     11360
#            1       0.77      0.61      0.68      3700
#
#     accuracy                           0.86     15060
#    macro avg       0.83      0.78      0.80     15060
# weighted avg       0.85      0.86      0.85     15060

# %%
# A slight increase in accuracy however it is insignificant
# This is the limit of the performance on this dataset
