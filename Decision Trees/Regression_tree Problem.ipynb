# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('D:\karan data\Data for Preprocessing\Movie_regression.csv')

# %%
df
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0              20.1264               59.62               0.462  36524.125
# 1              20.5462               69.14               0.531  35668.655
# 2              20.5458               69.14               0.531  39912.675
# 3              20.6474               59.36               0.542  38873.890
# 4              21.3810               59.36               0.542  39701.585
# ..                 ...                 ...                 ...        ...
# 501            21.2526               78.86               0.427  36624.115
# 502            20.9054               78.86               0.427  33996.600
# 503            21.2152               78.86               0.427  38751.680
# 504            22.1918               78.86               0.427  37740.670
# 505            20.9482               78.86               0.427  33496.650
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# ...

# %%
#df = pd.read_csv("Movie_regression.csv", header=0)

# %%
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           494 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
# ...

# %% [markdown]
# ### Missing Value Imputation

# %%
df['Time_taken'].isnull().sum()
# Out:
# 12

# %%
df['Time_taken'].mean()
# Out:
# 157.3914979757085

# %%
df['Time_taken'].fillna(value = df['Time_taken'].mean(), inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           506 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
# ...

# %% [markdown]
# ### Dummy Variable Creation

# %%
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# ...

# %%
df = pd.get_dummies(df, columns=['3D_available', 'Genre'], drop_first = True).astype(int)

# %%
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage  Budget  \
# 0                 20                  59                   0   36524
# 1                 20                  69                   0   35668
# 2                 20                  69                   0   39912
# 3                 20                  59                   0   38873
# 4                 21                  59                   0   39701
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0           138                   7                    8                7
# 1           152                   7                    7                7
# 2           134                   7                    7                7
# 3           119                   6                    7                6
# 4           127                   6                    7                6
#
#    Producer_rating  Critic_rating  Trailer_views  Time_taken  Twitter_hastags  \
# ...

# %% [markdown]
# ### X-y split

# %%
X = df.loc[:, df.columns!='Collection']

# %%
X.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage  Budget  \
# 0                 20                  59                   0   36524
# 1                 20                  69                   0   35668
# 2                 20                  69                   0   39912
# 3                 20                  59                   0   38873
# 4                 21                  59                   0   39701
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0           138                   7                    8                7
# 1           152                   7                    7                7
# 2           134                   7                    7                7
# 3           119                   6                    7                6
# 4           127                   6                    7                6
#
#    Producer_rating  Critic_rating  Trailer_views  Time_taken  Twitter_hastags  \
# ...

# %%
X.shape
# Out:
# (506, 19)

# %%
y = df['Collection']
type(y)
# Out:
# pandas.core.series.Series

# %%
y.head()
# Out:
# 0    48000
# 1    43200
# 2    69400
# 3    66800
# 4    72400
# Name: Collection, dtype: int32

# %%
y.shape
# Out:
# (506,)

# %% [markdown]
# ### Test-Train Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train.head()
# Out:
#      Marketing expense  Production expense  Multiplex coverage  Budget  \
# 220                 27                  67                   0   38612
# 71                  23                  76                   0   33113
# 240                 22                  64                   0   38312
# 6                   21                  70                   0   33396
# 417                538                  91                   0   29463
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 220           162                   8                    8                8
# 71             91                   7                    7                7
# 240           127                   6                    6                6
# 6             140                   7                    7                7
# 417           162                   9                    9                9
#
#      Producer_rating  Critic_rating  Trailer_views  Time_taken  \
# ...

# %%
X_train.shape
# Out:
# (404, 19)

# %%
X_test.shape
# Out:
# (102, 19)

# %% [markdown]
# ### Traing Regression Tree

# %%
from sklearn import tree

# %%
regtree = tree.DecisionTreeRegressor(max_depth=3)

# %%
regtree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
feature_name = list(X_train.columns)

# %% [markdown]
# ### Predict values using trained model

# %%
y_train_pred = regtree.predict(X_train)
y_test_pred = regtree.predict(X_test)

# %%
y_test_pred
# Out:
# array([44534.72222222, 44534.72222222, 44534.72222222, 23514.28571429,
#        44534.72222222, 44534.72222222, 44534.72222222, 44534.72222222,
#        44534.72222222, 44534.72222222, 23514.28571429, 23514.28571429,
#        23514.28571429, 23514.28571429, 91860.86956522, 65183.33333333,
#        44534.72222222, 65183.33333333, 44534.72222222, 44534.72222222,
#        44534.72222222, 44534.72222222, 44534.72222222, 44534.72222222,
#        44534.72222222, 44534.72222222, 44534.72222222, 35137.77777778,
#        91860.86956522, 35137.77777778, 23514.28571429, 23514.28571429,
#        44534.72222222, 44534.72222222, 44534.72222222, 35137.77777778,
#        23514.28571429, 44534.72222222, 23514.28571429, 23514.28571429,
#        44534.72222222, 44534.72222222, 44534.72222222, 23514.28571429,
#        44534.72222222, 44534.72222222, 35137.77777778, 35137.77777778,
#        35137.77777778, 56987.5       , 35137.77777778, 35137.77777778,
# ...

# %% [markdown]
# ### Model Performance

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
mean_squared_error(y_test, y_test_pred)
# Out:
# 129784684.56782678

# %%
r2_score(y_train, y_train_pred)
# Out:
# 0.8243458883227486

# %%
r2_score(y_test, y_test_pred)
# Out:
# 0.5968476117360633

# %% [markdown]
# ### Plotting decision tree

# %%
# Plot the tree
plt.figure(figsize=(40,8))
tree.plot_tree(regtree, filled=True, feature_names=feature_name)
plt.show()

# %%
X_train.columns
# Out:
# Index(['Marketing expense', 'Production expense', 'Multiplex coverage',
#        'Budget', 'Movie_length', 'Lead_ Actor_Rating', 'Lead_Actress_rating',
#        'Director_rating', 'Producer_rating', 'Critic_rating', 'Trailer_views',
#        'Time_taken', 'Twitter_hastags', 'Avg_age_actors', 'Num_multiplex',
#        '3D_available_YES', 'Genre_Comedy', 'Genre_Drama', 'Genre_Thriller'],
#       dtype='object')

# %% [markdown]
# ## Controlling Tree growth

# %% [markdown]
# ### Maximum number of levels in tree

# %%
regtree = tree.DecisionTreeRegressor(max_depth=3)
regtree.fit(X_train, y_train)
plt.figure(figsize=(40,8))
tree.plot_tree(regtree, filled=True, feature_names=feature_name)
plt.show()

# %% [markdown]
# ### Minimum observations at internal node

# %%
regtree = tree.DecisionTreeRegressor(min_samples_split=40)
regtree.fit(X_train, y_train)
plt.figure(figsize=(40,8))
tree.plot_tree(regtree, filled=True, feature_names=feature_name)
plt.show()

# %% [markdown]
# ### Minimum observations at leaf node

# %%
regtree = tree.DecisionTreeRegressor(min_samples_leaf=25, max_depth = 4)
regtree.fit(X_train, y_train)
plt.figure(figsize=(40,8))
tree.plot_tree(regtree, filled=True, feature_names=feature_name, fontsize=15)
plt.show()
