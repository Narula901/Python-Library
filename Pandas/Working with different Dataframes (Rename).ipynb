# %%
import pandas as pd

# %% [markdown]
# ### Lecture - 149

# %%
Ivies_Dataset = pd.read_csv("D:\karan data\Data for Preprocessing\ivies.csv")

# %%
Ivies_Dataset
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
# 5          Cornell University  Ivy League            $60,300.00
# 6            Brown University  Ivy League            $56,200.00
# 7         Columbia University  Ivy League            $59,400.00
#
#   Mid-Career Median Salary
# 0             $134,000.00
# 1             $131,000.00
# 2             $126,000.00
# 3             $124,000.00
# 4             $120,000.00
# 5             $110,000.00
# 6             $109,000.00
# 7             $107,000.00

# %%
Liberal_Dataset = pd.read_csv("D:\karan data\Data for Preprocessing\liberal_arts.csv")

# %%
State_Dataset = pd.read_csv("D:\karan data\Data for Preprocessing\state.csv")

# %%
Eng_Dataset = pd.read_csv("D:\karan data\Data for Preprocessing\eng.csv")

# %%
Ivies_Dataset
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
# 5          Cornell University  Ivy League            $60,300.00
# 6            Brown University  Ivy League            $56,200.00
# 7         Columbia University  Ivy League            $59,400.00
#
#   Mid-Career Median Salary
# 0             $134,000.00
# 1             $131,000.00
# 2             $126,000.00
# 3             $124,000.00
# 4             $120,000.00
# 5             $110,000.00
# 6             $109,000.00
# 7             $107,000.00

# %%
Liberal_Dataset
# Out:
#                                       School Name   School Type  \
# 0                             Bucknell University  Liberal Arts
# 1                              Colgate University  Liberal Arts
# 2                                 Amherst College  Liberal Arts
# 3                               Lafayette College  Liberal Arts
# 4                                 Bowdoin College  Liberal Arts
# 5                       College of the Holy Cross  Liberal Arts
# 6                              Occidental College  Liberal Arts
# 7                   Washington and Lee University  Liberal Arts
# 8                              Swarthmore College  Liberal Arts
# 9                                Davidson College  Liberal Arts
# 10                               Carleton College  Liberal Arts
# 11                               Williams College  Liberal Arts
# 12                                 Pomona College  Liberal Arts
# 13  Wesleyan University (Middletown, Connecticut)  Liberal Arts
# ...

# %%
State_Dataset
# Out:
#                                         School Name School Type  \
# 0                University of California, Berkeley       State
# 1                      University of Virginia (UVA)       State
# 2                          Cal Poly San Luis Obispo       State
# 3    University of California at Los Angeles (UCLA)       State
# 4        University of California, San Diego (UCSD)       State
# ..                                              ...         ...
# 170                    Austin Peay State University       State
# 171                      Pittsburg State University       State
# 172                        Southern Utah University       State
# 173             Montana State University - Billings       State
# 174                    Black Hills State University       State
#
#     Starting Median Salary Mid-Career Median Salary
# 0              $59,900.00              $112,000.00
# 1              $52,700.00              $103,000.00
# ...

# %%
Eng_Dataset
# Out:
#                                           School Name  School Type  \
# 0         Massachusetts Institute of Technology (MIT)  Engineering
# 1            California Institute of Technology (CIT)  Engineering
# 2                                 Harvey Mudd College  Engineering
# 3        Polytechnic University of New York, Brooklyn  Engineering
# 4                                        Cooper Union  Engineering
# 5               Worcester Polytechnic Institute (WPI)  Engineering
# 6                    Carnegie Mellon University (CMU)  Engineering
# 7              Rensselaer Polytechnic Institute (RPI)  Engineering
# 8                     Georgia Institute of Technology  Engineering
# 9                            Colorado School of Mines  Engineering
# 10                    Stevens Institute of Technology  Engineering
# 11             Illinois Institute of Technology (IIT)  Engineering
# 12                  Wentworth Institute of Technology  Engineering
# ...

# %%
# dfs = [df1,df2,df3,df4]   union in SQL
dfs = [State_Dataset, Eng_Dataset, Liberal_Dataset, Ivies_Dataset]

# %%
for df in dfs:
    print(df.shape)
# Out:
# (175, 4)
# (19, 4)
# (47, 4)
# (8, 4)

# %%
pd.concat([Ivies_Dataset, Eng_Dataset])
# Out:
#                                           School Name  School Type  \
# 0                                   Dartmouth College   Ivy League
# 1                                Princeton University   Ivy League
# 2                                     Yale University   Ivy League
# 3                                  Harvard University   Ivy League
# 4                          University of Pennsylvania   Ivy League
# 5                                  Cornell University   Ivy League
# 6                                    Brown University   Ivy League
# 7                                 Columbia University   Ivy League
# 0         Massachusetts Institute of Technology (MIT)  Engineering
# 1            California Institute of Technology (CIT)  Engineering
# 2                                 Harvey Mudd College  Engineering
# 3        Polytechnic University of New York, Brooklyn  Engineering
# 4                                        Cooper Union  Engineering
# ...

# %%
# use key parameter
df = pd.concat([Ivies_Dataset, Eng_Dataset], keys=['Ivi', 'Eng'])

# %%
# use key parameter
pd.concat([Ivies_Dataset, Eng_Dataset], keys=['Ivi', 'Eng'], names=['dataset'])
# Out:
#                                                   School Name  School Type  \
# dataset
# Ivi     0                                   Dartmouth College   Ivy League
#         1                                Princeton University   Ivy League
#         2                                     Yale University   Ivy League
#         3                                  Harvard University   Ivy League
#         4                          University of Pennsylvania   Ivy League
#         5                                  Cornell University   Ivy League
#         6                                    Brown University   Ivy League
#         7                                 Columbia University   Ivy League
# Eng     0         Massachusetts Institute of Technology (MIT)  Engineering
#         1            California Institute of Technology (CIT)  Engineering
#         2                                 Harvey Mudd College  Engineering
# ...

# %%
# tech.loc[('02-01-2014', 'GOOGL'), 'open' : 'close']
df.loc[('Eng'), ['School Name','School Type']]
# Out:
#                                           School Name  School Type
# 0         Massachusetts Institute of Technology (MIT)  Engineering
# 1            California Institute of Technology (CIT)  Engineering
# 2                                 Harvey Mudd College  Engineering
# 3        Polytechnic University of New York, Brooklyn  Engineering
# 4                                        Cooper Union  Engineering
# 5               Worcester Polytechnic Institute (WPI)  Engineering
# 6                    Carnegie Mellon University (CMU)  Engineering
# 7              Rensselaer Polytechnic Institute (RPI)  Engineering
# 8                     Georgia Institute of Technology  Engineering
# 9                            Colorado School of Mines  Engineering
# 10                    Stevens Institute of Technology  Engineering
# 11             Illinois Institute of Technology (IIT)  Engineering
# 12                  Wentworth Institute of Technology  Engineering
# ...

# %%
pd.concat([Ivies_Dataset, Eng_Dataset]).duplicated(subset=['School Name'], keep = 'first')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# dtype: bool

# %%
#pd.concat([Ivies_Dataset, Eng_Dataset]).drop_duplicates(subset=['School Name'], keep = 'first').shape

# %%
pd.concat([Ivies_Dataset, Eng_Dataset]).drop_duplicates(subset=['School Name'], keep = 'first').shape
# Out:
# (27, 4)

# %%
pd.concat([Ivies_Dataset, Eng_Dataset]).shape
# Out:
# (27, 4)

# %%
Ivies_Dataset
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
# 5          Cornell University  Ivy League            $60,300.00
# 6            Brown University  Ivy League            $56,200.00
# 7         Columbia University  Ivy League            $59,400.00
#
#   Mid-Career Median Salary
# 0             $134,000.00
# 1             $131,000.00
# 2             $126,000.00
# 3             $124,000.00
# 4             $120,000.00
# 5             $110,000.00
# 6             $109,000.00
# 7             $107,000.00

# %%
Eng_Dataset
# Out:
#                                           School Name  School Type  \
# 0         Massachusetts Institute of Technology (MIT)  Engineering
# 1            California Institute of Technology (CIT)  Engineering
# 2                                 Harvey Mudd College  Engineering
# 3        Polytechnic University of New York, Brooklyn  Engineering
# 4                                        Cooper Union  Engineering
# 5               Worcester Polytechnic Institute (WPI)  Engineering
# 6                    Carnegie Mellon University (CMU)  Engineering
# 7              Rensselaer Polytechnic Institute (RPI)  Engineering
# 8                     Georgia Institute of Technology  Engineering
# 9                            Colorado School of Mines  Engineering
# 10                    Stevens Institute of Technology  Engineering
# 11             Illinois Institute of Technology (IIT)  Engineering
# 12                  Wentworth Institute of Technology  Engineering
# ...

# %%
Ivies_Dataset.shape[0] + Eng_Dataset.shape[0]
# Out:
# 27

# %%
Eng_Dataset['School Name']
# Out:
# 0           Massachusetts Institute of Technology (MIT)
# 1              California Institute of Technology (CIT)
# 2                                   Harvey Mudd College
# 3          Polytechnic University of New York, Brooklyn
# 4                                          Cooper Union
# 5                 Worcester Polytechnic Institute (WPI)
# 6                      Carnegie Mellon University (CMU)
# 7                Rensselaer Polytechnic Institute (RPI)
# 8                       Georgia Institute of Technology
# 9                              Colorado School of Mines
# 10                      Stevens Institute of Technology
# 11               Illinois Institute of Technology (IIT)
# 12                    Wentworth Institute of Technology
# 13    Virginia Polytechnic Institute and State Unive...
# 14            South Dakota School of Mines & Technology
# 15    New Mexico Institute of Mining and Technology ...
# 16              Rochester Institute of Technology (RIT)
# ...

# %%
State_Dataset['School Name']
# Out:
# 0                  University of California, Berkeley
# 1                        University of Virginia (UVA)
# 2                            Cal Poly San Luis Obispo
# 3      University of California at Los Angeles (UCLA)
# 4          University of California, San Diego (UCSD)
#                             ...
# 170                      Austin Peay State University
# 171                        Pittsburg State University
# 172                          Southern Utah University
# 173               Montana State University - Billings
# 174                      Black Hills State University
# Name: School Name, Length: 175, dtype: object

# %%
type(State_Dataset['School Name'])
# Out:
# pandas.core.series.Series

# %%
'Cooper Union' in State_Dataset['School Name'].values
# Out:
# False

# %%
# set(series1).difference(series2)
set(Eng_Dataset['School Name']).difference(State_Dataset['School Name'])
# Out:
# {'California Institute of Technology (CIT)',
#  'Carnegie Mellon University (CMU)',
#  'Colorado School of Mines',
#  'Cooper Union',
#  'Embry-Riddle Aeronautical University (ERAU)',
#  'Georgia Institute of Technology',
#  'Harvey Mudd College',
#  'Illinois Institute of Technology (IIT)',
#  'Massachusetts Institute of Technology (MIT)',
#  'New Mexico Institute of Mining and Technology (New Mexico Tech)',
#  'Polytechnic University of New York, Brooklyn',
#  'Rensselaer Polytechnic Institute (RPI)',
#  'Rochester Institute of Technology (RIT)',
#  'South Dakota School of Mines & Technology',
#  'Stevens Institute of Technology',
#  'Tennessee Technological University',
#  'Virginia Polytechnic Institute and State University (Virginia Tech)',
#  'Wentworth Institute of Technology',
#  'Worcester Polytechnic Institute (WPI)'}

# %%
set(Ivies_Dataset['School Name']).difference(State_Dataset['School Name'])
# Out:
# {'Brown University',
#  'Columbia University',
#  'Cornell University',
#  'Dartmouth College',
#  'Harvard University',
#  'Princeton University',
#  'University of Pennsylvania',
#  'Yale University'}

# %%
'Yale University' in State_Dataset['School Name'].values
# Out:
# False

# %%
df =pd.concat(dfs)

# %%
df
# Out:
#                                        School Name School Type  \
# 0               University of California, Berkeley       State
# 1                     University of Virginia (UVA)       State
# 2                         Cal Poly San Luis Obispo       State
# 3   University of California at Los Angeles (UCLA)       State
# 4       University of California, San Diego (UCSD)       State
# ..                                             ...         ...
# 3                               Harvard University  Ivy League
# 4                       University of Pennsylvania  Ivy League
# 5                               Cornell University  Ivy League
# 6                                 Brown University  Ivy League
# 7                              Columbia University  Ivy League
#
#    Starting Median Salary Mid-Career Median Salary
# 0             $59,900.00              $112,000.00
# 1             $52,700.00              $103,000.00
# 2             $57,200.00              $101,000.00
# ...

# %%
df.duplicated(subset=['School Name'])
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
#      ...
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# Length: 249, dtype: bool

# %%
df.drop_duplicates(subset = ['School Name'])
# Out:
#                                        School Name School Type  \
# 0               University of California, Berkeley       State
# 1                     University of Virginia (UVA)       State
# 2                         Cal Poly San Luis Obispo       State
# 3   University of California at Los Angeles (UCLA)       State
# 4       University of California, San Diego (UCSD)       State
# ..                                             ...         ...
# 3                               Harvard University  Ivy League
# 4                       University of Pennsylvania  Ivy League
# 5                               Cornell University  Ivy League
# 6                                 Brown University  Ivy League
# 7                              Columbia University  Ivy League
#
#    Starting Median Salary Mid-Career Median Salary
# 0             $59,900.00              $112,000.00
# 1             $52,700.00              $103,000.00
# 2             $57,200.00              $101,000.00
# ...

# %% [markdown]
# ### 150 lecture

# %%
df.loc[0]
# Out:
#                                    School Name   School Type  \
# 0           University of California, Berkeley         State
# 0  Massachusetts Institute of Technology (MIT)   Engineering
# 0                          Bucknell University  Liberal Arts
# 0                            Dartmouth College    Ivy League
#
#   Starting Median Salary Mid-Career Median Salary
# 0            $59,900.00              $112,000.00
# 0            $72,200.00              $126,000.00
# 0            $54,100.00              $110,000.00
# 0            $58,000.00              $134,000.00

# %%
df.index.duplicated()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %%
# in pandas, we could have duplicated indices

# %%
# df.loc[0:2] # does not work anymore

# %%
df.reset_index()
# Out:
#      index                                     School Name School Type  \
# 0        0              University of California, Berkeley       State
# 1        1                    University of Virginia (UVA)       State
# 2        2                        Cal Poly San Luis Obispo       State
# 3        3  University of California at Los Angeles (UCLA)       State
# 4        4      University of California, San Diego (UCSD)       State
# ..     ...                                             ...         ...
# 244      3                              Harvard University  Ivy League
# 245      4                      University of Pennsylvania  Ivy League
# 246      5                              Cornell University  Ivy League
# 247      6                                Brown University  Ivy League
# 248      7                             Columbia University  Ivy League
#
#     Starting Median Salary Mid-Career Median Salary
# 0              $59,900.00              $112,000.00
# ...

# %%
df.reset_index(drop = True, inplace = True)

# %%
df.index.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Alternative Approach : concat()

# %%
pd.concat(dfs,ignore_index=True).drop_duplicates(subset = ['School Name']).index.duplicated().sum()
# Out:
# 0

# %%
pd.concat(dfs,ignore_index=True)
# Out:
#                                         School Name School Type  \
# 0                University of California, Berkeley       State
# 1                      University of Virginia (UVA)       State
# 2                          Cal Poly San Luis Obispo       State
# 3    University of California at Los Angeles (UCLA)       State
# 4        University of California, San Diego (UCSD)       State
# ..                                              ...         ...
# 244                              Harvard University  Ivy League
# 245                      University of Pennsylvania  Ivy League
# 246                              Cornell University  Ivy League
# 247                                Brown University  Ivy League
# 248                             Columbia University  Ivy League
#
#     Starting Median Salary Mid-Career Median Salary
# 0              $59,900.00              $112,000.00
# 1              $52,700.00              $103,000.00
# ...

# %% [markdown]
# ### Lec -151 - Enforcing Unique Indices

# %%
# Previously: df.reset_index(drop = True) or pd.concat(ignore_index = True)

# Goal: What if we wanted to preserve the index and force Uniqueness

# %%
Mod_Ivies = Ivies_Dataset.set_index('School Name')

# %%
Mod_Eng = Eng_Dataset.set_index('School Name')

# %%
pd.concat([Mod_Ivies, Mod_Eng])
# Out:
#                                                     School Type  \
# School Name
# Dartmouth College                                    Ivy League
# Princeton University                                 Ivy League
# Yale University                                      Ivy League
# Harvard University                                   Ivy League
# University of Pennsylvania                           Ivy League
# Cornell University                                   Ivy League
# Brown University                                     Ivy League
# Columbia University                                  Ivy League
# Massachusetts Institute of Technology (MIT)         Engineering
# California Institute of Technology (CIT)            Engineering
# Harvey Mudd College                                 Engineering
# Polytechnic University of New York, Brooklyn        Engineering
# Cooper Union                                        Engineering
# ...

# %%
pd.concat([Mod_Ivies, Mod_Eng], verify_integrity=True)
# Out:
#                                                     School Type  \
# School Name
# Dartmouth College                                    Ivy League
# Princeton University                                 Ivy League
# Yale University                                      Ivy League
# Harvard University                                   Ivy League
# University of Pennsylvania                           Ivy League
# Cornell University                                   Ivy League
# Brown University                                     Ivy League
# Columbia University                                  Ivy League
# Massachusetts Institute of Technology (MIT)         Engineering
# California Institute of Technology (CIT)            Engineering
# Harvey Mudd College                                 Engineering
# Polytechnic University of New York, Brooklyn        Engineering
# Cooper Union                                        Engineering
# ...

# %%
sel_Ivies = Mod_Ivies.sample()

# %%
pd.concat([Mod_Ivies, sel_Ivies], verify_integrity=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 pd.concat([Mod_Ivies, sel_Ivies], verify_integrity=True)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:372, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     369 elif copy and using_copy_on_write():
#     370     copy = False
# --> 372 op = _Concatenator(
#     373     objs,
#     374     axis=axis,
#     375     ignore_index=ignore_index,
#     376     join=join,
#     377     keys=keys,
#     378     levels=levels,
#     379     names=names,
#     380     verify_integrity=verify_integrity,
#     381     copy=copy,
#     382     sort=sort,
#     383 )
#     385 return op.get_result()
#
# ...

# %% [markdown]
# ### Lecture - 152 - Creating Multiple Indices With Concat()

# %%
#pd.concat([Eng_Dataset, Ivies_Dataset], keys= ['EngData', 'IviData'])

# %%
pd.concat([Eng_Dataset, Ivies_Dataset], keys= ['EngData', 'IviData'])
# Out:
#                                                   School Name  School Type  \
# EngData 0         Massachusetts Institute of Technology (MIT)  Engineering
#         1            California Institute of Technology (CIT)  Engineering
#         2                                 Harvey Mudd College  Engineering
#         3        Polytechnic University of New York, Brooklyn  Engineering
#         4                                        Cooper Union  Engineering
#         5               Worcester Polytechnic Institute (WPI)  Engineering
#         6                    Carnegie Mellon University (CMU)  Engineering
#         7              Rensselaer Polytechnic Institute (RPI)  Engineering
#         8                     Georgia Institute of Technology  Engineering
#         9                            Colorado School of Mines  Engineering
#         10                    Stevens Institute of Technology  Engineering
# ...

# %% [markdown]
# ### Lecture - 153 - Column Axis Concatenation

# %%
Ivies_Dataset
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
# 5          Cornell University  Ivy League            $60,300.00
# 6            Brown University  Ivy League            $56,200.00
# 7         Columbia University  Ivy League            $59,400.00
#
#   Mid-Career Median Salary
# 0             $134,000.00
# 1             $131,000.00
# 2             $126,000.00
# 3             $124,000.00
# 4             $120,000.00
# 5             $110,000.00
# 6             $109,000.00
# 7             $107,000.00

# %%
Eng_Dataset
# Out:
#                                           School Name  School Type  \
# 0         Massachusetts Institute of Technology (MIT)  Engineering
# 1            California Institute of Technology (CIT)  Engineering
# 2                                 Harvey Mudd College  Engineering
# 3        Polytechnic University of New York, Brooklyn  Engineering
# 4                                        Cooper Union  Engineering
# 5               Worcester Polytechnic Institute (WPI)  Engineering
# 6                    Carnegie Mellon University (CMU)  Engineering
# 7              Rensselaer Polytechnic Institute (RPI)  Engineering
# 8                     Georgia Institute of Technology  Engineering
# 9                            Colorado School of Mines  Engineering
# 10                    Stevens Institute of Technology  Engineering
# 11             Illinois Institute of Technology (IIT)  Engineering
# 12                  Wentworth Institute of Technology  Engineering
# ...

# %%
Eng_1 = Eng_Dataset.sort_values(by = 'Starting Median Salary', ascending=False).reset_index(drop = True)

# %%
Ivies_1 = Ivies_Dataset.sort_values(by = 'Starting Median Salary', ascending=False).reset_index(drop = True)

# %%
Ivies_1
# Out:
#                   School Name School Type Starting Median Salary  \
# 0        Princeton University  Ivy League            $66,500.00
# 1          Harvard University  Ivy League            $63,400.00
# 2  University of Pennsylvania  Ivy League            $60,900.00
# 3          Cornell University  Ivy League            $60,300.00
# 4         Columbia University  Ivy League            $59,400.00
# 5             Yale University  Ivy League            $59,100.00
# 6           Dartmouth College  Ivy League            $58,000.00
# 7            Brown University  Ivy League            $56,200.00
#
#   Mid-Career Median Salary
# 0             $131,000.00
# 1             $124,000.00
# 2             $120,000.00
# 3             $110,000.00
# 4             $107,000.00
# 5             $126,000.00
# 6             $134,000.00
# 7             $109,000.00

# %%
#pd.concat([Eng_1, Ivies_1], axis = 1)

# %%
pd.concat([Eng_1, Ivies_1], axis = 1)
# Out:
#                                           School Name  School Type  \
# 0            California Institute of Technology (CIT)  Engineering
# 1         Massachusetts Institute of Technology (MIT)  Engineering
# 2                                 Harvey Mudd College  Engineering
# 3        Polytechnic University of New York, Brooklyn  Engineering
# 4                                        Cooper Union  Engineering
# 5                    Carnegie Mellon University (CMU)  Engineering
# 6              Rensselaer Polytechnic Institute (RPI)  Engineering
# 7               Worcester Polytechnic Institute (WPI)  Engineering
# 8                     Stevens Institute of Technology  Engineering
# 9                     Georgia Institute of Technology  Engineering
# 10                           Colorado School of Mines  Engineering
# 11             Illinois Institute of Technology (IIT)  Engineering
# 12          South Dakota School of Mines & Technology  Engineering
# ...

# %% [markdown]
# ### Lecture - 154 - The append() Method: A Special Case of concat()

# %%
State_Dataset
# Out:
#                                         School Name School Type  \
# 0                University of California, Berkeley       State
# 1                      University of Virginia (UVA)       State
# 2                          Cal Poly San Luis Obispo       State
# 3    University of California at Los Angeles (UCLA)       State
# 4        University of California, San Diego (UCSD)       State
# ..                                              ...         ...
# 170                    Austin Peay State University       State
# 171                      Pittsburg State University       State
# 172                        Southern Utah University       State
# 173             Montana State University - Billings       State
# 174                    Black Hills State University       State
#
#     Starting Median Salary Mid-Career Median Salary
# 0              $59,900.00              $112,000.00
# 1              $52,700.00              $103,000.00
# ...

# %%
Liberal_Dataset
# Out:
#                                       School Name   School Type  \
# 0                             Bucknell University  Liberal Arts
# 1                              Colgate University  Liberal Arts
# 2                                 Amherst College  Liberal Arts
# 3                               Lafayette College  Liberal Arts
# 4                                 Bowdoin College  Liberal Arts
# 5                       College of the Holy Cross  Liberal Arts
# 6                              Occidental College  Liberal Arts
# 7                   Washington and Lee University  Liberal Arts
# 8                              Swarthmore College  Liberal Arts
# 9                                Davidson College  Liberal Arts
# 10                               Carleton College  Liberal Arts
# 11                               Williams College  Liberal Arts
# 12                                 Pomona College  Liberal Arts
# 13  Wesleyan University (Middletown, Connecticut)  Liberal Arts
# ...

# %%
Liberal_Dataset.append(State_Dataset)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22268\507234321.py in ?()
# ----> 1 Liberal_Dataset.append(State_Dataset)
#
# c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
### For more information about the Difference between Apppend and concat, follow the Documentation

# %% [markdown]
# ### Lecture - 155 Concat On Different Columns

# %%
Eng_Demo = Eng_Dataset.copy()

# %%
Eng_Demo
# Out:
#                                           School Name  School Type  \
# 0         Massachusetts Institute of Technology (MIT)  Engineering
# 1            California Institute of Technology (CIT)  Engineering
# 2                                 Harvey Mudd College  Engineering
# 3        Polytechnic University of New York, Brooklyn  Engineering
# 4                                        Cooper Union  Engineering
# 5               Worcester Polytechnic Institute (WPI)  Engineering
# 6                    Carnegie Mellon University (CMU)  Engineering
# 7              Rensselaer Polytechnic Institute (RPI)  Engineering
# 8                     Georgia Institute of Technology  Engineering
# 9                            Colorado School of Mines  Engineering
# 10                    Stevens Institute of Technology  Engineering
# 11             Illinois Institute of Technology (IIT)  Engineering
# 12                  Wentworth Institute of Technology  Engineering
# ...

# %%
Eng_Demo['STEM'] = True

# %%
Ivies_Dataset
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
# 5          Cornell University  Ivy League            $60,300.00
# 6            Brown University  Ivy League            $56,200.00
# 7         Columbia University  Ivy League            $59,400.00
#
#   Mid-Career Median Salary
# 0             $134,000.00
# 1             $131,000.00
# 2             $126,000.00
# 3             $124,000.00
# 4             $120,000.00
# 5             $110,000.00
# 6             $109,000.00
# 7             $107,000.00

# %% [markdown]
#     The pd.concat function in Python's pandas library is used to concatenate DataFrames along a particular axis, which can be either rows or columns. The join parameter specifies how to handle overlapping column names in the concatenated DataFrames. When you set join='inner', it means that only the columns that exist in both DataFrames will be included in the result.

# %%
pd.concat([Eng_Demo, Ivies_Dataset], join= 'inner', ignore_index=True)
# Out:
#                                           School Name  School Type  \
# 0         Massachusetts Institute of Technology (MIT)  Engineering
# 1            California Institute of Technology (CIT)  Engineering
# 2                                 Harvey Mudd College  Engineering
# 3        Polytechnic University of New York, Brooklyn  Engineering
# 4                                        Cooper Union  Engineering
# 5               Worcester Polytechnic Institute (WPI)  Engineering
# 6                    Carnegie Mellon University (CMU)  Engineering
# 7              Rensselaer Polytechnic Institute (RPI)  Engineering
# 8                     Georgia Institute of Technology  Engineering
# 9                            Colorado School of Mines  Engineering
# 10                    Stevens Institute of Technology  Engineering
# 11             Illinois Institute of Technology (IIT)  Engineering
# 12                  Wentworth Institute of Technology  Engineering
# ...

# %%
pd.concat([Eng_Demo, Ivies_Dataset], join= 'inner')
# Out:
#                                           School Name  School Type  \
# 0         Massachusetts Institute of Technology (MIT)  Engineering
# 1            California Institute of Technology (CIT)  Engineering
# 2                                 Harvey Mudd College  Engineering
# 3        Polytechnic University of New York, Brooklyn  Engineering
# 4                                        Cooper Union  Engineering
# 5               Worcester Polytechnic Institute (WPI)  Engineering
# 6                    Carnegie Mellon University (CMU)  Engineering
# 7              Rensselaer Polytechnic Institute (RPI)  Engineering
# 8                     Georgia Institute of Technology  Engineering
# 9                            Colorado School of Mines  Engineering
# 10                    Stevens Institute of Technology  Engineering
# 11             Illinois Institute of Technology (IIT)  Engineering
# 12                  Wentworth Institute of Technology  Engineering
# ...

# %%
pd.concat([Eng_Demo, Ivies_Dataset])
# Out:
#                                           School Name  School Type  \
# 0         Massachusetts Institute of Technology (MIT)  Engineering
# 1            California Institute of Technology (CIT)  Engineering
# 2                                 Harvey Mudd College  Engineering
# 3        Polytechnic University of New York, Brooklyn  Engineering
# 4                                        Cooper Union  Engineering
# 5               Worcester Polytechnic Institute (WPI)  Engineering
# 6                    Carnegie Mellon University (CMU)  Engineering
# 7              Rensselaer Polytechnic Institute (RPI)  Engineering
# 8                     Georgia Institute of Technology  Engineering
# 9                            Colorado School of Mines  Engineering
# 10                    Stevens Institute of Technology  Engineering
# 11             Illinois Institute of Technology (IIT)  Engineering
# 12                  Wentworth Institute of Technology  Engineering
# ...

# %% [markdown]
# ### Lecture 156 and 157 problem and Solution

# %% [markdown]
# ### Lecture 158 - Merge Method

# %%
regions = pd.read_csv("D:\\karan data\\Data for Preprocessing\\regions.csv")
regions
# Out:
#                                       School Name        Region
# 0     Massachusetts Institute of Technology (MIT)  Northeastern
# 1        California Institute of Technology (CIT)    California
# 2                             Harvey Mudd College    California
# 3    Polytechnic University of New York, Brooklyn  Northeastern
# 4                                    Cooper Union  Northeastern
# ..                                            ...           ...
# 264                  Austin Peay State University      Southern
# 265                    Pittsburg State University    Midwestern
# 266                      Southern Utah University       Western
# 267           Montana State University - Billings       Western
# 268                  Black Hills State University    Midwestern
#
# [269 rows x 2 columns]

# %%
regions['School Name'].nunique()
# Out:
# 249

# %%
regions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   School Name  269 non-null    object
#  1   Region       269 non-null    object
# dtypes: object(2)
# memory usage: 4.3+ KB

# %%
regions[regions.duplicated(subset = 'School Name', keep = 'first')]
# Out:
#                                            School Name        Region
# 67                              Randolph-Macon College      Southern
# 102  University of Illinois at Urbana-Champaign (UIUC)    Midwestern
# 107               University of Maryland, College Park      Southern
# 108     University of California, Santa Barbara (UCSB)    California
# 109                  University of Texas (UT) - Austin      Southern
# 112      State University of New York (SUNY) at Albany  Northeastern
# 118                         University of Florida (UF)      Southern
# 120                   Louisiana State University (LSU)      Southern
# 127                        University of Georgia (UGA)      Southern
# 128                Pennsylvania State University (PSU)  Northeastern
# 142                     Arizona State University (ASU)       Western
# 144               Indiana University (IU), Bloomington    Midwestern
# 145                            University of Iowa (UI)    Midwestern
# ...

# %%
regions[regions.duplicated(subset = 'School Name', keep = 'first')].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 67 to 214
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   School Name  20 non-null     object
#  1   Region       20 non-null     object
# dtypes: object(2)
# memory usage: 480.0+ bytes

# %%
df
# Out:
#                                         School Name School Type  \
# 0                University of California, Berkeley       State
# 1                      University of Virginia (UVA)       State
# 2                          Cal Poly San Luis Obispo       State
# 3    University of California at Los Angeles (UCLA)       State
# 4        University of California, San Diego (UCSD)       State
# ..                                              ...         ...
# 244                              Harvard University  Ivy League
# 245                      University of Pennsylvania  Ivy League
# 246                              Cornell University  Ivy League
# 247                                Brown University  Ivy League
# 248                             Columbia University  Ivy League
#
#     Starting Median Salary Mid-Career Median Salary
# 0              $59,900.00              $112,000.00
# 1              $52,700.00              $103,000.00
# ...

# %%
pd.merge(df, regions, on = 'School Name').isnull().sum().sum()
# Out:
# 0

# %%
pd.merge(df, regions, on = 'School Name')
# Out:
#                                         School Name School Type  \
# 0                University of California, Berkeley       State
# 1                      University of Virginia (UVA)       State
# 2                          Cal Poly San Luis Obispo       State
# 3    University of California at Los Angeles (UCLA)       State
# 4        University of California, San Diego (UCSD)       State
# ..                                              ...         ...
# 264                              Harvard University  Ivy League
# 265                      University of Pennsylvania  Ivy League
# 266                              Cornell University  Ivy League
# 267                                Brown University  Ivy League
# 268                             Columbia University  Ivy League
#
#     Starting Median Salary Mid-Career Median Salary        Region
# 0              $59,900.00              $112,000.00     California
# ...

# %%
Mid_Career =pd.read_csv("D:\karan data\Data for Preprocessing\mid_career_salaries.csv")

# %% [markdown]
# ### Lecture - 159 - The left_on and right_on Params

# %%
Mid_Career
# Out:
#                                       school_name  \
# 0     Massachusetts Institute of Technology (MIT)
# 1        California Institute of Technology (CIT)
# 2                             Harvey Mudd College
# 3    Polytechnic University of New York, Brooklyn
# 4                                    Cooper Union
# ..                                            ...
# 264                  Austin Peay State University
# 265                    Pittsburg State University
# 266                      Southern Utah University
# 267           Montana State University - Billings
# 268                  Black Hills State University
#
#     Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                         $76,800.00                        $99,200.00
# 1                                 NaN                      $104,000.00
# 2                                 NaN                       $96,000.00
# 3                         $66,800.00                        $94,300.00
# ...

# %%
df
# Out:
#                                         School Name School Type  \
# 0                University of California, Berkeley       State
# 1                      University of Virginia (UVA)       State
# 2                          Cal Poly San Luis Obispo       State
# 3    University of California at Los Angeles (UCLA)       State
# 4        University of California, San Diego (UCSD)       State
# ..                                              ...         ...
# 244                              Harvard University  Ivy League
# 245                      University of Pennsylvania  Ivy League
# 246                              Cornell University  Ivy League
# 247                                Brown University  Ivy League
# 248                             Columbia University  Ivy League
#
#     Starting Median Salary Mid-Career Median Salary
# 0              $59,900.00              $112,000.00
# 1              $52,700.00              $103,000.00
# ...

# %%
#merged_Data = pd.merge(df, Mid_Career, left_on= 'School Name', right_on= 'school_name')

# %%
merged_Data = pd.merge(df, Mid_Career, left_on= 'School Name', right_on= 'school_name')
merged_Data
# Out:
#                                         School Name School Type  \
# 0                University of California, Berkeley       State
# 1                      University of Virginia (UVA)       State
# 2                          Cal Poly San Luis Obispo       State
# 3    University of California at Los Angeles (UCLA)       State
# 4        University of California, San Diego (UCSD)       State
# ..                                              ...         ...
# 264                              Harvard University  Ivy League
# 265                      University of Pennsylvania  Ivy League
# 266                              Cornell University  Ivy League
# 267                                Brown University  Ivy League
# 268                             Columbia University  Ivy League
#
#     Starting Median Salary Mid-Career Median Salary  \
# 0              $59,900.00              $112,000.00
# 1              $52,700.00              $103,000.00
# ...

# %%
for i, column in enumerate(merged_Data.columns):
    n_miss = merged_Data[column].isnull().sum()
    perc = (n_miss / merged_Data.shape[0]) * 100
    print(f'> {i}, Missing: {n_miss} ({perc:.1f}%)')
# Out:
# > 0, Missing: 0 (0.0%)
# > 1, Missing: 0 (0.0%)
# > 2, Missing: 0 (0.0%)
# > 3, Missing: 0 (0.0%)
# > 4, Missing: 0 (0.0%)
# > 5, Missing: 38 (14.1%)
# > 6, Missing: 0 (0.0%)
# > 7, Missing: 0 (0.0%)
# > 8, Missing: 38 (14.1%)

# %%
merged_Data.iloc[:,8].values
# Out:
# array(['$201,000.00 ', '$215,000.00 ', '$178,000.00 ', '$193,000.00 ',
#        '$177,000.00 ', '$202,000.00 ', '$187,000.00 ', '$172,000.00 ',
#        '$177,000.00 ', '$177,000.00 ', '$171,000.00 ', '$201,000.00 ',
#        '$166,000.00 ', '$156,000.00 ', '$166,000.00 ', '$166,000.00 ',
#        '$173,000.00 ', '$173,000.00 ', '$188,000.00 ', '$188,000.00 ',
#        '$182,000.00 ', '$181,000.00 ', '$209,000.00 ', '$209,000.00 ',
#        '$176,000.00 ', '$168,000.00 ', '$162,000.00 ', '$168,000.00 ',
#        '$154,000.00 ', '$172,000.00 ', '$172,000.00 ', '$170,000.00 ',
#        '$165,000.00 ', '$165,000.00 ', '$158,000.00 ', '$150,000.00 ',
#        '$158,000.00 ', '$150,000.00 ', '$160,000.00 ', '$150,000.00 ',
#        '$164,000.00 ', '$164,000.00 ', '$160,000.00 ', '$160,000.00 ',
#        '$149,000.00 ', '$170,000.00 ', '$157,000.00 ', '$158,000.00 ',
#        '$145,000.00 ', '$162,000.00 ', '$154,000.00 ', '$147,000.00 ',
# ...

# %%
merged_Data.iloc[:,8]
# Out:
# 0      $201,000.00
# 1      $215,000.00
# 2      $178,000.00
# 3      $193,000.00
# 4      $177,000.00
#            ...
# 264    $288,000.00
# 265    $282,000.00
# 266    $210,000.00
# 267    $228,000.00
# 268    $241,000.00
# Name: Mid-Career 90th Percentile Salary, Length: 269, dtype: object

# %%
df['School Name'].nunique()
# Out:
# 249

# %%
Mid_Career['school_name'].nunique()
# Out:
# 249

# %%
import numpy as np

# %%
merged_Data.head(2)
# Out:
#                           School Name School Type Starting Median Salary  \
# 0  University of California, Berkeley       State            $59,900.00
# 1        University of Virginia (UVA)       State            $52,700.00
#
#   Mid-Career Median Salary                         school_name  \
# 0             $112,000.00   University of California, Berkeley
# 1             $103,000.00         University of Virginia (UVA)
#
#   Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                       $59,500.00                        $81,000.00
# 1                       $52,200.00                        $71,800.00
#
#   Mid-Career 75th Percentile Salary Mid-Career 90th Percentile Salary
# 0                      $149,000.00                       $201,000.00
# 1                      $146,000.00                       $215,000.00

# %%
merged_Data['Category'] = merged_Data.apply(lambda x : 'yes' if x['School Name'] == x['school_name'] else 'no', axis=1)

# %%
merged_Data
# Out:
#                                         School Name School Type  \
# 0                University of California, Berkeley       State
# 1                      University of Virginia (UVA)       State
# 2                          Cal Poly San Luis Obispo       State
# 3    University of California at Los Angeles (UCLA)       State
# 4        University of California, San Diego (UCSD)       State
# ..                                              ...         ...
# 264                              Harvard University  Ivy League
# 265                      University of Pennsylvania  Ivy League
# 266                              Cornell University  Ivy League
# 267                                Brown University  Ivy League
# 268                             Columbia University  Ivy League
#
#     Starting Median Salary Mid-Career Median Salary  \
# 0              $59,900.00              $112,000.00
# 1              $52,700.00              $103,000.00
# ...

# %%
merged_Data['Comparsion'] = np.where(merged_Data['School Name'] == merged_Data['school_name'], 'yes', 'no')

# %%
merged_Data[merged_Data.Comparsion == "yes"]
# Out:
#                                         School Name School Type  \
# 0                University of California, Berkeley       State
# 1                      University of Virginia (UVA)       State
# 2                          Cal Poly San Luis Obispo       State
# 3    University of California at Los Angeles (UCLA)       State
# 4        University of California, San Diego (UCSD)       State
# ..                                              ...         ...
# 264                              Harvard University  Ivy League
# 265                      University of Pennsylvania  Ivy League
# 266                              Cornell University  Ivy League
# 267                                Brown University  Ivy League
# 268                             Columbia University  Ivy League
#
#     Starting Median Salary Mid-Career Median Salary  \
# 0              $59,900.00              $112,000.00
# 1              $52,700.00              $103,000.00
# ...

# %%
df
# Out:
#                                         School Name School Type  \
# 0                University of California, Berkeley       State
# 1                      University of Virginia (UVA)       State
# 2                          Cal Poly San Luis Obispo       State
# 3    University of California at Los Angeles (UCLA)       State
# 4        University of California, San Diego (UCSD)       State
# ..                                              ...         ...
# 244                              Harvard University  Ivy League
# 245                      University of Pennsylvania  Ivy League
# 246                              Cornell University  Ivy League
# 247                                Brown University  Ivy League
# 248                             Columbia University  Ivy League
#
#     Starting Median Salary Mid-Career Median Salary
# 0              $59,900.00              $112,000.00
# 1              $52,700.00              $103,000.00
# ...

# %%
Mid_Career
# Out:
#                                       school_name  \
# 0     Massachusetts Institute of Technology (MIT)
# 1        California Institute of Technology (CIT)
# 2                             Harvey Mudd College
# 3    Polytechnic University of New York, Brooklyn
# 4                                    Cooper Union
# ..                                            ...
# 264                  Austin Peay State University
# 265                    Pittsburg State University
# 266                      Southern Utah University
# 267           Montana State University - Billings
# 268                  Black Hills State University
#
#     Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                         $76,800.00                        $99,200.00
# 1                                 NaN                      $104,000.00
# 2                                 NaN                       $96,000.00
# 3                         $66,800.00                        $94,300.00
# ...

# %%
merged_Data
# Out:
#                                         School Name School Type  \
# 0                University of California, Berkeley       State
# 1                      University of Virginia (UVA)       State
# 2                          Cal Poly San Luis Obispo       State
# 3    University of California at Los Angeles (UCLA)       State
# 4        University of California, San Diego (UCSD)       State
# ..                                              ...         ...
# 264                              Harvard University  Ivy League
# 265                      University of Pennsylvania  Ivy League
# 266                              Cornell University  Ivy League
# 267                                Brown University  Ivy League
# 268                             Columbia University  Ivy League
#
#     Starting Median Salary Mid-Career Median Salary  \
# 0              $59,900.00              $112,000.00
# 1              $52,700.00              $103,000.00
# ...

# %% [markdown]
# ### Lecture 160 Inner vs Outer Joins

# %%
regions
# Out:
#                                       School Name        Region
# 0     Massachusetts Institute of Technology (MIT)  Northeastern
# 1        California Institute of Technology (CIT)    California
# 2                             Harvey Mudd College    California
# 3    Polytechnic University of New York, Brooklyn  Northeastern
# 4                                    Cooper Union  Northeastern
# ..                                            ...           ...
# 264                  Austin Peay State University      Southern
# 265                    Pittsburg State University    Midwestern
# 266                      Southern Utah University       Western
# 267           Montana State University - Billings       Western
# 268                  Black Hills State University    Midwestern
#
# [269 rows x 2 columns]

# %%
Ivies_Dataset
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
# 5          Cornell University  Ivy League            $60,300.00
# 6            Brown University  Ivy League            $56,200.00
# 7         Columbia University  Ivy League            $59,400.00
#
#   Mid-Career Median Salary
# 0             $134,000.00
# 1             $131,000.00
# 2             $126,000.00
# 3             $124,000.00
# 4             $120,000.00
# 5             $110,000.00
# 6             $109,000.00
# 7             $107,000.00

# %%
pd.merge(Ivies_Dataset, regions)
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
# 5          Cornell University  Ivy League            $60,300.00
# 6            Brown University  Ivy League            $56,200.00
# 7         Columbia University  Ivy League            $59,400.00
#
#   Mid-Career Median Salary        Region
# 0             $134,000.00   Northeastern
# 1             $131,000.00   Northeastern
# 2             $126,000.00   Northeastern
# 3             $124,000.00   Northeastern
# 4             $120,000.00   Northeastern
# 5             $110,000.00   Northeastern
# 6             $109,000.00   Northeastern
# 7             $107,000.00   Northeastern

# %%
pd.merge(regions, Ivies_Dataset, how= 'outer')
# Out:
#                                       School Name        Region School Type  \
# 0     Massachusetts Institute of Technology (MIT)  Northeastern         NaN
# 1        California Institute of Technology (CIT)    California         NaN
# 2                             Harvey Mudd College    California         NaN
# 3    Polytechnic University of New York, Brooklyn  Northeastern         NaN
# 4                                    Cooper Union  Northeastern         NaN
# ..                                            ...           ...         ...
# 264                  Austin Peay State University      Southern         NaN
# 265                    Pittsburg State University    Midwestern         NaN
# 266                      Southern Utah University       Western         NaN
# 267           Montana State University - Billings       Western         NaN
# 268                  Black Hills State University    Midwestern         NaN
#
#     Starting Median Salary Mid-Career Median Salary
# ...

# %%
pd.merge(Ivies_Dataset,regions, how= 'outer')
# Out:
#                              School Name School Type Starting Median Salary  \
# 0                      Dartmouth College  Ivy League            $58,000.00
# 1                   Princeton University  Ivy League            $66,500.00
# 2                        Yale University  Ivy League            $59,100.00
# 3                     Harvard University  Ivy League            $63,400.00
# 4             University of Pennsylvania  Ivy League            $60,900.00
# ..                                   ...         ...                    ...
# 264         Austin Peay State University         NaN                    NaN
# 265           Pittsburg State University         NaN                    NaN
# 266             Southern Utah University         NaN                    NaN
# 267  Montana State University - Billings         NaN                    NaN
# 268         Black Hills State University         NaN                    NaN
#
#     Mid-Career Median Salary        Region
# ...

# %% [markdown]
# ### Lecture - 161 - Left vs Right Joins

# %%
regions.head()
# Out:
#                                     School Name        Region
# 0   Massachusetts Institute of Technology (MIT)  Northeastern
# 1      California Institute of Technology (CIT)    California
# 2                           Harvey Mudd College    California
# 3  Polytechnic University of New York, Brooklyn  Northeastern
# 4                                  Cooper Union  Northeastern

# %%
pd.merge(Ivies_Dataset,regions, how= 'left')
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
# 5          Cornell University  Ivy League            $60,300.00
# 6            Brown University  Ivy League            $56,200.00
# 7         Columbia University  Ivy League            $59,400.00
#
#   Mid-Career Median Salary        Region
# 0             $134,000.00   Northeastern
# 1             $131,000.00   Northeastern
# 2             $126,000.00   Northeastern
# 3             $124,000.00   Northeastern
# 4             $120,000.00   Northeastern
# 5             $110,000.00   Northeastern
# 6             $109,000.00   Northeastern
# 7             $107,000.00   Northeastern

# %%
Ivies_Dataset.merge(regions, how= 'inner', on = 'School Name', suffixes=[" -Ivies_Dataset", " -regions"])
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
# 5          Cornell University  Ivy League            $60,300.00
# 6            Brown University  Ivy League            $56,200.00
# 7         Columbia University  Ivy League            $59,400.00
#
#   Mid-Career Median Salary        Region
# 0             $134,000.00   Northeastern
# 1             $131,000.00   Northeastern
# 2             $126,000.00   Northeastern
# 3             $124,000.00   Northeastern
# 4             $120,000.00   Northeastern
# 5             $110,000.00   Northeastern
# 6             $109,000.00   Northeastern
# 7             $107,000.00   Northeastern

# %%
pd.merge(Ivies_Dataset,regions, how= 'inner', on = 'School Name', suffixes
# Out:
#   Cell In[199], line 1
#     pd.merge(Ivies_Dataset,regions, how= 'inner', on = 'School Name', suffixes
#                                                                               ^
# SyntaxError: incomplete input

# %%
pd.merge(Ivies_Dataset,regions, how= 'right')
# Out:
#                                       School Name School Type  \
# 0     Massachusetts Institute of Technology (MIT)         NaN
# 1        California Institute of Technology (CIT)         NaN
# 2                             Harvey Mudd College         NaN
# 3    Polytechnic University of New York, Brooklyn         NaN
# 4                                    Cooper Union         NaN
# ..                                            ...         ...
# 264                  Austin Peay State University         NaN
# 265                    Pittsburg State University         NaN
# 266                      Southern Utah University         NaN
# 267           Montana State University - Billings         NaN
# 268                  Black Hills State University         NaN
#
#     Starting Median Salary Mid-Career Median Salary        Region
# 0                      NaN                      NaN  Northeastern
# 1                      NaN                      NaN    California
# ...

# %%
# series1.isin(series2)
regions['School Name'].isin(Ivies_Dataset['School Name'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 264    False
# 265    False
# 266    False
# 267    False
# 268    False
# Name: School Name, Length: 269, dtype: bool

# %%
regions[regions['School Name'].isin(Ivies_Dataset['School Name'])]
# Out:
#                    School Name        Region
# 86           Dartmouth College  Northeastern
# 87        Princeton University  Northeastern
# 88             Yale University  Northeastern
# 89          Harvard University  Northeastern
# 90  University of Pennsylvania  Northeastern
# 91          Cornell University  Northeastern
# 92            Brown University  Northeastern
# 93         Columbia University  Northeastern

# %%
regions
# Out:
#                                       School Name        Region
# 0     Massachusetts Institute of Technology (MIT)  Northeastern
# 1        California Institute of Technology (CIT)    California
# 2                             Harvey Mudd College    California
# 3    Polytechnic University of New York, Brooklyn  Northeastern
# 4                                    Cooper Union  Northeastern
# ..                                            ...           ...
# 264                  Austin Peay State University      Southern
# 265                    Pittsburg State University    Midwestern
# 266                      Southern Utah University       Western
# 267           Montana State University - Billings       Western
# 268                  Black Hills State University    Midwestern
#
# [269 rows x 2 columns]

# %%
Regions_Support = regions.set_index('School Name')

# %%
Ivies_Dataset
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
# 5          Cornell University  Ivy League            $60,300.00
# 6            Brown University  Ivy League            $56,200.00
# 7         Columbia University  Ivy League            $59,400.00
#
#   Mid-Career Median Salary
# 0             $134,000.00
# 1             $131,000.00
# 2             $126,000.00
# 3             $124,000.00
# 4             $120,000.00
# 5             $110,000.00
# 6             $109,000.00
# 7             $107,000.00

# %%
pd.merge(Regions_Support, Ivies_1, left_index= True, right_on='School Name')
# Out:
#          Region                 School Name School Type  \
# 6  Northeastern           Dartmouth College  Ivy League
# 0  Northeastern        Princeton University  Ivy League
# 5  Northeastern             Yale University  Ivy League
# 1  Northeastern          Harvard University  Ivy League
# 2  Northeastern  University of Pennsylvania  Ivy League
# 3  Northeastern          Cornell University  Ivy League
# 7  Northeastern            Brown University  Ivy League
# 4  Northeastern         Columbia University  Ivy League
#
#   Starting Median Salary Mid-Career Median Salary
# 6            $58,000.00              $134,000.00
# 0            $66,500.00              $131,000.00
# 5            $59,100.00              $126,000.00
# 1            $63,400.00              $124,000.00
# 2            $60,900.00              $120,000.00
# 3            $60,300.00              $110,000.00
# 7            $56,200.00              $109,000.00
# 4            $59,400.00              $107,000.00

# %%
pd.merge(Regions_Support, Ivies_1, left_index= True, right_on='School Name')
# Out:
#          Region                 School Name School Type  \
# 6  Northeastern           Dartmouth College  Ivy League
# 0  Northeastern        Princeton University  Ivy League
# 5  Northeastern             Yale University  Ivy League
# 1  Northeastern          Harvard University  Ivy League
# 2  Northeastern  University of Pennsylvania  Ivy League
# 3  Northeastern          Cornell University  Ivy League
# 7  Northeastern            Brown University  Ivy League
# 4  Northeastern         Columbia University  Ivy League
#
#   Starting Median Salary Mid-Career Median Salary
# 6            $58,000.00              $134,000.00
# 0            $66,500.00              $131,000.00
# 5            $59,100.00              $126,000.00
# 1            $63,400.00              $124,000.00
# 2            $60,900.00              $120,000.00
# 3            $60,300.00              $110,000.00
# 7            $56,200.00              $109,000.00
# 4            $59,400.00              $107,000.00

# %% [markdown]
# ### Lecture - 165 - Join Method

# %% [markdown]
# ### Lecture - 167 & 168 - Problems and Solution

# %%
Eng_Demo.merge(Ivies_Dataset, how= 'outer', on = 'School Name', suffixes=[" -ID", " -R"])
# Out:
#                                           School Name School Type -ID  \
# 0         Massachusetts Institute of Technology (MIT)     Engineering
# 1            California Institute of Technology (CIT)     Engineering
# 2                                 Harvey Mudd College     Engineering
# 3        Polytechnic University of New York, Brooklyn     Engineering
# 4                                        Cooper Union     Engineering
# 5               Worcester Polytechnic Institute (WPI)     Engineering
# 6                    Carnegie Mellon University (CMU)     Engineering
# 7              Rensselaer Polytechnic Institute (RPI)     Engineering
# 8                     Georgia Institute of Technology     Engineering
# 9                            Colorado School of Mines     Engineering
# 10                    Stevens Institute of Technology     Engineering
# 11             Illinois Institute of Technology (IIT)     Engineering
# ...

# %%
pd.concat([Eng_Demo, Ivies_Dataset])
# Out:
#                                           School Name  School Type  \
# 0         Massachusetts Institute of Technology (MIT)  Engineering
# 1            California Institute of Technology (CIT)  Engineering
# 2                                 Harvey Mudd College  Engineering
# 3        Polytechnic University of New York, Brooklyn  Engineering
# 4                                        Cooper Union  Engineering
# 5               Worcester Polytechnic Institute (WPI)  Engineering
# 6                    Carnegie Mellon University (CMU)  Engineering
# 7              Rensselaer Polytechnic Institute (RPI)  Engineering
# 8                     Georgia Institute of Technology  Engineering
# 9                            Colorado School of Mines  Engineering
# 10                    Stevens Institute of Technology  Engineering
# 11             Illinois Institute of Technology (IIT)  Engineering
# 12                  Wentworth Institute of Technology  Engineering
# ...
