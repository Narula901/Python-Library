# %% [markdown]
# ### Lecture - 217 - New Data: New York City SAT Scores

# %%
import pandas as pd

# %%
sat = pd.read_csv('D:\karan data\Data for Preprocessing\scores.csv')

# %%
sat
# Out:
#             date                                 School Name    Borough  \
# 0     01-01-2023       A. Philip Randolph Campus High School  Manhattan
# 1     02-01-2023       A. Philip Randolph Campus High School  Manhattan
# 2     03-01-2023       A. Philip Randolph Campus High School  Manhattan
# 3     04-01-2023                 Abraham Lincoln High School   Brooklyn
# 4     05-01-2023                 Abraham Lincoln High School   Brooklyn
# ...          ...                                         ...        ...
# 1120  25-01-2026  Young Women's Leadership School in Astoria     Queens
# 1121  26-01-2026  Young Women's Leadership School in Astoria     Queens
# 1122  27-01-2026   Young Women's Leadership School in Queens     Queens
# 1123  28-01-2026   Young Women's Leadership School in Queens     Queens
# 1124  29-01-2026   Young Women's Leadership School in Queens     Queens
#
#       Student Enrollment Percent Tested SAT Section  Score  Unnamed: 7
# ...

# %%
sat['Percent Tested'] = sat['Percent Tested'].replace(regex='%', value='').astype('float')

# %%
sat.head(3)
# Out:
#          date                            School Name    Borough  \
# 0  01-01-2023  A. Philip Randolph Campus High School  Manhattan
# 1  02-01-2023  A. Philip Randolph Campus High School  Manhattan
# 2  03-01-2023  A. Philip Randolph Campus High School  Manhattan
#
#    Student Enrollment  Percent Tested SAT Section  Score  Unnamed: 7
# 0                1354            74.0        Math    459         NaN
# 1                1354            74.0     Reading    453         NaN
# 2                1354            74.0     Writing    447         NaN

# %%
sat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1125 entries, 0 to 1124
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                1125 non-null   object
#  1   School Name         1125 non-null   object
#  2   Borough             1125 non-null   object
#  3   Student Enrollment  1125 non-null   int64
#  4   Percent Tested      1125 non-null   float64
#  5   SAT Section         1125 non-null   object
#  6   Score               1125 non-null   int64
#  7   Unnamed: 7          0 non-null      float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 70.4+ KB

# %%
#sat['Percent Tested'] = sat['Percent Tested'].replace(regex = '%', value = '').astype('float')

# %%
#sat['Percent Tested'] = sat['Percent Tested'].replace(regex = '%', value = '').astype('float')

# %%
sat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1125 entries, 0 to 1124
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                1125 non-null   object
#  1   School Name         1125 non-null   object
#  2   Borough             1125 non-null   object
#  3   Student Enrollment  1125 non-null   int64
#  4   Percent Tested      1125 non-null   float64
#  5   SAT Section         1125 non-null   object
#  6   Score               1125 non-null   int64
#  7   Unnamed: 7          0 non-null      float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 70.4+ KB

# %%
sat
# Out:
#             date                                 School Name    Borough  \
# 0     01-01-2023       A. Philip Randolph Campus High School  Manhattan
# 1     02-01-2023       A. Philip Randolph Campus High School  Manhattan
# 2     03-01-2023       A. Philip Randolph Campus High School  Manhattan
# 3     04-01-2023                 Abraham Lincoln High School   Brooklyn
# 4     05-01-2023                 Abraham Lincoln High School   Brooklyn
# ...          ...                                         ...        ...
# 1120  25-01-2026  Young Women's Leadership School in Astoria     Queens
# 1121  26-01-2026  Young Women's Leadership School in Astoria     Queens
# 1122  27-01-2026   Young Women's Leadership School in Queens     Queens
# 1123  28-01-2026   Young Women's Leadership School in Queens     Queens
# 1124  29-01-2026   Young Women's Leadership School in Queens     Queens
#
#       Student Enrollment  Percent Tested SAT Section  Score  Unnamed: 7
# ...

# %% [markdown]
# ### Lecture - 218 - Pivoting Data

# %%
pivoted = sat.pivot(index = 'School Name', columns = 'SAT Section', values = 'Score')

# %%
pivoted
# Out:
# SAT Section                                         Math  Reading  Writing
# School Name
# A. Philip Randolph Campus High School                459      453      447
# ACORN Community High School                          379      395      385
# Abraham Lincoln High School                          441      422      422
# Academy for Careers in Television and Film           444      458      444
# Academy for College Preparation and Career Expl...   386      397      393
# ...                                                  ...      ...      ...
# World Journalism Preparatory (College Board)         484      491      487
# York Early College Academy                           496      481      473
# Young Women's Leadership School                      478      465      472
# Young Women's Leadership School in Astoria           483      464      477
# Young Women's Leadership School in Queens            415      420      433
#
# [375 rows x 3 columns]

# %% [markdown]
# ### Lecture 219 - Undoing Pivots

# %%
pivoted.reset_index().melt(id_vars = 'School Name', value_name='Score')
# Out:
#                                             School Name SAT Section  Score
# 0                 A. Philip Randolph Campus High School        Math    459
# 1                           ACORN Community High School        Math    379
# 2                           Abraham Lincoln High School        Math    441
# 3            Academy for Careers in Television and Film        Math    444
# 4     Academy for College Preparation and Career Exp...        Math    386
# ...                                                 ...         ...    ...
# 1120       World Journalism Preparatory (College Board)     Writing    487
# 1121                         York Early College Academy     Writing    473
# 1122                    Young Women's Leadership School     Writing    472
# 1123         Young Women's Leadership School in Astoria     Writing    477
# 1124          Young Women's Leadership School in Queens     Writing    433
#
# [1125 rows x 3 columns]

# %%
pivoted.reset_index().melt(id_vars = 'School Name', value_name = 'Score')
# Out:
#                                             School Name SAT Section  Score
# 0                 A. Philip Randolph Campus High School        Math    459
# 1                           ACORN Community High School        Math    379
# 2                           Abraham Lincoln High School        Math    441
# 3            Academy for Careers in Television and Film        Math    444
# 4     Academy for College Preparation and Career Exp...        Math    386
# ...                                                 ...         ...    ...
# 1120       World Journalism Preparatory (College Board)     Writing    487
# 1121                         York Early College Academy     Writing    473
# 1122                    Young Women's Leadership School     Writing    472
# 1123         Young Women's Leadership School in Astoria     Writing    477
# 1124          Young Women's Leadership School in Queens     Writing    433
#
# [1125 rows x 3 columns]

# %%
pivoted.reset_index().melt(id_vars = 'SAT Section', value_name = 'Score')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SAT Section'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# ### Lecture - 220 -  What About Aggregates?

# %%
pivoted
# Out:
# SAT Section                                         Math  Reading  Writing
# School Name
# A. Philip Randolph Campus High School                459      453      447
# ACORN Community High School                          379      395      385
# Abraham Lincoln High School                          441      422      422
# Academy for Careers in Television and Film           444      458      444
# Academy for College Preparation and Career Expl...   386      397      393
# ...                                                  ...      ...      ...
# World Journalism Preparatory (College Board)         484      491      487
# York Early College Academy                           496      481      473
# Young Women's Leadership School                      478      465      472
# Young Women's Leadership School in Astoria           483      464      477
# Young Women's Leadership School in Queens            415      420      433
#
# [375 rows x 3 columns]

# %%
sat
# Out:
#                                      School Name    Borough  \
# 0          A. Philip Randolph Campus High School  Manhattan
# 1          A. Philip Randolph Campus High School  Manhattan
# 2          A. Philip Randolph Campus High School  Manhattan
# 3                    Abraham Lincoln High School   Brooklyn
# 4                    Abraham Lincoln High School   Brooklyn
# ...                                          ...        ...
# 1120  Young Women's Leadership School in Astoria     Queens
# 1121  Young Women's Leadership School in Astoria     Queens
# 1122   Young Women's Leadership School in Queens     Queens
# 1123   Young Women's Leadership School in Queens     Queens
# 1124   Young Women's Leadership School in Queens     Queens
#
#       Student Enrollment  Percent Tested SAT Section  Score
# 0                   1354            74.0        Math    459
# 1                   1354            74.0     Reading    453
# 2                   1354            74.0     Writing    447
# ...

# %%
sat['Borough'].nunique()
# Out:
# 5

# %%
sat.Borough.unique()
# Out:
# array(['Manhattan', 'Brooklyn', 'Queens', 'Bronx', 'Staten Island'],
#       dtype=object)

# %%
sat.pivot(index = 'Borough', columns = 'SAT Section', values = 'Score')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21384/2984239976.py in <module>
# ----> 1 sat.pivot(index = 'Borough', columns = 'SAT Section', values = 'Score')
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    7791         from pandas.core.reshape.pivot import pivot
#    7792
# -> 7793         return pivot(self, index=index, columns=columns, values=values)
#    7794
#    7795     _shared_docs[
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     515         else:
#     516             indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> 517     return indexed.unstack(columns_listlike)
#     518
#     519
#
# ...

# %% [markdown]
# ### Lecture - 221 - The pivot_table()

# %%
sat
# Out:
#                                      School Name    Borough  \
# 0          A. Philip Randolph Campus High School  Manhattan
# 1          A. Philip Randolph Campus High School  Manhattan
# 2          A. Philip Randolph Campus High School  Manhattan
# 3                    Abraham Lincoln High School   Brooklyn
# 4                    Abraham Lincoln High School   Brooklyn
# ...                                          ...        ...
# 1120  Young Women's Leadership School in Astoria     Queens
# 1121  Young Women's Leadership School in Astoria     Queens
# 1122   Young Women's Leadership School in Queens     Queens
# 1123   Young Women's Leadership School in Queens     Queens
# 1124   Young Women's Leadership School in Queens     Queens
#
#       Student Enrollment  Percent Tested SAT Section  Score
# 0                   1354            74.0        Math    459
# 1                   1354            74.0     Reading    453
# 2                   1354            74.0     Writing    447
# ...

# %%
sat.pivot_table(values = 'Score', index = 'Borough', columns = 'SAT Section', aggfunc = 'std')
# Out:
# SAT Section         Math    Reading    Writing
# Borough
# Bronx          52.215898  49.224340  51.304298
# Brooklyn       60.481420  48.914684  49.657072
# Manhattan      83.818315  73.930987  76.387707
# Queens         71.890229  61.712724  66.233383
# Staten Island  83.132825  66.850164  72.671330

# %%
sat.pivot_table(values = 'Score', index = 'Borough', columns = 'SAT Section', aggfunc = 'mean')
# Out:
# SAT Section          Math     Reading     Writing
# Borough
# Bronx          404.357143  402.520408  395.846939
# Brooklyn       416.403670  410.761468  403.091743
# Manhattan      455.887640  444.932584  439.314607
# Queens         462.362319  443.260870  439.855072
# Staten Island  486.200000  478.500000  474.300000

# %%
sat
# Out:
#                                      School Name    Borough  \
# 0          A. Philip Randolph Campus High School  Manhattan
# 1          A. Philip Randolph Campus High School  Manhattan
# 2          A. Philip Randolph Campus High School  Manhattan
# 3                    Abraham Lincoln High School   Brooklyn
# 4                    Abraham Lincoln High School   Brooklyn
# ...                                          ...        ...
# 1120  Young Women's Leadership School in Astoria     Queens
# 1121  Young Women's Leadership School in Astoria     Queens
# 1122   Young Women's Leadership School in Queens     Queens
# 1123   Young Women's Leadership School in Queens     Queens
# 1124   Young Women's Leadership School in Queens     Queens
#
#       Student Enrollment  Percent Tested SAT Section  Score
# 0                   1354            74.0        Math    459
# 1                   1354            74.0     Reading    453
# 2                   1354            74.0     Writing    447
# ...

# %%
sat.pivot_table(values = 'Percent Tested', index = 'Borough')
# Out:
#                Percent Tested
# Borough
# Bronx               58.220408
# Brooklyn            62.423853
# Manhattan           71.197753
# Queens              69.036232
# Staten Island       67.390000

# %%
sat.pivot_table(values = 'Percent Tested', index = 'Borough', aggfunc = 'min')
# Out:
#                Percent Tested
# Borough
# Bronx                    19.2
# Brooklyn                 18.5
# Manhattan                30.6
# Queens                   26.3
# Staten Island            38.0

# %% [markdown]
# ### Lecture - 222 -  BONUS: The Problem With Average Percentage

# %%
sat.pivot_table(values = 'Percent Tested', index = 'Borough')
# Out:
#                Percent Tested
# Borough
# Bronx               58.220408
# Brooklyn            62.423853
# Manhattan           71.197753
# Queens              69.036232
# Staten Island       67.390000

# %%
sat
# Out:
#                                      School Name    Borough  \
# 0          A. Philip Randolph Campus High School  Manhattan
# 1          A. Philip Randolph Campus High School  Manhattan
# 2          A. Philip Randolph Campus High School  Manhattan
# 3                    Abraham Lincoln High School   Brooklyn
# 4                    Abraham Lincoln High School   Brooklyn
# ...                                          ...        ...
# 1120  Young Women's Leadership School in Astoria     Queens
# 1121  Young Women's Leadership School in Astoria     Queens
# 1122   Young Women's Leadership School in Queens     Queens
# 1123   Young Women's Leadership School in Queens     Queens
# 1124   Young Women's Leadership School in Queens     Queens
#
#       Student Enrollment  Percent Tested SAT Section  Score
# 0                   1354            74.0        Math    459
# 1                   1354            74.0     Reading    453
# 2                   1354            74.0     Writing    447
# ...

# %%
sat['SAT Tackers'] = (sat['Student Enrollment'] * sat['Percent Tested'])/100

# %%
sat.describe()
# Out:
#        Student Enrollment  Percent Tested        Score  SAT Tackers
# count         1125.000000     1125.000000  1125.000000  1125.000000
# mean           764.682667       64.756800   425.302222   514.057597
# std            788.773514       18.822627    66.471686   607.706771
# min            142.000000       18.500000   284.000000    46.070000
# 25%            397.000000       50.700000   385.000000   213.237000
# 50%            483.000000       63.800000   409.000000   329.588000
# 75%            666.000000       79.600000   446.000000   494.428000
# max           5447.000000      100.000000   754.000000  5201.885000

# %%
sat
# Out:
#                                      School Name    Borough  \
# 0          A. Philip Randolph Campus High School  Manhattan
# 1          A. Philip Randolph Campus High School  Manhattan
# 2          A. Philip Randolph Campus High School  Manhattan
# 3                    Abraham Lincoln High School   Brooklyn
# 4                    Abraham Lincoln High School   Brooklyn
# ...                                          ...        ...
# 1120  Young Women's Leadership School in Astoria     Queens
# 1121  Young Women's Leadership School in Astoria     Queens
# 1122   Young Women's Leadership School in Queens     Queens
# 1123   Young Women's Leadership School in Queens     Queens
# 1124   Young Women's Leadership School in Queens     Queens
#
#       Student Enrollment  Percent Tested SAT Section  Score  SAT Tackers
# 0                   1354            74.0        Math    459     1001.960
# 1                   1354            74.0     Reading    453     1001.960
# ...

# %%
sat.groupby('Borough')['Percent Tested'].sum()
# Out:
# Borough
# Bronx            17116.8
# Brooklyn         20412.6
# Manhattan        19009.8
# Queens           14290.5
# Staten Island     2021.7
# Name: Percent Tested, dtype: float64

# %%
sat.pivot_table(values= 'SAT Tackers', index = 'Borough', aggfunc= 'mean')
# Out:
#                SAT Tackers
# Borough
# Bronx           322.523888
# Brooklyn        498.704807
# Manhattan       477.360876
# Queens          747.937551
# Staten Island  1271.262500

# %%
sat.pivot_table(values= 'Student Enrollment', index = 'Borough', aggfunc= 'mean')
# Out:
#                Student Enrollment
# Borough
# Bronx                  541.724490
# Brooklyn               742.550459
# Manhattan              638.089888
# Queens                1122.884058
# Staten Island         1846.000000

# %%
sat.groupby('Borough')['SAT Tackers'].mean()
# Out:
# Borough
# Bronx             322.523888
# Brooklyn          498.704807
# Manhattan         477.360876
# Queens            747.937551
# Staten Island    1271.262500
# Name: SAT Tackers, dtype: float64

# %%
# practice it
sat.groupby(['Borough'])[['Student Enrollment','SAT Tackers' ]]\
   .apply(lambda sg: sg['SAT Tackers'].mean() / sg['Student Enrollment'].mean())\
   .nsmallest(10)
# Out:
# Borough
# Bronx            0.595365
# Queens           0.666086
# Brooklyn         0.671611
# Staten Island    0.688658
# Manhattan        0.748109
# dtype: float64

# %% [markdown]
# ### Lecture - 223 -  Replicating Pivot Tables With GroupBy

# %%
sat.pivot_table('Score', 'Borough', 'SAT Section')
# Out:
# SAT Section          Math     Reading     Writing
# Borough
# Bronx          404.357143  402.520408  395.846939
# Brooklyn       416.403670  410.761468  403.091743
# Manhattan      455.887640  444.932584  439.314607
# Queens         462.362319  443.260870  439.855072
# Staten Island  486.200000  478.500000  474.300000

# %%
sat.groupby(['Borough', 'SAT Section']).agg({'Score':'mean'}).unstack()
# Out:
#                     Score
# SAT Section          Math     Reading     Writing
# Borough
# Bronx          404.357143  402.520408  395.846939
# Brooklyn       416.403670  410.761468  403.091743
# Manhattan      455.887640  444.932584  439.314607
# Queens         462.362319  443.260870  439.855072
# Staten Island  486.200000  478.500000  474.300000

# %%
sat['SAT Section'].value_counts()
# Out:
# Math       375
# Reading    375
# Writing    375
# Name: SAT Section, dtype: int64

# %% [markdown]
# ### Lecture - 224 - Adding Margins

# %%
sat.pivot_table('Score', 'Borough', 'SAT Section', aggfunc= 'mean')
# Out:
# SAT Section          Math     Reading     Writing
# Borough
# Bronx          404.357143  402.520408  395.846939
# Brooklyn       416.403670  410.761468  403.091743
# Manhattan      455.887640  444.932584  439.314607
# Queens         462.362319  443.260870  439.855072
# Staten Island  486.200000  478.500000  474.300000

# %%
sat.pivot_table('Score', 'Borough', 'SAT Section', aggfunc= 'mean', margins=True)
# Out:
# SAT Section          Math     Reading     Writing         All
# Borough
# Bronx          404.357143  402.520408  395.846939  400.908163
# Brooklyn       416.403670  410.761468  403.091743  410.085627
# Manhattan      455.887640  444.932584  439.314607  446.711610
# Queens         462.362319  443.260870  439.855072  448.492754
# Staten Island  486.200000  478.500000  474.300000  479.666667
# All            432.944000  424.504000  418.458667  425.302222

# %%
sat.pivot_table('Score', 'Borough')
# Out:
#                     Score
# Borough
# Bronx          400.908163
# Brooklyn       410.085627
# Manhattan      446.711610
# Queens         448.492754
# Staten Island  479.666667

# %%
sat.pivot_table('Score', 'SAT Section')
# Out:
#                   Score
# SAT Section
# Math         432.944000
# Reading      424.504000
# Writing      418.458667

# %% [markdown]
# ### Lecture - 225 - MultiIndex Pivot Tables

# %%
sat.pivot_table('Score', 'School Name', 'SAT Section')
# Out:
# SAT Section                                         Math  Reading  Writing
# School Name
# A. Philip Randolph Campus High School                459      453      447
# ACORN Community High School                          379      395      385
# Abraham Lincoln High School                          441      422      422
# Academy for Careers in Television and Film           444      458      444
# Academy for College Preparation and Career Expl...   386      397      393
# ...                                                  ...      ...      ...
# World Journalism Preparatory (College Board)         484      491      487
# York Early College Academy                           496      481      473
# Young Women's Leadership School                      478      465      472
# Young Women's Leadership School in Astoria           483      464      477
# Young Women's Leadership School in Queens            415      420      433
#
# [375 rows x 3 columns]

# %%
#sat.pivot_table('Score', ['School Name', 'Borough'] , 'SAT Section')

# %%
sat.pivot_table('Score', ['School Name', 'Borough'] , 'SAT Section')
# Out:
# SAT Section                                                   Math  Reading  \
# School Name                                        Borough
# A. Philip Randolph Campus High School              Manhattan   459      453
# ACORN Community High School                        Brooklyn    379      395
# Abraham Lincoln High School                        Brooklyn    441      422
# Academy for Careers in Television and Film         Queens      444      458
# Academy for College Preparation and Career Expl... Brooklyn    386      397
# ...                                                            ...      ...
# World Journalism Preparatory (College Board)       Queens      484      491
# York Early College Academy                         Queens      496      481
# Young Women's Leadership School                    Manhattan   478      465
# Young Women's Leadership School in Astoria         Queens      483      464
# Young Women's Leadership School in Queens          Queens      415      420
# ...

# %%
sat.pivot_table(values = 'Score', index = ['School Name', 'Borough'] , columns = 'SAT Section').T
# Out:
# School Name A. Philip Randolph Campus High School ACORN Community High School  \
# Borough                                 Manhattan                    Brooklyn
# SAT Section
# Math                                          459                         379
# Reading                                       453                         395
# Writing                                       447                         385
#
# School Name Abraham Lincoln High School  \
# Borough                        Brooklyn
# SAT Section
# Math                                441
# Reading                             422
# Writing                             422
#
# School Name Academy for Careers in Television and Film  \
# Borough                                         Queens
# SAT Section
# Math                                               444
# Reading                                            458
# Writing                                            444
#
# ...

# %%
sat.pivot_table(values = 'Score', index = ['School Name', 'Borough'] , columns = 'SAT Section').T.T
# Out:
# SAT Section                                                   Math  Reading  \
# School Name                                        Borough
# A. Philip Randolph Campus High School              Manhattan   459      453
# ACORN Community High School                        Brooklyn    379      395
# Abraham Lincoln High School                        Brooklyn    441      422
# Academy for Careers in Television and Film         Queens      444      458
# Academy for College Preparation and Career Expl... Brooklyn    386      397
# ...                                                            ...      ...
# World Journalism Preparatory (College Board)       Queens      484      491
# York Early College Academy                         Queens      496      481
# Young Women's Leadership School                    Manhattan   478      465
# Young Women's Leadership School in Astoria         Queens      483      464
# Young Women's Leadership School in Queens          Queens      415      420
# ...

# %% [markdown]
# ### lecture - 226 -  Applying Multiple Functions

# %%
sat.pivot_table('Score', 'Borough' , 'SAT Section', aggfunc='mean')
# Out:
# SAT Section          Math     Reading     Writing
# Borough
# Bronx          404.357143  402.520408  395.846939
# Brooklyn       416.403670  410.761468  403.091743
# Manhattan      455.887640  444.932584  439.314607
# Queens         462.362319  443.260870  439.855072
# Staten Island  486.200000  478.500000  474.300000

# %%
sat.pivot_table('Score', 'Borough' , 'SAT Section', aggfunc='max')
# Out:
# SAT Section    Math  Reading  Writing
# Borough
# Bronx           714      672      672
# Brooklyn        682      608      606
# Manhattan       754      697      693
# Queens          701      640      661
# Staten Island   711      660      670

# %%
#sat.pivot_table('Score', 'Borough' , 'SAT Section', aggfunc=['max', 'min']).rename(axis = 1, level=0,mapper={'max': 'Maximum_Value', 'min': 'Minimum_Value'})

# %%
sat.pivot_table('Score', 'Borough' , 'SAT Section', aggfunc=['max', 'min']).rename(axis = 1, level=0,mapper={'max': 'Maximum_Value', 'min': 'Minimum_Value'})
# Out:
#               Maximum_Value                 Minimum_Value
# SAT Section            Math Reading Writing          Math Reading Writing
# Borough
# Bronx                   714     672     672           317     311     292
# Brooklyn                682     608     606           319     302     284
# Manhattan               754     697     693           344     330     316
# Queens                  701     640     661           340     320     318
# Staten Island           711     660     670           420     427     409

# %%
sat
# Out:
#             date                                 School Name    Borough  \
# 0     01-01-2023       A. Philip Randolph Campus High School  Manhattan
# 1     02-01-2023       A. Philip Randolph Campus High School  Manhattan
# 2     03-01-2023       A. Philip Randolph Campus High School  Manhattan
# 3     04-01-2023                 Abraham Lincoln High School   Brooklyn
# 4     05-01-2023                 Abraham Lincoln High School   Brooklyn
# ...          ...                                         ...        ...
# 1120  25-01-2026  Young Women's Leadership School in Astoria     Queens
# 1121  26-01-2026  Young Women's Leadership School in Astoria     Queens
# 1122  27-01-2026   Young Women's Leadership School in Queens     Queens
# 1123  28-01-2026   Young Women's Leadership School in Queens     Queens
# 1124  29-01-2026   Young Women's Leadership School in Queens     Queens
#
#       Student Enrollment  Percent Tested SAT Section  Score  Unnamed: 7
# ...
