# %%
import pandas as pd
import numpy as np

# %%
tech = pd.read_csv('D:\\karan data\\Data for Preprocessing\\tech_giants.csv')

# %%
tech['date'] = pd.to_datetime(tech['date'], format="%d-%m-%Y")

# %%
tech.set_index(['date', 'name'], inplace=True)

# %%
tech.loc[('2019-01', ['GOOGL', 'AAPL']), :]
# Out:
#                   month  year  day     open    close     high      low  \
# date       name
# 2019-01-02 GOOGL      1  2019    2  1027.20  1054.68  1060.79  1025.28
# 2019-01-03 GOOGL      1  2019    3  1050.67  1025.47  1066.26  1022.37
# 2019-01-04 GOOGL      1  2019    4  1042.56  1078.07  1080.00  1036.86
# 2019-01-07 GOOGL      1  2019    7  1080.97  1075.92  1082.70  1062.64
# 2019-01-08 GOOGL      1  2019    8  1086.00  1085.37  1093.35  1068.35
# 2019-01-09 GOOGL      1  2019    9  1087.99  1081.65  1091.64  1074.37
# 2019-01-10 GOOGL      1  2019   10  1074.94  1078.83  1079.81  1064.68
# 2019-01-11 GOOGL      1  2019   11  1069.90  1064.47  1073.37  1056.43
# 2019-01-14 GOOGL      1  2019   14  1053.34  1051.51  1058.45  1048.55
# 2019-01-15 GOOGL      1  2019   15  1058.01  1086.51  1088.27  1054.44
# 2019-01-16 GOOGL      1  2019   16  1090.00  1089.51  1102.36  1088.01
# 2019-01-17 GOOGL      1  2019   17  1087.99  1099.12  1100.70  1083.26
# ...

# %%
tech
# Out:
#                   month  year  day     open    close     high      low  \
# date       name
# 2014-01-02 FB         1  2014    2    54.86    54.71    55.22    54.19
#            AAPL       1  2014    2    79.38    79.02    79.58    78.86
#            GOOGL      1  2014    2   557.73   556.56   558.88   554.13
#            MSFT       1  2014    2    37.35    37.16    37.40    37.10
#            AMZN       1  2014    2   398.80   397.97   399.36   394.02
# ...                 ...   ...  ...      ...      ...      ...      ...
# 2019-08-23 MSFT       8  2019   23   137.19   133.39   138.35   132.80
#            AAPL       8  2019   23   209.43   202.64   212.05   201.00
#            GOOGL      8  2019   23  1185.17  1153.58  1195.67  1150.00
#            AMZN       8  2019   23  1793.03  1749.62  1804.90  1745.23
#            FB         8  2019   23   180.84   177.75   183.13   176.66
#
#                     volume volume_type
# date       name
# 2014-01-02 FB     43257622      medium
# ...

# %%
tech.index.levels[0]
# Out:
# DatetimeIndex(['2014-01-02', '2014-01-03', '2014-01-06', '2014-01-07',
#                '2014-01-08', '2014-01-09', '2014-01-10', '2014-01-13',
#                '2014-01-14', '2014-01-15',
#                ...
#                '2019-08-12', '2019-08-13', '2019-08-14', '2019-08-15',
#                '2019-08-16', '2019-08-19', '2019-08-20', '2019-08-21',
#                '2019-08-22', '2019-08-23'],
#               dtype='datetime64[ns]', name='date', length=1421, freq=None)

# %%
df = tech.reset_index()

# %%
df.set_index(['name', 'year'], inplace=True)

# %%
df
# Out:
#                  date  month  day     open    close     high      low  \
# name  year
# FB    2014 2014-01-02      1    2    54.86    54.71    55.22    54.19
# AAPL  2014 2014-01-02      1    2    79.38    79.02    79.58    78.86
# GOOGL 2014 2014-01-02      1    2   557.73   556.56   558.88   554.13
# MSFT  2014 2014-01-02      1    2    37.35    37.16    37.40    37.10
# AMZN  2014 2014-01-02      1    2   398.80   397.97   399.36   394.02
# ...               ...    ...  ...      ...      ...      ...      ...
# MSFT  2019 2019-08-23      8   23   137.19   133.39   138.35   132.80
# AAPL  2019 2019-08-23      8   23   209.43   202.64   212.05   201.00
# GOOGL 2019 2019-08-23      8   23  1185.17  1153.58  1195.67  1150.00
# AMZN  2019 2019-08-23      8   23  1793.03  1749.62  1804.90  1745.23
# FB    2019 2019-08-23      8   23   180.84   177.75   183.13   176.66
#
#               volume volume_type
# name  year
# FB    2014  43257622      medium
# AAPL  2014   8398851         low
# ...

# %%
even_year = df.index.levels[1] % 2 == 0

# %%
even_year
# Out:
# array([ True, False,  True, False,  True, False])

# %%
df[even_year]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16456\3612229532.py in ?()
# ----> 1 df[even_year]
#
# c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, key)
#    3748             return self.where(key)
#    3749
#    3750         # Do we have a (boolean) 1d indexer?
#    3751         if com.is_bool_indexer(key):
# -> 3752             return self._getitem_bool_array(key)
#    3753
#    3754         # We are left with two options: a single key, and a collection of keys,
#    3755         # We interpret tuples as collections only for non-MultiIndex
#
# c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, key)
#    3795                 UserWarning,
#    3796                 stacklevel=find_stack_level(),
#    3797             )
#    3798         elif len(key) != len(self.index):
# ...

# %%
even_years = df.index.get_level_values(1) % 2 == 0  # important

# %%
even_years
# Out:
# array([ True,  True,  True, ..., False, False, False])

# %%
df[even_years]
# Out:
#                  date  month  day     open    close     high      low  \
# name  year
# FB    2014 2014-01-02      1    2    54.86    54.71    55.22    54.19
# AAPL  2014 2014-01-02      1    2    79.38    79.02    79.58    78.86
# GOOGL 2014 2014-01-02      1    2   557.73   556.56   558.88   554.13
# MSFT  2014 2014-01-02      1    2    37.35    37.16    37.40    37.10
# AMZN  2014 2014-01-02      1    2   398.80   397.97   399.36   394.02
# ...               ...    ...  ...      ...      ...      ...      ...
#       2018 2018-12-31     12   31  1510.80  1501.97  1520.76  1487.00
# FB    2018 2018-12-31     12   31   134.45   131.09   134.64   129.95
# GOOGL 2018 2018-12-31     12   31  1057.83  1044.96  1062.99  1033.04
# AAPL  2018 2018-12-31     12   31   158.53   157.74   159.36   156.48
# MSFT  2018 2018-12-31     12   31   101.29   101.57   102.40   100.44
#
#               volume volume_type
# name  year
# FB    2014  43257622      medium
# AAPL  2014   8398851         low
# ...

# %%
df1 = df.reset_index()

# %%
df1
# Out:
#        name  year       date  month  day     open    close     high      low  \
# 0        FB  2014 2014-01-02      1    2    54.86    54.71    55.22    54.19
# 1      AAPL  2014 2014-01-02      1    2    79.38    79.02    79.58    78.86
# 2     GOOGL  2014 2014-01-02      1    2   557.73   556.56   558.88   554.13
# 3      MSFT  2014 2014-01-02      1    2    37.35    37.16    37.40    37.10
# 4      AMZN  2014 2014-01-02      1    2   398.80   397.97   399.36   394.02
# ...     ...   ...        ...    ...  ...      ...      ...      ...      ...
# 7100   MSFT  2019 2019-08-23      8   23   137.19   133.39   138.35   132.80
# 7101   AAPL  2019 2019-08-23      8   23   209.43   202.64   212.05   201.00
# 7102  GOOGL  2019 2019-08-23      8   23  1185.17  1153.58  1195.67  1150.00
# 7103   AMZN  2019 2019-08-23      8   23  1793.03  1749.62  1804.90  1745.23
# 7104     FB  2019 2019-08-23      8   23   180.84   177.75   183.13   176.66
#
#         volume volume_type
# ...

# %%
df1
# Out:
#        name  year       date  month  day     open    close     high      low  \
# 0        FB  2014 2014-01-02      1    2    54.86    54.71    55.22    54.19
# 1      AAPL  2014 2014-01-02      1    2    79.38    79.02    79.58    78.86
# 2     GOOGL  2014 2014-01-02      1    2   557.73   556.56   558.88   554.13
# 3      MSFT  2014 2014-01-02      1    2    37.35    37.16    37.40    37.10
# 4      AMZN  2014 2014-01-02      1    2   398.80   397.97   399.36   394.02
# ...     ...   ...        ...    ...  ...      ...      ...      ...      ...
# 7100   MSFT  2019 2019-08-23      8   23   137.19   133.39   138.35   132.80
# 7101   AAPL  2019 2019-08-23      8   23   209.43   202.64   212.05   201.00
# 7102  GOOGL  2019 2019-08-23      8   23  1185.17  1153.58  1195.67  1150.00
# 7103   AMZN  2019 2019-08-23      8   23  1793.03  1749.62  1804.90  1745.23
# 7104     FB  2019 2019-08-23      8   23   180.84   177.75   183.13   176.66
#
#         volume volume_type
# ...

# %%
df2 = df1.groupby(['name', 'volume_type']).agg(Total_High = ('high', 'sum'))

# %%
df1.groupby(['name', 'volume_type'])[['high']].sum().unstack(1).plot(kind = 'bar')
# Out:
# <Axes: xlabel='name'>

# %%
df2.unstack(1).plot(kind = 'bar')
# Out:
# <Axes: xlabel='name'>
