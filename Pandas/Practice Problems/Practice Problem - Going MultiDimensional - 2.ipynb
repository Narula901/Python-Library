# %%
import pandas as pd
import numpy as np

# %%
tech = pd.read_csv('D:\\karan data\\Data for Preprocessing\\tech_giants.csv')

# %%
tech.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7105 entries, 0 to 7104
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         7105 non-null   object
#  1   month        7105 non-null   int64
#  2   year         7105 non-null   int64
#  3   day          7105 non-null   int64
#  4   name         7105 non-null   object
#  5   open         7105 non-null   float64
#  6   close        7105 non-null   float64
#  7   high         7105 non-null   float64
#  8   low          7105 non-null   float64
#  9   volume       7105 non-null   int64
#  10  volume_type  7105 non-null   object
# dtypes: float64(4), int64(4), object(3)
# memory usage: 610.7+ KB

# %%
tech['date'] = pd.to_datetime(tech['date'], format="%d-%m-%Y")

# %%
tech.set_index(['date', 'name'], inplace = True)

# %%
tech
# Out:
#                   month  year  day     open    close     high      low  \
# date       name
# 2014-01-02 FB         1  2014    2    54.86    54.71    55.22    54.19
#            AAPL       1  2014    2    79.38    79.02    79.58    78.86
#            GOOGL      1  2014    2   557.73   556.56   558.88   554.13
#            MSFT       1  2014    2    37.35    37.16    37.40    37.10
#            AMZN       1  2014    2   398.80   397.97   399.36   394.02
# ...                 ...   ...  ...      ...      ...      ...      ...
# 2019-08-23 MSFT       8  2019   23   137.19   133.39   138.35   132.80
#            AAPL       8  2019   23   209.43   202.64   212.05   201.00
#            GOOGL      8  2019   23  1185.17  1153.58  1195.67  1150.00
#            AMZN       8  2019   23  1793.03  1749.62  1804.90  1745.23
#            FB         8  2019   23   180.84   177.75   183.13   176.66
#
#                     volume volume_type
# date       name
# 2014-01-02 FB     43257622      medium
# ...

# %%
tech.loc[(slice('2017-01-03','2017-01-31'), 'GOOGL'), 'open':'low']
# Out:
#                     open   close    high     low
# date       name
# 2017-01-03 GOOGL  800.62  808.01  811.44  796.89
# 2017-01-04 GOOGL  809.89  807.77  813.43  804.11
# 2017-01-05 GOOGL  807.50  813.02  813.74  805.92
# 2017-01-06 GOOGL  814.99  825.21  828.96  811.50
# 2017-01-09 GOOGL  826.37  827.18  830.43  821.62
# 2017-01-10 GOOGL  827.07  826.01  829.41  823.14
# 2017-01-11 GOOGL  826.62  829.86  829.90  821.47
# 2017-01-12 GOOGL  828.38  829.53  830.38  821.01
# 2017-01-13 GOOGL  831.00  830.94  834.65  829.52
# 2017-01-17 GOOGL  830.00  827.46  830.18  823.20
# 2017-01-18 GOOGL  829.80  829.02  829.81  824.08
# 2017-01-19 GOOGL  829.00  824.37  833.00  823.96
# 2017-01-20 GOOGL  829.09  828.17  829.24  824.60
# 2017-01-23 GOOGL  831.61  844.43  845.54  828.70
# 2017-01-24 GOOGL  846.98  849.53  851.52  842.28
# 2017-01-25 GOOGL  853.55  858.45  858.79  849.74
# 2017-01-26 GOOGL  859.05  856.98  861.00  850.52
# 2017-01-27 GOOGL  859.00  845.03  867.00  841.90
# ...

# %%
tech.loc[('2019-01-31',['GOOGL', 'AAPL']), :]
# Out:
#                   month  year  day     open    close     high      low  \
# date       name
# 2019-01-31 GOOGL      1  2019   31  1112.24  1125.89  1127.67  1105.25
#            AAPL       1  2019   31   166.11   166.44   169.00   164.56
#
#                     volume volume_type
# date       name
# 2019-01-31 GOOGL   2011572      medium
#            AAPL   40739649      medium

# %%
tech.loc[(slice('2019-01-01','2019-01-31'), ['GOOGL', 'AAPL']), :]
# Out:
#                   month  year  day     open    close     high      low  \
# date       name
# 2019-01-02 GOOGL      1  2019    2  1027.20  1054.68  1060.79  1025.28
#            AAPL       1  2019    2   154.89   157.92   158.85   154.23
# 2019-01-03 AAPL       1  2019    3   143.98   142.19   145.72   142.00
#            GOOGL      1  2019    3  1050.67  1025.47  1066.26  1022.37
# 2019-01-04 AAPL       1  2019    4   144.53   148.26   148.55   143.80
#            GOOGL      1  2019    4  1042.56  1078.07  1080.00  1036.86
# 2019-01-07 AAPL       1  2019    7   148.70   147.93   148.83   145.90
#            GOOGL      1  2019    7  1080.97  1075.92  1082.70  1062.64
# 2019-01-08 AAPL       1  2019    8   149.56   150.75   151.82   148.52
#            GOOGL      1  2019    8  1086.00  1085.37  1093.35  1068.35
# 2019-01-09 GOOGL      1  2019    9  1087.99  1081.65  1091.64  1074.37
#            AAPL       1  2019    9   151.29   153.31   154.53   149.63
# ...

# %%
tech.loc[(slice('2019-01-01','2019-01-31'), 'GOOGL'), :]
# Out:
#                   month  year  day     open    close     high      low  \
# date       name
# 2019-01-02 GOOGL      1  2019    2  1027.20  1054.68  1060.79  1025.28
# 2019-01-03 GOOGL      1  2019    3  1050.67  1025.47  1066.26  1022.37
# 2019-01-04 GOOGL      1  2019    4  1042.56  1078.07  1080.00  1036.86
# 2019-01-07 GOOGL      1  2019    7  1080.97  1075.92  1082.70  1062.64
# 2019-01-08 GOOGL      1  2019    8  1086.00  1085.37  1093.35  1068.35
# 2019-01-09 GOOGL      1  2019    9  1087.99  1081.65  1091.64  1074.37
# 2019-01-10 GOOGL      1  2019   10  1074.94  1078.83  1079.81  1064.68
# 2019-01-11 GOOGL      1  2019   11  1069.90  1064.47  1073.37  1056.43
# 2019-01-14 GOOGL      1  2019   14  1053.34  1051.51  1058.45  1048.55
# 2019-01-15 GOOGL      1  2019   15  1058.01  1086.51  1088.27  1054.44
# 2019-01-16 GOOGL      1  2019   16  1090.00  1089.51  1102.36  1088.01
# 2019-01-17 GOOGL      1  2019   17  1087.99  1099.12  1100.70  1083.26
# ...

# %%
tech.loc[(['2019-01-28', '2019-01-31'],['GOOGL', 'AAPL']), :]
# Out:
#                   month  year  day     open    close     high      low  \
# date       name
# 2019-01-28 GOOGL      1  2019   28  1090.07  1079.86  1093.37  1074.61
#            AAPL       1  2019   28   155.79   156.30   156.33   153.66
# 2019-01-31 GOOGL      1  2019   31  1112.24  1125.89  1127.67  1105.25
#            AAPL       1  2019   31   166.11   166.44   169.00   164.56
#
#                     volume volume_type
# date       name
# 2019-01-28 GOOGL   1466714      medium
#            AAPL   26192058      medium
# 2019-01-31 GOOGL   2011572      medium
#            AAPL   40739649      medium

# %%
tech
# Out:
#                   month  year  day     open    close     high      low  \
# date       name
# 2014-01-02 FB         1  2014    2    54.86    54.71    55.22    54.19
#            AAPL       1  2014    2    79.38    79.02    79.58    78.86
#            GOOGL      1  2014    2   557.73   556.56   558.88   554.13
#            MSFT       1  2014    2    37.35    37.16    37.40    37.10
#            AMZN       1  2014    2   398.80   397.97   399.36   394.02
# ...                 ...   ...  ...      ...      ...      ...      ...
# 2019-08-23 MSFT       8  2019   23   137.19   133.39   138.35   132.80
#            AAPL       8  2019   23   209.43   202.64   212.05   201.00
#            GOOGL      8  2019   23  1185.17  1153.58  1195.67  1150.00
#            AMZN       8  2019   23  1793.03  1749.62  1804.90  1745.23
#            FB         8  2019   23   180.84   177.75   183.13   176.66
#
#                     volume volume_type
# date       name
# 2014-01-02 FB     43257622      medium
# ...

# %%
tech.loc[(slice('2014-01-02', '2014-01-10'), ['FB', 'AAPL']), : ]
# Out:
#                  month  year  day   open  close   high    low    volume  \
# date       name
# 2014-01-02 FB        1  2014    2  54.86  54.71  55.22  54.19  43257622
#            AAPL      1  2014    2  79.38  79.02  79.58  78.86   8398851
# 2014-01-03 FB        1  2014    3  55.00  54.56  55.65  54.53  38287706
#            AAPL      1  2014    3  79.00  77.28  79.10  77.20  14043410
# 2014-01-06 AAPL      1  2014    6  76.78  77.70  78.11  76.23  14765593
#            FB        1  2014    6  54.39  57.20  57.26  54.05  68974359
# 2014-01-07 FB        1  2014    7  57.67  57.92  58.55  57.22  77329009
#            AAPL      1  2014    7  77.76  77.15  77.99  76.85  11347538
# 2014-01-08 AAPL      1  2014    8  76.97  77.64  77.94  76.96   9240955
#            FB        1  2014    8  57.59  58.23  58.41  57.23  56800776
# 2014-01-09 AAPL      1  2014    9  78.11  76.65  78.12  76.48   9986457
#            FB        1  2014    9  58.66  57.22  58.96  56.65  92349222
# ...

# %%
tech.loc[['2015-01-06', '2015-01-07'], ['FB', 'AMZN']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 tech.loc[['2015-01-06', '2015-01-07'], ['FB', 'AMZN']]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1280, in _LocIndexer._getitem_tuple(self, tup)
#    1278 with suppress(IndexingError):
#    1279     tup = self._expand_ellipsis(tup)
# -> 1280     return self._getitem_lowerdim(tup)
#    1282 # no multi-index, so validate all of the indexers
# ...

# %%
tech.loc[(['2015-01-06', '2015-01-07'], ['FB', 'AMZN']), :]
# Out:
#                  month  year  day    open   close    high     low    volume  \
# date       name
# 2015-01-06 FB        1  2015    6   77.23   76.15   77.59   75.36  27399288
#            AMZN      1  2015    6  302.20  295.29  303.00  292.38   3519034
# 2015-01-07 FB        1  2015    7   76.76   76.15   77.36   75.82  22045333
#            AMZN      1  2015    7  297.54  298.42  301.28  295.33   2640349
#
#                 volume_type
# date       name
# 2015-01-06 FB        medium
#            AMZN      medium
# 2015-01-07 FB        medium
#            AMZN      medium

# %%
tech.loc[(['2015-01-06', '2015-01-07'], ['FB', 'AMZN']), ['close', 'volume']]
# Out:
#                   close    volume
# date       name
# 2015-01-06 FB     76.15  27399288
#            AMZN  295.29   3519034
# 2015-01-07 FB     76.15  22045333
#            AMZN  298.42   2640349

# %%
#Question:

tech_df2 = tech.loc['2016-07-01':'2016-08-01']

# %%
# Select 10 days at random 
tech_df2.loc[(slice(None),['AAPL']), :].sample(10)
# Out:
#                  month  year  day    open   close    high     low    volume  \
# date       name
# 2016-07-15 AAPL      7  2016   15   98.92   98.78   99.30   98.50  30136990
# 2016-07-01 AAPL      7  2016    1   95.49   95.89   96.47   95.33  26026540
# 2016-07-29 AAPL      7  2016   29  104.19  104.21  104.55  103.68  27733688
# 2016-08-01 AAPL      8  2016    1  104.41  106.05  106.15  104.41  38167871
# 2016-07-06 AAPL      7  2016    6   94.60   95.53   95.66   94.37  30949090
# 2016-07-12 AAPL      7  2016   12   97.17   97.42   97.70   97.12  24167463
# 2016-07-27 AAPL      7  2016   27  104.27  102.95  104.35  102.75  92344820
# 2016-07-05 AAPL      7  2016    5   95.39   94.99   95.40   94.46  27705210
# 2016-07-13 AAPL      7  2016   13   97.41   96.87   97.67   96.84  25892171
# 2016-07-19 AAPL      7  2016   19   99.56   99.87  100.00   99.34  23779924
#
#                 volume_type
# date       name
# 2016-07-15 AAPL      medium
# 2016-07-01 AAPL      medium
# ...

# %%
tech_df2.loc[(slice(None), ['AAPL', 'GOOGL']),['high','low']]
# Out:
#                     high     low
# date       name
# 2016-07-01 AAPL    96.47   95.33
# 2016-07-05 AAPL    95.40   94.46
# 2016-07-06 AAPL    95.66   94.37
# 2016-07-07 AAPL    96.50   95.62
# 2016-07-08 AAPL    96.89   96.05
# 2016-07-11 AAPL    97.65   96.73
# 2016-07-12 AAPL    97.70   97.12
# 2016-07-13 AAPL    97.67   96.84
# 2016-07-14 AAPL    98.99   97.32
# 2016-07-15 AAPL    99.30   98.50
# 2016-07-18 AAPL   100.13   98.60
# 2016-07-19 AAPL   100.00   99.34
# 2016-07-20 AAPL   100.46   99.74
# 2016-07-21 AAPL   101.00   99.13
# 2016-07-22 AAPL    99.30   98.31
# 2016-07-25 AAPL    98.84   96.92
# 2016-07-26 AAPL    97.97   96.42
# 2016-07-27 AAPL   104.35  102.75
# 2016-07-28 AAPL   104.45  102.82
# 2016-07-29 AAPL   104.55  103.68
# 2016-08-01 AAPL   106.15  104.41
# 2016-07-01 GOOGL  712.53  703.73
# 2016-07-05 GOOGL  708.12  699.13
# 2016-07-06 GOOGL  713.00  699.00
# 2016-07-07 GOOGL  710.17  700.67
# 2016-07-08 GOOGL  717.90  708.11
# 2016-07-11 GOOGL  728.93  718.87
# ...

# %% [markdown]
#     Cross-Section with XS()

# %%
tech.xs('2019-01-02', drop_level=False)
# Out:
#                   month  year  day     open    close     high      low  \
# date       name
# 2019-01-02 MSFT       1  2019    2    99.55   101.12   101.75    98.94
#            FB         1  2019    2   128.99   135.68   137.51   128.56
#            GOOGL      1  2019    2  1027.20  1054.68  1060.79  1025.28
#            AMZN       1  2019    2  1465.20  1539.13  1553.36  1460.93
#            AAPL       1  2019    2   154.89   157.92   158.85   154.23
#
#                     volume volume_type
# date       name
# 2019-01-02 MSFT   35329345      medium
#            FB     28146193      medium
#            GOOGL   1593395      medium
#            AMZN    7983103      medium
#            AAPL   37039737      medium

# %%
tech.xs('FB', level=1, drop_level=False)
# Out:
#                  month  year  day    open   close    high     low    volume  \
# date       name
# 2014-01-02 FB        1  2014    2   54.86   54.71   55.22   54.19  43257622
# 2014-01-03 FB        1  2014    3   55.00   54.56   55.65   54.53  38287706
# 2014-01-06 FB        1  2014    6   54.39   57.20   57.26   54.05  68974359
# 2014-01-07 FB        1  2014    7   57.67   57.92   58.55   57.22  77329009
# 2014-01-08 FB        1  2014    8   57.59   58.23   58.41   57.23  56800776
# ...                ...   ...  ...     ...     ...     ...     ...       ...
# 2019-08-19 FB        8  2019   19  186.01  186.17  187.50  184.85   9699661
# 2019-08-20 FB        8  2019   20  185.45  183.81  186.00  182.39  10087592
# 2019-08-21 FB        8  2019   21  185.00  183.55  185.90  183.14   8409548
# 2019-08-22 FB        8  2019   22  183.43  182.04  184.11  179.91  10829509
# 2019-08-23 FB        8  2019   23  180.84  177.75  183.13  176.66  17331221
#
#                 volume_type
# ...

# %%
tech.xs('FB',level=1, drop_level=False)
# Out:
#                  month  year  day    open   close    high     low    volume  \
# date       name
# 2014-01-02 FB        1  2014    2   54.86   54.71   55.22   54.19  43257622
# 2014-01-03 FB        1  2014    3   55.00   54.56   55.65   54.53  38287706
# 2014-01-06 FB        1  2014    6   54.39   57.20   57.26   54.05  68974359
# 2014-01-07 FB        1  2014    7   57.67   57.92   58.55   57.22  77329009
# 2014-01-08 FB        1  2014    8   57.59   58.23   58.41   57.23  56800776
# ...                ...   ...  ...     ...     ...     ...     ...       ...
# 2019-08-19 FB        8  2019   19  186.01  186.17  187.50  184.85   9699661
# 2019-08-20 FB        8  2019   20  185.45  183.81  186.00  182.39  10087592
# 2019-08-21 FB        8  2019   21  185.00  183.55  185.90  183.14   8409548
# 2019-08-22 FB        8  2019   22  183.43  182.04  184.11  179.91  10829509
# 2019-08-23 FB        8  2019   23  180.84  177.75  183.13  176.66  17331221
#
#                 volume_type
# ...

# %%
tech.xs((('2019-01-02', '2019-01-12'), 'FB'), level=(0,1),axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2019-01-12'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
#     The Anatomy of a Multi-Index Object

# %%
type(tech)
# Out:
# pandas.core.frame.DataFrame

# %%
type(tech.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
tech.index
# Out:
# MultiIndex([('2014-01-02',    'FB'),
#             ('2014-01-02',  'AAPL'),
#             ('2014-01-02', 'GOOGL'),
#             ('2014-01-02',  'MSFT'),
#             ('2014-01-02',  'AMZN'),
#             ('2014-01-03',    'FB'),
#             ('2014-01-03', 'GOOGL'),
#             ('2014-01-03',  'MSFT'),
#             ('2014-01-03',  'AAPL'),
#             ('2014-01-03',  'AMZN'),
#             ...
#             ('2019-08-22',  'MSFT'),
#             ('2019-08-22',    'FB'),
#             ('2019-08-22',  'AMZN'),
#             ('2019-08-22',  'AAPL'),
#             ('2019-08-22', 'GOOGL'),
#             ('2019-08-23',  'MSFT'),
#             ('2019-08-23',  'AAPL'),
#             ('2019-08-23', 'GOOGL'),
#             ('2019-08-23',  'AMZN'),
#             ('2019-08-23',    'FB')],
#            names=['date', 'name'], length=7105)

# %%
tech.index.names
# Out:
# FrozenList(['date', 'name'])

# %%
tech.index.nlevels
# Out:
# 2

# %%
len(tech.index.levels)
# Out:
# 2

# %%
tech.index.levels[0]
# Out:
# DatetimeIndex(['2014-01-02', '2014-01-03', '2014-01-06', '2014-01-07',
#                '2014-01-08', '2014-01-09', '2014-01-10', '2014-01-13',
#                '2014-01-14', '2014-01-15',
#                ...
#                '2019-08-12', '2019-08-13', '2019-08-14', '2019-08-15',
#                '2019-08-16', '2019-08-19', '2019-08-20', '2019-08-21',
#                '2019-08-22', '2019-08-23'],
#               dtype='datetime64[ns]', name='date', length=1421, freq=None)

# %%
tech.index.levels[1]
# Out:
# Index(['AAPL', 'AMZN', 'FB', 'GOOGL', 'MSFT'], dtype='object', name='name')

# %%
tech.index.levshape
# Out:
# (1421, 5)

# %%
tech.index.values
# Out:
# array([(Timestamp('2014-01-02 00:00:00'), 'FB'),
#        (Timestamp('2014-01-02 00:00:00'), 'AAPL'),
#        (Timestamp('2014-01-02 00:00:00'), 'GOOGL'), ...,
#        (Timestamp('2019-08-23 00:00:00'), 'GOOGL'),
#        (Timestamp('2019-08-23 00:00:00'), 'AMZN'),
#        (Timestamp('2019-08-23 00:00:00'), 'FB')], dtype=object)

# %% [markdown]
#     Adding Another Level

# %%
tech
# Out:
#                   month  year  day     open    close     high      low  \
# date       name
# 2014-01-02 FB         1  2014    2    54.86    54.71    55.22    54.19
#            AAPL       1  2014    2    79.38    79.02    79.58    78.86
#            GOOGL      1  2014    2   557.73   556.56   558.88   554.13
#            MSFT       1  2014    2    37.35    37.16    37.40    37.10
#            AMZN       1  2014    2   398.80   397.97   399.36   394.02
# ...                 ...   ...  ...      ...      ...      ...      ...
# 2019-08-23 MSFT       8  2019   23   137.19   133.39   138.35   132.80
#            AAPL       8  2019   23   209.43   202.64   212.05   201.00
#            GOOGL      8  2019   23  1185.17  1153.58  1195.67  1150.00
#            AMZN       8  2019   23  1793.03  1749.62  1804.90  1745.23
#            FB         8  2019   23   180.84   177.75   183.13   176.66
#
#                     volume volume_type
# date       name
# 2014-01-02 FB     43257622      medium
# ...

# %%
tech_3level = tech.set_index('volume_type', append=True)

# %%
tech_3level
# Out:
#                               month  year  day     open    close     high  \
# date       name  volume_type
# 2014-01-02 FB    medium           1  2014    2    54.86    54.71    55.22
#            AAPL  low              1  2014    2    79.38    79.02    79.58
#            GOOGL medium           1  2014    2   557.73   556.56   558.88
#            MSFT  medium           1  2014    2    37.35    37.16    37.40
#            AMZN  medium           1  2014    2   398.80   397.97   399.36
# ...                             ...   ...  ...      ...      ...      ...
# 2019-08-23 MSFT  medium           8  2019   23   137.19   133.39   138.35
#            AAPL  medium           8  2019   23   209.43   202.64   212.05
#            GOOGL medium           8  2019   23  1185.17  1153.58  1195.67
#            AMZN  medium           8  2019   23  1793.03  1749.62  1804.90
#            FB    medium           8  2019   23   180.84   177.75   183.13
#
#                                   low    volume
# ...

# %%
tech_3level.index
# Out:
# MultiIndex([('2014-01-02',    'FB', 'medium'),
#             ('2014-01-02',  'AAPL',    'low'),
#             ('2014-01-02', 'GOOGL', 'medium'),
#             ('2014-01-02',  'MSFT', 'medium'),
#             ('2014-01-02',  'AMZN', 'medium'),
#             ('2014-01-03',    'FB', 'medium'),
#             ('2014-01-03', 'GOOGL', 'medium'),
#             ('2014-01-03',  'MSFT', 'medium'),
#             ('2014-01-03',  'AAPL',    'low'),
#             ('2014-01-03',  'AMZN', 'medium'),
#             ...
#             ('2019-08-22',  'MSFT', 'medium'),
#             ('2019-08-22',    'FB',    'low'),
#             ('2019-08-22',  'AMZN', 'medium'),
#             ('2019-08-22',  'AAPL', 'medium'),
#             ('2019-08-22', 'GOOGL',    'low'),
#             ('2019-08-23',  'MSFT', 'medium'),
#             ('2019-08-23',  'AAPL', 'medium'),
#             ('2019-08-23', 'GOOGL', 'medium'),
#             ('2019-08-23',  'AMZN', 'medium'),
#             ('2019-08-23',    'FB', 'medium')],
# ...

# %%
tech_3level.index.nlevels
# Out:
# 3

# %%
for i in range(2):
  print(tech_3level.index.levels[i])
# Out:
# DatetimeIndex(['2014-01-02', '2014-01-03', '2014-01-06', '2014-01-07',
#                '2014-01-08', '2014-01-09', '2014-01-10', '2014-01-13',
#                '2014-01-14', '2014-01-15',
#                ...
#                '2019-08-12', '2019-08-13', '2019-08-14', '2019-08-15',
#                '2019-08-16', '2019-08-19', '2019-08-20', '2019-08-21',
#                '2019-08-22', '2019-08-23'],
#               dtype='datetime64[ns]', name='date', length=1421, freq=None)
# Index(['AAPL', 'AMZN', 'FB', 'GOOGL', 'MSFT'], dtype='object', name='name')

# %%
tech_3level.loc[(slice('2019-01-01', '2019-01-31'), slice(None), 'high'), :]
# Out:
#                              month  year  day     open    close     high  \
# date       name volume_type
# 2019-01-03 AAPL high             1  2019    3   143.98   142.19   145.72
# 2019-01-04 AMZN high             1  2019    4  1530.00  1575.39  1594.00
# 2019-01-08 AMZN high             1  2019    8  1664.69  1656.58  1676.61
# 2019-01-31 AMZN high             1  2019   31  1692.85  1718.73  1736.41
#            FB   high             1  2019   31   165.60   166.69   171.68
#
#                                  low    volume
# date       name volume_type
# 2019-01-03 AAPL high          142.00  91312195
# 2019-01-04 AMZN high         1518.31   9182575
# 2019-01-08 AMZN high         1616.61   8881428
# 2019-01-31 AMZN high         1679.08  10910338
#            FB   high          165.00  77233602

# %%
tech_3level.loc[(slice('2019-01-01', '2019-01-31'), slice(None), ['high' ,'low']), :]
# Out:
#                              month  year  day     open    close     high  \
# date       name volume_type
# 2019-01-03 AAPL high             1  2019    3   143.98   142.19   145.72
# 2019-01-04 AMZN high             1  2019    4  1530.00  1575.39  1594.00
# 2019-01-08 AMZN high             1  2019    8  1664.69  1656.58  1676.61
# 2019-01-11 FB   low              1  2019   11   143.15   143.80   145.36
# 2019-01-31 AMZN high             1  2019   31  1692.85  1718.73  1736.41
#            FB   high             1  2019   31   165.60   166.69   171.68
#
#                                  low    volume
# date       name volume_type
# 2019-01-03 AAPL high          142.00  91312195
# 2019-01-04 AMZN high         1518.31   9182575
# 2019-01-08 AMZN high         1616.61   8881428
# 2019-01-11 FB   low           142.57  12908031
# 2019-01-31 AMZN high         1679.08  10910338
#            FB   high          165.00  77233602

# %%
tech_3level.index.levels[2]
# Out:
# Index(['high', 'low', 'medium'], dtype='object', name='volume_type')

# %%
tech.xs(level=2, key='high')

# %%
tech_3level.xs(level=2, key= 'high', drop_level=False)
# Out:
#                               month  year  day     open    close     high  \
# date       name  volume_type
# 2014-01-06 FB    high             1  2014    6    54.39    57.20    57.26
# 2014-01-07 FB    high             1  2014    7    57.67    57.92    58.55
# 2014-01-08 FB    high             1  2014    8    57.59    58.23    58.41
# 2014-01-09 FB    high             1  2014    9    58.66    57.22    58.96
# 2014-01-13 FB    high             1  2014   13    57.89    55.91    58.25
# ...                             ...   ...  ...      ...      ...      ...
# 2019-04-30 GOOGL high             4  2019   30  1190.63  1198.96  1200.98
# 2019-06-03 FB    high             6  2019    3   175.00   164.15   175.05
#            AMZN  high             6  2019    3  1760.01  1692.69  1766.29
#            GOOGL high             6  2019    3  1066.93  1038.74  1067.00
# 2019-07-26 GOOGL high             7  2019   26  1228.00  1245.22  1268.39
#
#                                   low    volume
# ...

# %%
tech.xs(level=(2,1), key=('high', 'FB'))

# %%
tech_3level.xs(level=(2,1),key=('high', 'FB'), drop_level=False)
# Out:
#                              month  year  day    open   close    high     low  \
# date       name volume_type
# 2014-01-06 FB   high             1  2014    6   54.39   57.20   57.26   54.05
# 2014-01-07 FB   high             1  2014    7   57.67   57.92   58.55   57.22
# 2014-01-08 FB   high             1  2014    8   57.59   58.23   58.41   57.23
# 2014-01-09 FB   high             1  2014    9   58.66   57.22   58.96   56.65
# 2014-01-13 FB   high             1  2014   13   57.89   55.91   58.25   55.38
# ...                            ...   ...  ...     ...     ...     ...     ...
# 2018-10-31 FB   high            10  2018   31  155.00  151.79  156.40  148.96
# 2018-12-19 FB   high            12  2018   19  141.21  133.24  144.91  132.50
# 2018-12-21 FB   high            12  2018   21  133.39  124.95  134.90  123.42
# 2019-01-31 FB   high             1  2019   31  165.60  166.69  171.68  165.00
# 2019-06-03 FB   high             6  2019    3  175.00  164.15  175.05  161.01
#
# ...

# %%
tech_3level.head()
# Out:
#                               month  year  day    open   close    high  \
# date       name  volume_type
# 2014-01-02 FB    medium           1  2014    2   54.86   54.71   55.22
#            AAPL  low              1  2014    2   79.38   79.02   79.58
#            GOOGL medium           1  2014    2  557.73  556.56  558.88
#            MSFT  medium           1  2014    2   37.35   37.16   37.40
#            AMZN  medium           1  2014    2  398.80  397.97  399.36
#
#                                  low    volume
# date       name  volume_type
# 2014-01-02 FB    medium        54.19  43257622
#            AAPL  low           78.86   8398851
#            GOOGL medium       554.13   1822719
#            MSFT  medium        37.10  30643745
#            AMZN  medium       394.02   2140246

# %%
tech = tech.swaplevel('volume_type', 'name')

# %%
tech_3level.swaplevel(i=1,j=2)
# Out:
#                               month  year  day     open    close     high  \
# date       volume_type name
# 2014-01-02 medium      FB         1  2014    2    54.86    54.71    55.22
#            low         AAPL       1  2014    2    79.38    79.02    79.58
#            medium      GOOGL      1  2014    2   557.73   556.56   558.88
#                        MSFT       1  2014    2    37.35    37.16    37.40
#                        AMZN       1  2014    2   398.80   397.97   399.36
# ...                             ...   ...  ...      ...      ...      ...
# 2019-08-23 medium      MSFT       8  2019   23   137.19   133.39   138.35
#                        AAPL       8  2019   23   209.43   202.64   212.05
#                        GOOGL      8  2019   23  1185.17  1153.58  1195.67
#                        AMZN       8  2019   23  1793.03  1749.62  1804.90
#                        FB         8  2019   23   180.84   177.75   183.13
#
#                                   low    volume
# ...

# %%
tech_3level.swaplevel('volume_type', 'name')
# Out:
#                               month  year  day     open    close     high  \
# date       volume_type name
# 2014-01-02 medium      FB         1  2014    2    54.86    54.71    55.22
#            low         AAPL       1  2014    2    79.38    79.02    79.58
#            medium      GOOGL      1  2014    2   557.73   556.56   558.88
#                        MSFT       1  2014    2    37.35    37.16    37.40
#                        AMZN       1  2014    2   398.80   397.97   399.36
# ...                             ...   ...  ...      ...      ...      ...
# 2019-08-23 medium      MSFT       8  2019   23   137.19   133.39   138.35
#                        AAPL       8  2019   23   209.43   202.64   212.05
#                        GOOGL      8  2019   23  1185.17  1153.58  1195.67
#                        AMZN       8  2019   23  1793.03  1749.62  1804.90
#                        FB         8  2019   23   180.84   177.75   183.13
#
#                                   low    volume
# ...

# %%
tech_3level.head()
# Out:
#                               month  year  day    open   close    high  \
# volume_type name  date
# medium      FB    2014-01-02      1  2014    2   54.86   54.71   55.22
# low         AAPL  2014-01-02      1  2014    2   79.38   79.02   79.58
# medium      GOOGL 2014-01-02      1  2014    2  557.73  556.56  558.88
#             MSFT  2014-01-02      1  2014    2   37.35   37.16   37.40
#             AMZN  2014-01-02      1  2014    2  398.80  397.97  399.36
#
#                                  low    volume
# volume_type name  date
# medium      FB    2014-01-02   54.19  43257622
# low         AAPL  2014-01-02   78.86   8398851
# medium      GOOGL 2014-01-02  554.13   1822719
#             MSFT  2014-01-02   37.10  30643745
#             AMZN  2014-01-02  394.02   2140246

# %%
tech_3level=tech_3level.swaplevel(i=2, j=0)

# %%
tech_3level.reorder_levels([2,1,0])
# Out:
#                               month  year  day     open    close     high  \
# date       name  volume_type
# 2014-01-02 FB    medium           1  2014    2    54.86    54.71    55.22
#            AAPL  low              1  2014    2    79.38    79.02    79.58
#            GOOGL medium           1  2014    2   557.73   556.56   558.88
#            MSFT  medium           1  2014    2    37.35    37.16    37.40
#            AMZN  medium           1  2014    2   398.80   397.97   399.36
# ...                             ...   ...  ...      ...      ...      ...
# 2019-08-23 MSFT  medium           8  2019   23   137.19   133.39   138.35
#            AAPL  medium           8  2019   23   209.43   202.64   212.05
#            GOOGL medium           8  2019   23  1185.17  1153.58  1195.67
#            AMZN  medium           8  2019   23  1793.03  1749.62  1804.90
#            FB    medium           8  2019   23   180.84   177.75   183.13
#
#                                   low    volume
# ...

# %% [markdown]
#     Removing Multi-index

# %%
# - df.droplevel()
# - df.reset_index(drop=bool)

# %%
tech_3level.droplevel(1)
# Out:
#                         month  year  day     open    close     high      low  \
# volume_type date
# medium      2014-01-02      1  2014    2    54.86    54.71    55.22    54.19
# low         2014-01-02      1  2014    2    79.38    79.02    79.58    78.86
# medium      2014-01-02      1  2014    2   557.73   556.56   558.88   554.13
#             2014-01-02      1  2014    2    37.35    37.16    37.40    37.10
#             2014-01-02      1  2014    2   398.80   397.97   399.36   394.02
# ...                       ...   ...  ...      ...      ...      ...      ...
#             2019-08-23      8  2019   23   137.19   133.39   138.35   132.80
#             2019-08-23      8  2019   23   209.43   202.64   212.05   201.00
#             2019-08-23      8  2019   23  1185.17  1153.58  1195.67  1150.00
#             2019-08-23      8  2019   23  1793.03  1749.62  1804.90  1745.23
#             2019-08-23      8  2019   23   180.84   177.75   183.13   176.66
#
# ...

# %%
tech_3level.reset_index(level=1, drop=False)
# Out:
#                          name  month  year  day     open    close     high  \
# volume_type date
# medium      2014-01-02     FB      1  2014    2    54.86    54.71    55.22
# low         2014-01-02   AAPL      1  2014    2    79.38    79.02    79.58
# medium      2014-01-02  GOOGL      1  2014    2   557.73   556.56   558.88
#             2014-01-02   MSFT      1  2014    2    37.35    37.16    37.40
#             2014-01-02   AMZN      1  2014    2   398.80   397.97   399.36
# ...                       ...    ...   ...  ...      ...      ...      ...
#             2019-08-23   MSFT      8  2019   23   137.19   133.39   138.35
#             2019-08-23   AAPL      8  2019   23   209.43   202.64   212.05
#             2019-08-23  GOOGL      8  2019   23  1185.17  1153.58  1195.67
#             2019-08-23   AMZN      8  2019   23  1793.03  1749.62  1804.90
#             2019-08-23     FB      8  2019   23   180.84   177.75   183.13
#
#                             low    volume
# ...

# %%
tech_3level.reset_index(level=1, drop=True)
# Out:
#                         month  year  day     open    close     high      low  \
# volume_type date
# medium      2014-01-02      1  2014    2    54.86    54.71    55.22    54.19
# low         2014-01-02      1  2014    2    79.38    79.02    79.58    78.86
# medium      2014-01-02      1  2014    2   557.73   556.56   558.88   554.13
#             2014-01-02      1  2014    2    37.35    37.16    37.40    37.10
#             2014-01-02      1  2014    2   398.80   397.97   399.36   394.02
# ...                       ...   ...  ...      ...      ...      ...      ...
#             2019-08-23      8  2019   23   137.19   133.39   138.35   132.80
#             2019-08-23      8  2019   23   209.43   202.64   212.05   201.00
#             2019-08-23      8  2019   23  1185.17  1153.58  1195.67  1150.00
#             2019-08-23      8  2019   23  1793.03  1749.62  1804.90  1745.23
#             2019-08-23      8  2019   23   180.84   177.75   183.13   176.66
#
# ...

# %%
tech_3level.head()
# Out:
#                               month  year  day    open   close    high  \
# volume_type name  date
# medium      FB    2014-01-02      1  2014    2   54.86   54.71   55.22
# low         AAPL  2014-01-02      1  2014    2   79.38   79.02   79.58
# medium      GOOGL 2014-01-02      1  2014    2  557.73  556.56  558.88
#             MSFT  2014-01-02      1  2014    2   37.35   37.16   37.40
#             AMZN  2014-01-02      1  2014    2  398.80  397.97  399.36
#
#                                  low    volume
# volume_type name  date
# medium      FB    2014-01-02   54.19  43257622
# low         AAPL  2014-01-02   78.86   8398851
# medium      GOOGL 2014-01-02  554.13   1822719
#             MSFT  2014-01-02   37.10  30643745
#             AMZN  2014-01-02  394.02   2140246

# %%
tech_3level.droplevel(level=(0,1))
# Out:
#             month  year  day     open    close     high      low    volume
# date
# 2014-01-02      1  2014    2    54.86    54.71    55.22    54.19  43257622
# 2014-01-02      1  2014    2    79.38    79.02    79.58    78.86   8398851
# 2014-01-02      1  2014    2   557.73   556.56   558.88   554.13   1822719
# 2014-01-02      1  2014    2    37.35    37.16    37.40    37.10  30643745
# 2014-01-02      1  2014    2   398.80   397.97   399.36   394.02   2140246
# ...           ...   ...  ...      ...      ...      ...      ...       ...
# 2019-08-23      8  2019   23   137.19   133.39   138.35   132.80  38515386
# 2019-08-23      8  2019   23   209.43   202.64   212.05   201.00  46882843
# 2019-08-23      8  2019   23  1185.17  1153.58  1195.67  1150.00   1813141
# 2019-08-23      8  2019   23  1793.03  1749.62  1804.90  1745.23   5277898
# 2019-08-23      8  2019   23   180.84   177.75   183.13   176.66  17331221
#
# [7105 rows x 8 columns]

# %%
tech_3level.droplevel(['volume_type', 'name'])
# Out:
#             month  year  day     open    close     high      low    volume
# date
# 2014-01-02      1  2014    2    54.86    54.71    55.22    54.19  43257622
# 2014-01-02      1  2014    2    79.38    79.02    79.58    78.86   8398851
# 2014-01-02      1  2014    2   557.73   556.56   558.88   554.13   1822719
# 2014-01-02      1  2014    2    37.35    37.16    37.40    37.10  30643745
# 2014-01-02      1  2014    2   398.80   397.97   399.36   394.02   2140246
# ...           ...   ...  ...      ...      ...      ...      ...       ...
# 2019-08-23      8  2019   23   137.19   133.39   138.35   132.80  38515386
# 2019-08-23      8  2019   23   209.43   202.64   212.05   201.00  46882843
# 2019-08-23      8  2019   23  1185.17  1153.58  1195.67  1150.00   1813141
# 2019-08-23      8  2019   23  1793.03  1749.62  1804.90  1745.23   5277898
# 2019-08-23      8  2019   23   180.84   177.75   183.13   176.66  17331221
#
# [7105 rows x 8 columns]

# %%
tech_3level.reset_index(level=(0,1), drop=True)
# Out:
#             month  year  day     open    close     high      low    volume
# date
# 2014-01-02      1  2014    2    54.86    54.71    55.22    54.19  43257622
# 2014-01-02      1  2014    2    79.38    79.02    79.58    78.86   8398851
# 2014-01-02      1  2014    2   557.73   556.56   558.88   554.13   1822719
# 2014-01-02      1  2014    2    37.35    37.16    37.40    37.10  30643745
# 2014-01-02      1  2014    2   398.80   397.97   399.36   394.02   2140246
# ...           ...   ...  ...      ...      ...      ...      ...       ...
# 2019-08-23      8  2019   23   137.19   133.39   138.35   132.80  38515386
# 2019-08-23      8  2019   23   209.43   202.64   212.05   201.00  46882843
# 2019-08-23      8  2019   23  1185.17  1153.58  1195.67  1150.00   1813141
# 2019-08-23      8  2019   23  1793.03  1749.62  1804.90  1745.23   5277898
# 2019-08-23      8  2019   23   180.84   177.75   183.13   176.66  17331221
#
# [7105 rows x 8 columns]

# %%
tech_3level.reset_index(level=['volume_type', 'name'])
# Out:
#            volume_type   name  month  year  day     open    close     high  \
# date
# 2014-01-02      medium     FB      1  2014    2    54.86    54.71    55.22
# 2014-01-02         low   AAPL      1  2014    2    79.38    79.02    79.58
# 2014-01-02      medium  GOOGL      1  2014    2   557.73   556.56   558.88
# 2014-01-02      medium   MSFT      1  2014    2    37.35    37.16    37.40
# 2014-01-02      medium   AMZN      1  2014    2   398.80   397.97   399.36
# ...                ...    ...    ...   ...  ...      ...      ...      ...
# 2019-08-23      medium   MSFT      8  2019   23   137.19   133.39   138.35
# 2019-08-23      medium   AAPL      8  2019   23   209.43   202.64   212.05
# 2019-08-23      medium  GOOGL      8  2019   23  1185.17  1153.58  1195.67
# 2019-08-23      medium   AMZN      8  2019   23  1793.03  1749.62  1804.90
# 2019-08-23      medium     FB      8  2019   23   180.84   177.75   183.13
#
#                 low    volume
# date
# ...

# %% [markdown]
#     Multi-Index Sort_Index

# %%
tech.loc[(slice('2014-01-02', '2014-04-02'), slice(None), 'AAPL'), 'open':'low']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 tech.loc[(slice('2014-01-02', '2014-04-02'), slice(None), 'AAPL'), 'open':'low']
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1280, in _LocIndexer._getitem_tuple(self, tup)
#    1278 with suppress(IndexingError):
#    1279     tup = self._expand_ellipsis(tup)
# -> 1280     return self._getitem_lowerdim(tup)
#    1282 # no multi-index, so validate all of the indexers
# ...

# %%
tech_3level = tech_3level.reorder_levels([2,0,1])

# %%
tech_3level
# Out:
#                               month  year  day     open    close     high  \
# date       volume_type name
# 2014-01-02 medium      FB         1  2014    2    54.86    54.71    55.22
#            low         AAPL       1  2014    2    79.38    79.02    79.58
#            medium      GOOGL      1  2014    2   557.73   556.56   558.88
#                        MSFT       1  2014    2    37.35    37.16    37.40
#                        AMZN       1  2014    2   398.80   397.97   399.36
# ...                             ...   ...  ...      ...      ...      ...
# 2019-08-23 medium      MSFT       8  2019   23   137.19   133.39   138.35
#                        AAPL       8  2019   23   209.43   202.64   212.05
#                        GOOGL      8  2019   23  1185.17  1153.58  1195.67
#                        AMZN       8  2019   23  1793.03  1749.62  1804.90
#                        FB         8  2019   23   180.84   177.75   183.13
#
#                                   low    volume
# ...

# %%
tech_3level.loc[(slice('2014-01-02', '2014-04-02'), slice(None), 'AAPL'), 'open':'low']
# Out:
#                               open  close   high    low
# date       volume_type name
# 2014-01-02 low         AAPL  79.38  79.02  79.58  78.86
# 2014-01-03 low         AAPL  79.00  77.28  79.10  77.20
# 2014-01-06 low         AAPL  76.78  77.70  78.11  76.23
# 2014-01-07 low         AAPL  77.76  77.15  77.99  76.85
# 2014-01-08 low         AAPL  76.97  77.64  77.94  76.96
# ...                            ...    ...    ...    ...
# 2014-03-27 low         AAPL  77.11  76.78  77.36  76.45
# 2014-03-28 low         AAPL  76.82  76.69  76.99  76.32
# 2014-03-31 low         AAPL  77.03  76.68  77.26  76.56
# 2014-04-01 low         AAPL  76.84  77.38  77.41  76.68
# 2014-04-02 low         AAPL  77.48  77.51  77.64  77.18
#
# [63 rows x 4 columns]

# %%
tech_3level.sort_index(inplace=True)

# %%
tech_3level
# Out:
#                               month  year  day     open    close     high  \
# date       volume_type name
# 2014-01-02 low         AAPL       1  2014    2    79.38    79.02    79.58
#            medium      AMZN       1  2014    2   398.80   397.97   399.36
#                        FB         1  2014    2    54.86    54.71    55.22
#                        GOOGL      1  2014    2   557.73   556.56   558.88
#                        MSFT       1  2014    2    37.35    37.16    37.40
# ...                             ...   ...  ...      ...      ...      ...
# 2019-08-23 medium      AAPL       8  2019   23   209.43   202.64   212.05
#                        AMZN       8  2019   23  1793.03  1749.62  1804.90
#                        FB         8  2019   23   180.84   177.75   183.13
#                        GOOGL      8  2019   23  1185.17  1153.58  1195.67
#                        MSFT       8  2019   23   137.19   133.39   138.35
#
#                                   low    volume
# ...

# %%
# tech.loc[(slice('2014-01-02', '2014-04-02'), slice(None), slice('AAPL','FB')), 'open':'low']

# %%
tech_3level.loc[(slice(None),slice(None), slice('AAPL', 'FB')),'open':'low']
# Out:
#                                 open    close     high      low
# date       volume_type name
# 2014-01-02 low         AAPL    79.38    79.02    79.58    78.86
#            medium      AMZN   398.80   397.97   399.36   394.02
#                        FB      54.86    54.71    55.22    54.19
# 2014-01-03 low         AAPL    79.00    77.28    79.10    77.20
#            medium      AMZN   398.29   396.44   402.71   396.22
# ...                              ...      ...      ...      ...
# 2019-08-22 medium      AAPL   213.19   212.46   214.44   210.75
#                        AMZN  1828.00  1805.60  1829.41  1800.10
# 2019-08-23 medium      AAPL   209.43   202.64   212.05   201.00
#                        AMZN  1793.03  1749.62  1804.90  1745.23
#                        FB     180.84   177.75   183.13   176.66
#
# [4263 rows x 4 columns]

# %%
tech_3level.sort_index(level = (0,2), ascending = [False, True] )
# Out:
#                               month  year  day     open    close     high  \
# date       volume_type name
# 2019-08-23 medium      AAPL       8  2019   23   209.43   202.64   212.05
#                        AMZN       8  2019   23  1793.03  1749.62  1804.90
#                        FB         8  2019   23   180.84   177.75   183.13
#                        GOOGL      8  2019   23  1185.17  1153.58  1195.67
#                        MSFT       8  2019   23   137.19   133.39   138.35
# ...                             ...   ...  ...      ...      ...      ...
# 2014-01-02 low         AAPL       1  2014    2    79.38    79.02    79.58
#            medium      AMZN       1  2014    2   398.80   397.97   399.36
#                        FB         1  2014    2    54.86    54.71    55.22
#                        GOOGL      1  2014    2   557.73   556.56   558.88
#                        MSFT       1  2014    2    37.35    37.16    37.40
#
#                                   low    volume
# ...

# %% [markdown]
#     More Multi-Dimensional Index

# %%
tidx = tech.index

# %%
tidx = tech_3level.index

# %%
tidx
# Out:
# MultiIndex([('2014-01-02', 'medium',    'FB'),
#             ('2014-01-02',    'low',  'AAPL'),
#             ('2014-01-02', 'medium', 'GOOGL'),
#             ('2014-01-02', 'medium',  'MSFT'),
#             ('2014-01-02', 'medium',  'AMZN'),
#             ('2014-01-03', 'medium',    'FB'),
#             ('2014-01-03', 'medium', 'GOOGL'),
#             ('2014-01-03', 'medium',  'MSFT'),
#             ('2014-01-03',    'low',  'AAPL'),
#             ('2014-01-03', 'medium',  'AMZN'),
#             ...
#             ('2019-08-22', 'medium',  'MSFT'),
#             ('2019-08-22',    'low',    'FB'),
#             ('2019-08-22', 'medium',  'AMZN'),
#             ('2019-08-22', 'medium',  'AAPL'),
#             ('2019-08-22',    'low', 'GOOGL'),
#             ('2019-08-23', 'medium',  'MSFT'),
#             ('2019-08-23', 'medium',  'AAPL'),
#             ('2019-08-23', 'medium', 'GOOGL'),
#             ('2019-08-23', 'medium',  'AMZN'),
#             ('2019-08-23', 'medium',    'FB')],
# ...

# %%
tidx.sortlevel(0, ascending=False, sort_remaining=True)
# Out:
# (MultiIndex([('2019-08-23', 'medium',  'MSFT'),
#              ('2019-08-23', 'medium', 'GOOGL'),
#              ('2019-08-23', 'medium',    'FB'),
#              ('2019-08-23', 'medium',  'AMZN'),
#              ('2019-08-23', 'medium',  'AAPL'),
#              ('2019-08-22', 'medium',  'MSFT'),
#              ('2019-08-22', 'medium',  'AMZN'),
#              ('2019-08-22', 'medium',  'AAPL'),
#              ('2019-08-22',    'low', 'GOOGL'),
#              ('2019-08-22',    'low',    'FB'),
#              ...
#              ('2014-01-03', 'medium',  'MSFT'),
#              ('2014-01-03', 'medium', 'GOOGL'),
#              ('2014-01-03', 'medium',    'FB'),
#              ('2014-01-03', 'medium',  'AMZN'),
#              ('2014-01-03',    'low',  'AAPL'),
#              ('2014-01-02', 'medium',  'MSFT'),
#              ('2014-01-02', 'medium', 'GOOGL'),
#              ('2014-01-02', 'medium',    'FB'),
#              ('2014-01-02', 'medium',  'AMZN'),
# ...

# %%
tidx.sortlevel((0,1,2), ascending=[True, True, False])
# Out:
# (MultiIndex([('2014-01-02',    'low',  'AAPL'),
#              ('2014-01-02', 'medium',  'MSFT'),
#              ('2014-01-02', 'medium', 'GOOGL'),
#              ('2014-01-02', 'medium',    'FB'),
#              ('2014-01-02', 'medium',  'AMZN'),
#              ('2014-01-03',    'low',  'AAPL'),
#              ('2014-01-03', 'medium',  'MSFT'),
#              ('2014-01-03', 'medium', 'GOOGL'),
#              ('2014-01-03', 'medium',    'FB'),
#              ('2014-01-03', 'medium',  'AMZN'),
#              ...
#              ('2019-08-22',    'low', 'GOOGL'),
#              ('2019-08-22',    'low',    'FB'),
#              ('2019-08-22', 'medium',  'MSFT'),
#              ('2019-08-22', 'medium',  'AMZN'),
#              ('2019-08-22', 'medium',  'AAPL'),
#              ('2019-08-23', 'medium',  'MSFT'),
#              ('2019-08-23', 'medium', 'GOOGL'),
#              ('2019-08-23', 'medium',    'FB'),
#              ('2019-08-23', 'medium',  'AMZN'),
# ...

# %%
tidx.set_names(['Trading Date', 'Volume Category', 'Ticker'], inplace=True)

# %%
# suppose if i want to only change the 'Trading Date' not others
# df.index.set_names(names = 'Date', level=0)
# df.index.set_names(names = 'Date', level = 'Trading Date', inplace=True)

# %%
tidx.set_names(['Trading_Date', 'Volume_Category', 'Ticker'], inplace = True)

# %%
tech_3level
# Out:
#                                      month  year  day     open    close  \
# Trading_Date Volume_Category Ticker
# 2014-01-02   medium          FB          1  2014    2    54.86    54.71
#              low             AAPL        1  2014    2    79.38    79.02
#              medium          GOOGL       1  2014    2   557.73   556.56
#                              MSFT        1  2014    2    37.35    37.16
#                              AMZN        1  2014    2   398.80   397.97
# ...                                    ...   ...  ...      ...      ...
# 2019-08-23   medium          MSFT        8  2019   23   137.19   133.39
#                              AAPL        8  2019   23   209.43   202.64
#                              GOOGL       8  2019   23  1185.17  1153.58
#                              AMZN        8  2019   23  1793.03  1749.62
#                              FB          8  2019   23   180.84   177.75
#
#                                         high      low    volume
# ...

# %%
tech_3level
# Out:
#                                      month  year  day     open    close  \
# Trading_Date Volume_Category Ticker
# 2014-01-02   medium          FB          1  2014    2    54.86    54.71
#              low             AAPL        1  2014    2    79.38    79.02
#              medium          GOOGL       1  2014    2   557.73   556.56
#                              MSFT        1  2014    2    37.35    37.16
#                              AMZN        1  2014    2   398.80   397.97
# ...                                    ...   ...  ...      ...      ...
# 2019-08-23   medium          MSFT        8  2019   23   137.19   133.39
#                              AAPL        8  2019   23   209.43   202.64
#                              GOOGL       8  2019   23  1185.17  1153.58
#                              AMZN        8  2019   23  1793.03  1749.62
#                              FB          8  2019   23   180.84   177.75
#
#                                         high      low    volume
# ...

# %%
tech_stack = tech_3level.stack()

# %%
type(tech_stack)
# Out:
# pandas.core.series.Series

# %%
tech_stack.index.nlevels
# Out:
# 4

# %%
names = tech_stack.index.names

# %%
names
# Out:
# FrozenList(['Trading_Date', 'Volume_Category', 'Ticker', None])

# %%
tech_stack.index.set_names([*names[:-1],'Previously a Column Axis'], inplace=True )

# %%
tech_stack
# Out:
# Trading_Date  Volume_Category  Ticker  Previously a Column Axis
# 2014-01-02    medium           FB      month                              1.00
#                                        year                            2014.00
#                                        day                                2.00
#                                        open                              54.86
#                                        close                             54.71
#                                                                       ...
# 2019-08-23    medium           FB      open                             180.84
#                                        close                            177.75
#                                        high                             183.13
#                                        low                              176.66
#                                        volume                      17331221.00
# Length: 56840, dtype: float64

# %%
tech_stack.unstack(-1)
# Out:
# Previously a Column Axis             month    year   day     open    close  \
# Trading_Date Volume_Category Ticker
# 2014-01-02   low             AAPL      1.0  2014.0   2.0    79.38    79.02
#              medium          AMZN      1.0  2014.0   2.0   398.80   397.97
#                              FB        1.0  2014.0   2.0    54.86    54.71
#                              GOOGL     1.0  2014.0   2.0   557.73   556.56
#                              MSFT      1.0  2014.0   2.0    37.35    37.16
# ...                                    ...     ...   ...      ...      ...
# 2019-08-23   medium          AAPL      8.0  2019.0  23.0   209.43   202.64
#                              AMZN      8.0  2019.0  23.0  1793.03  1749.62
#                              FB        8.0  2019.0  23.0   180.84   177.75
#                              GOOGL     8.0  2019.0  23.0  1185.17  1153.58
#                              MSFT      8.0  2019.0  23.0   137.19   133.39
#
# ...

# %%
tech_3level.unstack(-1, fill_value='-')
# Out:
#                              month                     year                    \
# Ticker                        AAPL AMZN FB GOOGL MSFT  AAPL  AMZN    FB GOOGL
# Trading_Date Volume_Category
# 2014-01-02   low                 1    -  -     -    -  2014     -     -     -
#              medium              -    1  1     1    1     -  2014  2014  2014
# 2014-01-03   low                 1    -  -     -    -  2014     -     -     -
#              medium              -    1  1     1    1     -  2014  2014  2014
# 2014-01-06   high                -    -  1     -    -     -     -  2014     -
# ...                            ...  ... ..   ...  ...   ...   ...   ...   ...
# 2019-08-21   low                 -    8  8     8    8     -  2019  2019  2019
#              medium              8    -  -     -    -  2019     -     -     -
# 2019-08-22   low                 -    -  8     8    -     -     -  2019  2019
#              medium              8    8  -     -    8  2019  2019     -     -
# ...

# %%
tech_stack.unstack(-2, fill_value='-')
# Out:
# Ticker                                                       AAPL       AMZN  \
# Trading_Date Volume_Category Previously a Column Axis
# 2014-01-02   low             month                            1.0          -
#                              year                          2014.0          -
#                              day                              2.0          -
#                              open                           79.38          -
#                              close                          79.02          -
# ...                                                           ...        ...
# 2019-08-23   medium          open                          209.43    1793.03
#                              close                         202.64    1749.62
#                              high                          212.05     1804.9
#                              low                            201.0    1745.23
# ...

# %%
df = tech.reset_index()

# %%
df
# Out:
#            date   name  month  year  day     open    close     high      low  \
# 0    2014-01-02     FB      1  2014    2    54.86    54.71    55.22    54.19
# 1    2014-01-02   AAPL      1  2014    2    79.38    79.02    79.58    78.86
# 2    2014-01-02  GOOGL      1  2014    2   557.73   556.56   558.88   554.13
# 3    2014-01-02   MSFT      1  2014    2    37.35    37.16    37.40    37.10
# 4    2014-01-02   AMZN      1  2014    2   398.80   397.97   399.36   394.02
# ...         ...    ...    ...   ...  ...      ...      ...      ...      ...
# 7100 2019-08-23   MSFT      8  2019   23   137.19   133.39   138.35   132.80
# 7101 2019-08-23   AAPL      8  2019   23   209.43   202.64   212.05   201.00
# 7102 2019-08-23  GOOGL      8  2019   23  1185.17  1153.58  1195.67  1150.00
# 7103 2019-08-23   AMZN      8  2019   23  1793.03  1749.62  1804.90  1745.23
# 7104 2019-08-23     FB      8  2019   23   180.84   177.75   183.13   176.66
#
#         volume volume_type
# ...

# %%
df = df.set_index(['year', 'month', 'day'])

# %%
df
# Out:
#                      date   name     open    close     high      low  \
# year month day
# 2014 1     2   2014-01-02     FB    54.86    54.71    55.22    54.19
#            2   2014-01-02   AAPL    79.38    79.02    79.58    78.86
#            2   2014-01-02  GOOGL   557.73   556.56   558.88   554.13
#            2   2014-01-02   MSFT    37.35    37.16    37.40    37.10
#            2   2014-01-02   AMZN   398.80   397.97   399.36   394.02
# ...                   ...    ...      ...      ...      ...      ...
# 2019 8     23  2019-08-23   MSFT   137.19   133.39   138.35   132.80
#            23  2019-08-23   AAPL   209.43   202.64   212.05   201.00
#            23  2019-08-23  GOOGL  1185.17  1153.58  1195.67  1150.00
#            23  2019-08-23   AMZN  1793.03  1749.62  1804.90  1745.23
#            23  2019-08-23     FB   180.84   177.75   183.13   176.66
#
#                   volume volume_type
# year month day
# 2014 1     2    43257622      medium
# ...

# %%
df.loc['2019', ]
# Out:
#                 date   name     open    close     high      low    volume  \
# month day
# 1     2   2019-01-02   MSFT    99.55   101.12   101.75    98.94  35329345
#       2   2019-01-02     FB   128.99   135.68   137.51   128.56  28146193
#       2   2019-01-02  GOOGL  1027.20  1054.68  1060.79  1025.28   1593395
#       2   2019-01-02   AMZN  1465.20  1539.13  1553.36  1460.93   7983103
#       2   2019-01-02   AAPL   154.89   157.92   158.85   154.23  37039737
# ...              ...    ...      ...      ...      ...      ...       ...
# 8     23  2019-08-23   MSFT   137.19   133.39   138.35   132.80  38515386
#       23  2019-08-23   AAPL   209.43   202.64   212.05   201.00  46882843
#       23  2019-08-23  GOOGL  1185.17  1153.58  1195.67  1150.00   1813141
#       23  2019-08-23   AMZN  1793.03  1749.62  1804.90  1745.23   5277898
#       23  2019-08-23     FB   180.84   177.75   183.13   176.66  17331221
#
#           volume_type
# month day
# 1     2        medium
# ...

# %%
df.loc[(2019, slice(None), slice(None))]
# Out:
#                 date   name     open    close     high      low    volume  \
# month day
# 1     2   2019-01-02   MSFT    99.55   101.12   101.75    98.94  35329345
#       2   2019-01-02     FB   128.99   135.68   137.51   128.56  28146193
#       2   2019-01-02  GOOGL  1027.20  1054.68  1060.79  1025.28   1593395
#       2   2019-01-02   AMZN  1465.20  1539.13  1553.36  1460.93   7983103
#       2   2019-01-02   AAPL   154.89   157.92   158.85   154.23  37039737
# ...              ...    ...      ...      ...      ...      ...       ...
# 8     23  2019-08-23   MSFT   137.19   133.39   138.35   132.80  38515386
#       23  2019-08-23   AAPL   209.43   202.64   212.05   201.00  46882843
#       23  2019-08-23  GOOGL  1185.17  1153.58  1195.67  1150.00   1813141
#       23  2019-08-23   AMZN  1793.03  1749.62  1804.90  1745.23   5277898
#       23  2019-08-23     FB   180.84   177.75   183.13   176.66  17331221
#
#           volume_type
# month day
# 1     2        medium
# ...

# %%
df_stack = df.loc[(2019, slice(None), slice(None))].stack()

# %%
df_stack.head(20)
# Out:
# month  day
# 1      2    date           2019-01-02 00:00:00
#             name                          MSFT
#             open                         99.55
#             close                       101.12
#             high                        101.75
#             low                          98.94
#             volume                    35329345
#             volume_type                 medium
#             date           2019-01-02 00:00:00
#             name                            FB
#             open                        128.99
#             close                       135.68
#             high                        137.51
#             low                         128.56
#             volume                    28146193
#             volume_type                 medium
#             date           2019-01-02 00:00:00
#             name                         GOOGL
#             open                        1027.2
#             close                      1054.68
# ...

# %%
df_stack.index.nlevels
# Out:
# 3
