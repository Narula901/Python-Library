# %%
# Import Different library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Data = pd.read_csv('D:\Data for Preprocessing\Reviews.csv')

# %%
Data
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %%
Data['Time']
# Out:
# 0         1303862400
# 1         1346976000
# 2         1219017600
# 3         1307923200
# 4         1350777600
#              ...
# 568449    1299628800
# 568450    1331251200
# 568451    1329782400
# 568452    1331596800
# 568453    1338422400
# Name: Time, Length: 568454, dtype: int64

# %%
Data['Time'] = pd.to_datetime(Data['Time'], unit = 's')

# %%
Data
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %%
Prod_count =  data['ProductId'].value_counts(ascending=False).to_frame()

# %%
Prod_count = Data['ProductId'].value_counts(ascending=False)

# %%
Prod_count = Prod_count.reset_index().rename(columns={'index': 'Product_ID'})

# %%
Prod_count.drop(columns='level_0', inplace = True)

# %%
Prod_count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74258 entries, 0 to 74257
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product_ID  74258 non-null  object
#  1   ProductId   74258 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 1.1+ MB

# %%
x = Data['UserId'].value_counts()

# %%
x
# Out:
# A3OXHLG6DIBRW8    448
# A1YUL9PCJR3JTY    421
# AY12DBB0U420B     389
# A281NPSIMI1C2R    365
# A1Z54EM24Y40LL    256
#                  ...
# A2O8OFVSTO9PF3      1
# A1C6KXG47GAQ7B      1
# A1TU5DS89D9OVD      1
# A3N005JS5FG5FI      1
# A3LGQPJCZVL9UC      1
# Name: UserId, Length: 256059, dtype: int64

# %%
x['A1YUL9PCJR3JTY']
# Out:
# 421

# %%
Data['viewer_type'] = Data['UserId'].apply(lambda user : "Frequent" if x[user]>=50 else "Not Frequent")

# %%
"Frequent" if x['A2O8OFVSTO9PF3'] > 50 else "Not Frequent"
# Out:
# 'Not Frequent'

# %%
Data['Viewer_type']= Data['UserId'].apply(lambda user : "Frequent" if x[user] > 50 else "Not Frequent")

# %%
Data
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %%
Data['Text_Length'] = Data['Text'].str.split(' ').str.len()

# %%
Data
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %%
Data['Text'].str.split(' ').str.len()
# Out:
# 0         49
# 1         31
# 2         99
# 3         43
# 4         30
#           ..
# 568449    26
# 568450    46
# 568451    71
# 568452    37
# 568453    21
# Name: Text, Length: 568454, dtype: int64

# %%
len(Data['Text'][0].split(' '))
# Out:
# 49

# %%
Data['Text'][0]
# Out:
# 'I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labrador is finicky and she appreciates this product better than  most.'

# %%
Data['Text'][0].split(' ')
# Out:
# ['I',
#  'have',
#  'bought',
#  'several',
#  'of',
#  'the',
#  'Vitality',
#  'canned',
#  'dog',
#  'food',
#  'products',
#  'and',
#  'have',
#  'found',
#  'them',
#  'all',
#  'to',
#  'be',
#  'of',
#  'good',
#  'quality.',
#  'The',
#  'product',
#  'looks',
#  'more',
#  'like',
#  'a',
#  'stew',
#  'than',
#  'a',
#  'processed',
#  'meat',
#  'and',
#  'it',
#  'smells',
#  'better.',
#  'My',
#  'Labrador',
#  'is',
#  'finicky',
#  'and',
#  'she',
#  'appreciates',
#  'this',
#  'product',
#  'better',
#  'than',
#  '',
#  'most.']

# %%
Data['Text_Length'][0]
# Out:
# 263
