# %%
match_data['toss_winner'].value_counts(ascending=False)[0:5].index

# %%
match_data['toss_winner'].value_counts(ascending=False)[0:5].index[0]
# Out:
# 'Mumbai Indians'

# %%
match_data['Checking_Con'] = match_data.apply(lambda row:'Yes' if row['toss_winner'] == row['winner']else 'No', axis =1)

# %%
match_data.apply(lambda row: 'Yes' if row['toss_winner']== row['winner']else 'No', axis = 1)
# Out:
# 0       No
# 1      Yes
# 2       No
# 3       No
# 4       No
#       ...
# 811     No
# 812     No
# 813    Yes
# 814    Yes
# 815     No
# Length: 816, dtype: object

# %%
match_data[match_data['Year'] == 2008].sort_values(by = 'date').tail(1)['toss_winner'].values[0]

# %%
winners_team = {}

for year in sorted(match_data['Year'].unique()):
     current_yr_df = match_data[match_data['Year'] == year]
     winners_team[year] = current_yr_df.tail(1)['winner'].values[0]

# %%
winners_team
# Out:
# {2008: 'Rajasthan Royals',
#  2009: 'Deccan Chargers',
#  2010: 'Chennai Super Kings',
#  2011: 'Chennai Super Kings',
#  2012: 'Kolkata Knight Riders',
#  2013: 'Mumbai Indians',
#  2014: 'Kolkata Knight Riders',
#  2015: 'Mumbai Indians',
#  2016: 'Sunrisers Hyderabad',
#  2017: 'Mumbai Indians',
#  2018: 'Chennai Super Kings',
#  2019: 'Mumbai Indians',
#  2020: 'Mumbai Indians'}

# %%
match_data
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 811  1216547       Dubai 2020-09-28  AB de Villiers
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
T_M = match_data['team1'].value_counts() + match_data['team2'].value_counts()

# %%
T_M
# Out:
# Chennai Super Kings            178
# Deccan Chargers                 75
# Delhi Capitals                  33
# Delhi Daredevils               161
# Gujarat Lions                   30
# Kings XI Punjab                190
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          192
# Mumbai Indians                 203
# Pune Warriors                   46
# Rajasthan Royals               161
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    195
# Sunrisers Hyderabad            124
# dtype: int64

# %%
match_data['team2'].value_counts() + match_data['team1'].value_counts()
# Out:
# Chennai Super Kings            178
# Deccan Chargers                 75
# Delhi Capitals                  33
# Delhi Daredevils               161
# Gujarat Lions                   30
# Kings XI Punjab                190
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          192
# Mumbai Indians                 203
# Pune Warriors                   46
# Rajasthan Royals               161
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    195
# Sunrisers Hyderabad            124
# dtype: int64

# %%
match_data['team2'].value_counts()
# Out:
# Mumbai Indians                 106
# Kings XI Punjab                 98
# Kolkata Knight Riders           97
# Rajasthan Royals                91
# Royal Challengers Bangalore     87
# Chennai Super Kings             84
# Delhi Daredevils                78
# Sunrisers Hyderabad             65
# Deccan Chargers                 36
# Pune Warriors                   23
# Gujarat Lions                   14
# Delhi Capitals                  14
# Rising Pune Supergiant           9
# Kochi Tuskers Kerala             7
# Rising Pune Supergiants          7
# Name: team2, dtype: int64

# %%
match_data['team1'].value_counts()
# Out:
# Royal Challengers Bangalore    108
# Mumbai Indians                  97
# Kolkata Knight Riders           95
# Chennai Super Kings             94
# Kings XI Punjab                 92
# Delhi Daredevils                83
# Rajasthan Royals                70
# Sunrisers Hyderabad             59
# Deccan Chargers                 39
# Pune Warriors                   23
# Delhi Capitals                  19
# Gujarat Lions                   16
# Kochi Tuskers Kerala             7
# Rising Pune Supergiants          7
# Rising Pune Supergiant           7
# Name: team1, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
delivery_data = pd.read_csv("D:\Data for Preprocessing\IPL Ball-by-Ball 2008-2020.csv")
match_data = pd.read_csv("D:\Data for Preprocessing\IPL Matches 2008-2020.csv")
match_data
match_data['city'].unique()
match_data['city'].nunique()
match_data['venue'].unique()
match_data['venue'].nunique()
match_data['toss_winner'].value_counts(ascending=False)[0:5]
type(match_data['toss_winner'].value_counts(ascending=False))
match_data['toss_winner'].value_counts(ascending=False)[0:5].plot(kind = 'bar')
match_data['toss_winner'].value_counts(ascending=False)[0:5].index
match_data['toss_winner'].value_counts(ascending=False)[0:5].index[0]
match_data['player_of_match'].value_counts(ascending=False)[0:5].index[0]
delivery_data
UV = delivery_data[delivery_data['batsman'] == 'Yuvraj Singh']
UV['batsman_runs'].unique()
len(UV[UV['batsman_runs'] == 1])
len(UV[UV['batsman_runs'] == 2])*2
len(UV[UV['batsman_runs'] == 3])*3
len(UV[UV['batsman_runs'] == 1])*4
len(UV[UV['batsman_runs'] == 1])*6
values = [9, 238, 741, 2964, 4446]
label= [3, 2, 1, 4, 6]
type(label)
# Pie Chart

fig, ax = plt.subplots(figsize = (12,7))

pie = ax.pie(
    x=values, ## sorting the data from largest to lowest, but make sure you should provide the correct label
    startangle=180,
    labels=label,
    autopct='%.0f%%',
    explode = (0.6, 0, 0, 0,0),
    textprops={'color': 'white'} 
)


for label in pie[1]:
    label.set_color('white')



ax.set_title('Share of Home Sales Select CA Markets', color='white')

plt.show()

match_data
match_data.info()
match_data['date'] = pd.to_datetime(match_data['date'])
match_data['Year'] = match_data['date'].dt.year
match_data.head(2)
df = match_data.groupby(['Year','toss_decision']).size().reset_index().rename(columns={0: 'Count'})
fig, ax = plt.subplots(figsize = (15,8))

sns.barplot(x='Year', y = 'Count', hue = 'toss_decision', data = df)
match_data.head()
#toss_winner, winner
match_data['Checking_Con'] = match_data.apply(lambda row:'Yes' if row['toss_winner'] == row['winner']else 'No', axis =1)
match_data.head(2)
df = match_data['Checking_Con'].value_counts().reset_index()
winG_winT = df.set_index('index')
winG_winT

fig, ax = plt.subplots(figsize = (12,5))

pie = ax.pie(
    x=winG_winT['Checking_Con'], ## sorting the data from largest to lowest, but make sure you should provide the correct label
    startangle=90,
    labels=['Yes', 'No'],
    autopct='%.0f%%',
    explode = (0, .2)
)


for label in pie[1]:
    label.set_color('white')

ax.set_title('Winning toss implies winning Matches', color='white')

plt.show()
match_data.head(3)
match_data['winner', 'Year'].value_counts()
match_data[match_data['Year'] == 2008].sort_values(by = 'date').tail(1)['toss_winner'].values[0]
winners_team = {}

for year in sorted(match_data['Year'].unique()):
     current_yr_df = match_data[match_data['Year'] == year]
     winners_team[year] = current_yr_df.tail(1)['winner'].values[0]
winners_team
from collections import Counter
Counter(winners_team.values())
match_data.head(5)
T_M = match_data['team1'].value_counts() + match_data['team2'].value_counts()

T_M = Total_Macthes.reset_index()
Total_Matches = T_M.rename(columns = {'index': 'Teams', 0 : 'Matches_Played'})
Total_Matches
W_L = match_data['winner'].value_counts()
W_L_E = W_L.reset_index()
winner_list = W_L_E.rename(columns = {'index': 'Teams' ,'winner' : 'Wins'})
winner_list
final_list = Total_Matches.merge(winner_list, how = 'inner', on = 'Teams')
final_list
# Set the figure size
plt.figure(figsize=(15, 8))

# Number of teams
num_teams = len(final_list)

# Set the bar width and positions
bar_width = 0.35
index = np.arange(num_teams)

# Create the grouped bar chart
plt.bar(index, df['Matches_Played'], bar_width, color='skyblue', label='Matches Played')
plt.bar(index + bar_width, df['Wins'], bar_width, color='salmon', label='Wins')

# Set x-axis labels and rotate for better readability
plt.xlabel('Teams')
plt.xticks(index + bar_width, df['Teams'], rotation=90)

# Set y-axis label
plt.ylabel('Metrics')

# Add a legend
plt.legend(title='Metrics', bbox_to_anchor = (1,1))

# Add a title
plt.title('Matches Played vs. Wins by Team (Grouped Bar Chart)')

# Display the chart
plt.tight_layout()
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...
