# %%
import pandas as pd

# %%
sat = pd.read_csv('D:\karan data\Data for Preprocessing\scores.csv', index_col='date' ,parse_dates=True)

# %%
sat.head()
# Out:
#                                       School Name    Borough  \
# date
# 01-01-2023  A. Philip Randolph Campus High School  Manhattan
# 02-01-2023  A. Philip Randolph Campus High School  Manhattan
# 03-01-2023  A. Philip Randolph Campus High School  Manhattan
# 04-01-2023            Abraham Lincoln High School   Brooklyn
# 05-01-2023            Abraham Lincoln High School   Brooklyn
#
#             Student Enrollment Percent Tested SAT Section  Score  Unnamed: 7
# date
# 01-01-2023                1354         74.00%        Math    459         NaN
# 02-01-2023                1354         74.00%     Reading    453         NaN
# 03-01-2023                1354         74.00%     Writing    447         NaN
# 04-01-2023                2341         54.90%        Math    441         NaN
# 05-01-2023                2341         54.90%     Reading    422         NaN

# %%
sat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1125 entries, 01-01-2023 to 29-01-2026
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   School Name         1125 non-null   object
#  1   Borough             1125 non-null   object
#  2   Student Enrollment  1125 non-null   int64
#  3   Percent Tested      1125 non-null   object
#  4   SAT Section         1125 non-null   object
#  5   Score               1125 non-null   int64
#  6   Unnamed: 7          0 non-null      float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 70.3+ KB

# %%
sat.pivot_table(index = 'Borough', values= 'Student Enrollment', aggfunc={'Student Enrollment':['count', 'mean']}).sort_values(('Student Enrollment', 'count'), ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15308\2255744547.py in ?()
# ----> 1 sat.pivot_table(index = 'Borough', values= 'Student Enrollment', aggfunc={'Student Enrollment':['count', 'mean']}).sort_values(('Student Enrollment', 'count'), ascending=False)
#
# c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6754         elif len(by):
#    6755             # len(by) == 1
#    6756
#    6757             by = by[0]
# -> 6758             k = self._get_label_or_level_values(by, axis=axis)
#    6759
#    6760             # need to rewrap column in Series to apply key function
#    6761             if key is not None:
#
# c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
# ...

# %%
sat.pivot_table(index='Borough', values='Student Enrollment', aggfunc=['sum', 'mean'])
# Out:
#                              sum               mean
#               Student Enrollment Student Enrollment
# Borough
# Bronx                     159267         541.724490
# Brooklyn                  242814         742.550459
# Manhattan                 170370         638.089888
# Queens                    232437        1122.884058
# Staten Island              55380        1846.000000

# %%
sat
# Out:
#                                            School Name    Borough  \
# date
# 01-01-2023       A. Philip Randolph Campus High School  Manhattan
# 02-01-2023       A. Philip Randolph Campus High School  Manhattan
# 03-01-2023       A. Philip Randolph Campus High School  Manhattan
# 04-01-2023                 Abraham Lincoln High School   Brooklyn
# 05-01-2023                 Abraham Lincoln High School   Brooklyn
# ...                                                ...        ...
# 25-01-2026  Young Women's Leadership School in Astoria     Queens
# 26-01-2026  Young Women's Leadership School in Astoria     Queens
# 27-01-2026   Young Women's Leadership School in Queens     Queens
# 28-01-2026   Young Women's Leadership School in Queens     Queens
# 29-01-2026   Young Women's Leadership School in Queens     Queens
#
#             Student Enrollment Percent Tested SAT Section  Score  Unnamed: 7
# date
# 01-01-2023                1354         74.00%        Math    459         NaN
# ...

# %%
sat_Queen = sat[sat['Borough'] == 'Queens'].drop('Unnamed: 7', axis=1)

# %%
sat_Queen.pivot_table(index='School Name',columns = 'SAT Section', values = 'Score').sort_values(by = 'Math',ascending=False)
# Out:
# SAT Section                                         Math  Reading  Writing
# School Name
# Queens High School for the Sciences at York Col...   701      621      625
# Townsend Harris High School                          680      640      661
# Baccalaureate School for Global Education            633      620      628
# Bard High School Early College Queens                631      598      610
# Scholars' Academy                                    588      560      568
# ...                                                  ...      ...      ...
# Middle College High School at LaGuardia Communi...   377      389      377
# Queens High School for Information, Research, a...   372      362      352
# August Martin High School                            366      372      364
# Rockaway Park High School for Environmental Sus...   357      381      376
# Pan American International High School               340      320      318
#
# [69 rows x 3 columns]
