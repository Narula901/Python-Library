# %%
# Practice Problems - Groupby
# https://www.udemy.com/course/data-analysis-with-pandas/learn/lecture/5937656#overview

# %%
import pandas as pd
import numpy as np

# %%
games = pd.read_csv("D:\karan data\Data for Preprocessing\games_sales.csv")

# %%
games
# Out:
#                                 Name Platform    Year         Genre  \
# 0                 Kinect Adventures!     X360  2010.0          Misc
# 1                 Grand Theft Auto V      PS3  2013.0        Action
# 2                 Grand Theft Auto V     X360  2013.0        Action
# 3     Call of Duty: Modern Warfare 3     X360  2011.0       Shooter
# 4            Call of Duty: Black Ops     X360  2010.0       Shooter
# ...                              ...      ...     ...           ...
# 3138                  Bound By Flame     X360  2014.0  Role-Playing
# 3139                    Mighty No. 9     XOne  2016.0      Platform
# 3140              Resident Evil 4 HD     XOne  2016.0       Shooter
# 3141   Farming 2017 - The Simulation      PS4  2016.0    Simulation
# 3142               Rugby Challenge 3     XOne  2016.0        Sports
#
#                    Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0     Microsoft Game Studios     14.97      4.94      0.24         1.67
# ...

# %%
Genre = games.groupby('Genre')

# %%
Genre.first()
# Out:
#                                         Name Platform    Year  \
# Genre
# Action                    Grand Theft Auto V      PS3  2013.0
# Adventure                   Assassin's Creed     X360  2007.0
# Fighting                   Street Fighter IV      PS3  2009.0
# Misc                      Kinect Adventures!     X360  2010.0
# Platform                     LittleBigPlanet      PS3  2008.0
# Puzzle                      Katamari Forever      PS3  2009.0
# Racing                        Gran Turismo 5      PS3  2010.0
# Role-Playing     The Elder Scrolls V: Skyrim     X360  2011.0
# Shooter       Call of Duty: Modern Warfare 3     X360  2011.0
# Simulation                        The Sims 3     X360  2010.0
# Sports                               FIFA 16      PS4  2015.0
# Strategy                           Halo Wars     X360  2009.0
#
#                                 Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Genre
# ...

# %%
Genre.groups
# Out:
# {'Action': [1, 2, 12, 13, 16, 25, 34, 36, 39, 42, 44, 48, 49, 52, 54, 59, 60, 61, 64, 65, 68, 69, 73, 75, 77, 85, 86, 89, 92, 100, 101, 105, 106, 116, 117, 118, 121, 126, 127, 128, 129, 144, 146, 150, 153, 163, 168, 170, 172, 173, 183, 185, 192, 196, 198, 212, 213, 214, 216, 225, 226, 227, 229, 236, 239, 240, 241, 247, 253, 254, 257, 263, 269, 272, 277, 288, 291, 292, 300, 302, 304, 306, 309, 310, 315, 325, 330, 331, 335, 338, 339, 348, 353, 354, 355, 358, 363, 364, 365, 367, ...], 'Adventure': [53, 70, 132, 139, 174, 308, 344, 435, 456, 669, 768, 813, 838, 867, 891, 972, 979, 1056, 1107, 1134, 1188, 1289, 1299, 1330, 1355, 1457, 1515, 1576, 1595, 1621, 1634, 1655, 1706, 1720, 1734, 1752, 1754, 1775, 1785, 1809, 1812, 1849, 1879, 1897, 1900, 1958, 1982, 2011, 2030, 2043, 2049, 2121, 2125, 2135, 2163, 2177, 2196, 2242, 2246, 2272, 2288, 2291, 2295, 2302, 2325, 2337, 2338, 2380, 2448, 2486, 2493, 2502, 2508, 2514, 2518, 2554, 2587, 2602, 2608, 2609, 2613, 2615, 2639, 2648, 2686, 2695, 
# ...

# %%
Genre.get_group('Adventure')
# Out:
#                                                    Name Platform    Year  \
# 53                                     Assassin's Creed     X360  2007.0
# 70                                     Assassin's Creed      PS3  2007.0
# 132                                          L.A. Noire      PS3  2011.0
# 139                                          Heavy Rain      PS3  2010.0
# 174                                          L.A. Noire     X360  2011.0
# ...                                                 ...      ...     ...
# 3108                        Hakuouki: Shinsengumi Kitan      PS3     NaN
# 3116                                          Time Leap     X360  2009.0
# 3118                                        Chaos;Child      PS3  2015.0
# 3125  Shin Koihime Musou: Otome Taisen * Sangokushi ...      PS3  2014.0
# 3132                           Akatsuki no Goei Trinity      PS3  2012.0
#
#           Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
games.query('Genre == "Adventure"')
# Out:
#                                                    Name Platform    Year  \
# 53                                     Assassin's Creed     X360  2007.0
# 70                                     Assassin's Creed      PS3  2007.0
# 132                                          L.A. Noire      PS3  2011.0
# 139                                          Heavy Rain      PS3  2010.0
# 174                                          L.A. Noire     X360  2011.0
# ...                                                 ...      ...     ...
# 3108                        Hakuouki: Shinsengumi Kitan      PS3     NaN
# 3116                                          Time Leap     X360  2009.0
# 3118                                        Chaos;Child      PS3  2015.0
# 3125  Shin Koihime Musou: Otome Taisen * Sangokushi ...      PS3  2014.0
# 3132                           Akatsuki no Goei Trinity      PS3  2012.0
#
#           Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
games.iat[49,3]
# Out:
# 'Action'

# %%
games.iloc[65]
# Out:
# Name              Grand Theft Auto V
# Platform                        XOne
# Year                          2014.0
# Genre                         Action
# Publisher       Take-Two Interactive
# NA_Sales                        2.66
# EU_Sales                        2.01
# JP_Sales                         0.0
# Other_Sales                     0.41
# Global_Sales                    5.08
# Name: 65, dtype: object

# %%
Genre_Comparison = Genre.sum().select_dtypes(include=float).reset_index()

# %%
Top_Genre_Global_Sales = Genre_Comparison.set_index('Genre').sort_values(by = 'Global_Sales', ascending = False).iloc[:5]

# %%
Top_Genre_Global_Sales
# Out:
#                    Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Genre
# Action        1772291.0    311.70    237.09     37.82        84.73
# Shooter        842555.0    315.90    200.15     14.40        70.94
# Sports        1013418.0    182.70    116.07      9.25        40.73
# Role-Playing   508978.0     88.32     51.96     22.67        19.64
# Racing         458415.0     63.37     71.04      3.96        21.92
#
#               Global_Sales
# Genre
# Action              671.40
# Shooter             601.52
# Sports              348.72
# Role-Playing        182.53
# Racing              160.27

# %%
Top_Genre_Global_Sales.loc[:, 'Global_Sales'].plot(kind= 'barh', color = 'Red')
# Out:
# <Axes: ylabel='Genre'>

# %%
Genre[['NA_Sales']].sum().sort_values(by = 'NA_Sales').plot(kind = 'barh', legend=False)
# Out:
# <Axes: ylabel='Genre'>

# %%
games
# Out:
#                                 Name Platform    Year         Genre  \
# 0                 Kinect Adventures!     X360  2010.0          Misc
# 1                 Grand Theft Auto V      PS3  2013.0        Action
# 2                 Grand Theft Auto V     X360  2013.0        Action
# 3     Call of Duty: Modern Warfare 3     X360  2011.0       Shooter
# 4            Call of Duty: Black Ops     X360  2010.0       Shooter
# ...                              ...      ...     ...           ...
# 3138                  Bound By Flame     X360  2014.0  Role-Playing
# 3139                    Mighty No. 9     XOne  2016.0      Platform
# 3140              Resident Evil 4 HD     XOne  2016.0       Shooter
# 3141   Farming 2017 - The Simulation      PS4  2016.0    Simulation
# 3142               Rugby Challenge 3     XOne  2016.0        Sports
#
#                    Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0     Microsoft Game Studios     14.97      4.94      0.24         1.67
# ...

# %%
Genre.size()
# Out:
# Genre
# Action          894
# Adventure       152
# Fighting        165
# Misc            280
# Platform         76
# Puzzle           11
# Racing          233
# Role-Playing    255
# Shooter         426
# Simulation       79
# Sports          512
# Strategy         60
# dtype: int64

# %%
games.head(3)
# Out:
#                  Name Platform    Year   Genre               Publisher  \
# 0  Kinect Adventures!     X360  2010.0    Misc  Microsoft Game Studios
# 1  Grand Theft Auto V      PS3  2013.0  Action    Take-Two Interactive
# 2  Grand Theft Auto V     X360  2013.0  Action    Take-Two Interactive
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     14.97      4.94      0.24         1.67         21.82
# 1      7.01      9.27      0.97         4.14         21.40
# 2      9.63      5.31      0.06         1.38         16.38

# %%
Genre_Name = games.groupby(['Genre', 'Name'])

# %%
Genre_Name[['Global_Sales']].sum()
# Out:
#                                               Global_Sales
# Genre    Name
# Action   .hack: Sekai no Mukou ni + Versus            0.03
#          007: Quantum of Solace                       2.65
#          3rd Super Robot Wars Z: Tengoku-Hen          0.15
#          7 Days to Die                                0.16
#          Ace Combat: Assault Horizon                  1.23
# ...                                                    ...
# Strategy Warhammer: Battle March                      0.11
#          Worms                                        0.05
#          XCOM 2                                       0.06
#          XCOM: Enemy Unknown                          1.24
#          Zoids Assault                                0.09
#
# [1931 rows x 1 columns]

# %%
dfs = []

# %%
df
# Out:
# Empty DataFrame
# Columns: [Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []

# %%
Genre

# %%
df = pd.DataFrame(columns = games.columns)
for genre, data in Genre:
    Highest_Global_Sales_in_group = data.nlargest(1,'Global_Sales')
    dfs.append(Highest_Global_Sales_in_group)


df = pd.concat(dfs, ignore_index=True)

# %%
import pandas as pd

# Initialize an empty list to store DataFrames
dfs = []

# Iterate over the Genre groups
for genre, data in Genre:
    # Find the row with the highest global sales for each genre
    Highest_Global_Sales_in_group = data.nlargest(1, 'Global_Sales')
    # Append this DataFrame to the list
    dfs.append(Highest_Global_Sales_in_group)

# Concatenate all DataFrames in the list to create the final DataFrame
df = pd.concat(dfs, ignore_index=True)

# Now df contains the concatenated data

# %%
df
# Out:
#                               Name Platform    Year         Genre  \
# 0               Grand Theft Auto V      PS3  2013.0        Action
# 1                 Assassin's Creed     X360  2007.0     Adventure
# 2                Street Fighter IV      PS3  2009.0      Fighting
# 3               Kinect Adventures!     X360  2010.0          Misc
# 4                  LittleBigPlanet      PS3  2008.0      Platform
# 5                 Katamari Forever      PS3  2009.0        Puzzle
# 6                   Gran Turismo 5      PS3  2010.0        Racing
# 7      The Elder Scrolls V: Skyrim     X360  2011.0  Role-Playing
# 8   Call of Duty: Modern Warfare 3     X360  2011.0       Shooter
# 9                       The Sims 3     X360  2010.0    Simulation
# 10                         FIFA 16      PS4  2015.0        Sports
# 11                       Halo Wars     X360  2009.0      Strategy
# 12              Grand Theft Auto V      PS3  2013.0        Action
# ...
