# %% [markdown]
# Seaborn.Catplot is a function in seaborn that allows you to create categorical plot which are used to visualize relationships between one continous variable and one or more categorical variables

# %%
import seaborn as sns

# %%
df = sns.load_dataset("titanic")
sns.catplot(data=df, x="age", y="class", kind='swarm')
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 12.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df = sns.load_dataset("titanic")
sns.catplot(data=df, x="age", y="class", kind='boxen')

# %%
df = sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.catplot(
    data=df, x="age", y="class", hue="sex",
    kind="violin", bw=.25, cut=0, split=True,
)

# %%
sns.catplot(
    data=df, x="age", y="class", hue="sex",
    kind="violin", bw=.25, split=True,
)

# %%
sns.catplot(
    data=df, x="age", y="class", hue="sex",
    kind="violin"
)

# %%
sns.catplot(
    data=df, x="class", y="survived", col="sex",
    kind="bar", height=7 ,aspect=.6,
)

# %% [markdown]
# For single-subplot figures, it is easy to layer different representations

# %%
sns.catplot(data=df, x="age", y="class", kind="violin", color=".9", inner=None, height= 8, aspect=0.9)
sns.swarmplot(data=df, x="age", y="class", size=3)
# Out:
# <AxesSubplot:xlabel='age', ylabel='class'>

# %%
g = sns.catplot(
    data=df, x="who", y="survived", col="class",
    kind="bar", height=4, aspect=.6,
)
g.set_axis_labels("", "Survival Rate")
g.set_xticklabels(["Men", "Women", "Children"])
g.set_titles("{col_name} {col_var}")
g.set(ylim=(0, 1))
g.despine(left=True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.catplot(
    data=df, x="who", y="survived", col="class",
    kind="bar", height=7 ,aspect=.6,
)
